# %%
import pandas as pd
from opencc import OpenCC
from tqdm import tqdm
tqdm.pandas()

cc = OpenCC('s2t')


df = pd.read_excel('PDCS - 20220101 to 20241203.xlsx')

df = df[['bill_no', 'group_line', 'manufacture_time', 'exception_desc', 'defects_name',
   'reason_fix', 'qc_suggestion']]

# 確保所有值都是字串，並將 NaN 或空值轉換為空字串
df['reason_fix'] = df['reason_fix'].fillna('').astype(str)
df['exception_desc'] = df['exception_desc'].fillna('').astype(str)


df['corpus'] = df['reason_fix'] + ' '+df['exception_desc']
df['corpus'] = df['corpus'].progress_apply(lambda x: cc.convert(x))
# Out:
# 100%|█████████████████████████████████████| 7329/7329 [00:02<00:00, 2542.45it/s]

# %%
import re

def clean_text(text):
    # 移除 _x000D_
    text = re.sub(r'_x000D_', '', text)
    # 替換換行符號 (\n) 為空格
    text = re.sub(r'\n', ' ', text)
    # 替換多個空格為單個空格
    text = re.sub(r'\s+', ' ', text)
    # 移除前後空白字符
    return text.strip()

# 應用清洗函數到 'reason_fix' 欄位
df['corpus'] = df['corpus'].apply(clean_text)

# %%
synonym_df
# Out:
#      main     branch1
# 0     貼裝頭         貼片頭
# 1  Feeder  飛達, feeder
# 2      吸嘴      nozzle
# 3      殘錫  沾錫, 纏錫, 馋錫
# 4      軌道      滑軌, 導軌
# 5      端板      拿板, 取板
# 6      機台          治具
# 7      殘膠  沾膠, 纏膠, 馋膠

# %%
synonym_df = pd.read_excel('SMT同義字整理.xlsx')

def synonym_replacement(input_text, synonym_df=synonym_df):
    """
    Replace words in the input text with their corresponding synonyms based on the synonym dataframe.

    Args:
        input_text (str): The text to be processed.
        synonym_df (pd.DataFrame): A dataframe with two columns: 'main' and 'branch1'.
                                  'main' contains the target word,
                                  'branch1' contains a comma-separated string of synonyms for the target word.

    Returns:
        str: The processed text with synonyms replaced.
    """
    replacement_dict = {}
    for _, row in synonym_df.iterrows():
        main = row['main']
        synonyms = row['branch1'].split(', ')
        for synonym in synonyms:
            replacement_dict[synonym] = main

    # Replace synonyms with main terms
    for synonym, main in replacement_dict.items():
        input_text = input_text.replace(synonym, main)

    return input_text

synonym_replacement('該群組的feeder有沾膠現象')
# Out:
# '該群組的Feeder有殘膠現象'

# %%
df['corpus'] = df['corpus'].apply(synonym_replacement)

# %%
df.loc[0,'corpus']
# Out:
# '1.現場確認為電感偏位不良，3顆用量，3個位置均有不良產出； 2.查詢不良板路由時間：1/7-1/8白晚班均有不良產出，目前不良持續中； 3.更換其它廠商（EATON）交叉驗證，未有不良產出，通過爐前觀察，發現部分流線主板出現電感歪斜不良，仔細目檢電感焊接端子，物料底部兩端凸材面不平整； 4.取下不良板上物料，在顯微鏡下觀察：底部殘錫不均，導致過爐時兩端受力不均，出現偏位不良； 綜上：初步嫌疑為電感底部凸材不均，導致過爐異常，請SQE知會廠商改善。 臨時對策： 1.知會生技持續優化貼裝坐標； 2.更換其它廠商使用； S33線在生產SIERRA-V2（M10314-003）機種時，PL415/PL2005/PL2305位置電感偏位，不良率：28.57%（16/56），請相關單位協助分析改善！'

# %%
#df = df[:500]

# %% [markdown]
# ## 清理文本並進行分詞

# %%
import jieba

# 读取自定义词典
with open('關鍵字熱詞.txt', 'r', encoding='utf-8') as f:
    custom_words = f.readlines()

# 去除多余的换行符并处理词频和词性
processed_words = [f"{word.strip()} 10000 n" for word in custom_words if word.strip()]

# 将处理后的内容保存为新的词典文件
with open('processed_關鍵字熱詞.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join(processed_words))

# 加載自定義詞典
jieba.load_userdict('processed_關鍵字熱詞.txt')
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache /tmp/jieba.cache
# Loading model cost 0.498 seconds.
# Prefix dict has been built successfully.

# %%
import jieba.posseg as pseg
import re
import pandas as pd
from multiprocessing import Pool

# 清理文本函數
def clean_and_segment(text):
    if not isinstance(text, str):  # 確保文本是字串
        return ''
    text = re.sub(r'[^\u4e00-\u9fffa-zA-Z0-9]+', ' ', text)  # 僅保留中文、英文、數字
    words = pseg.cut(text)  # 使用 jieba.posseg 進行分詞與詞性標註
    return " ".join([word for word, flag in words if flag in ['n', 'nz', 'nt', 'nl', 'eng', 'x']])  # 保留名詞和專有名詞



# n：普通名詞
# 代表一般的名詞，例如「物料」、「廠商」、「現場」。
# nz：專有名詞
# 代表專有名詞，例如「SMT」、「Feeder」、「Lenovo」。
# nt：機構團體名
# 代表組織或機構的名稱，例如「公司」、「工廠」。
# nl：地名
# 代表地點或地名，例如「深圳」、「台北」。
# eng：英文單詞
# 代表英文字詞，例如「Rail」、「pin」、「ICT」。

# v：動詞，例如「操作」、「檢查」。
# a：形容詞，例如「不良」、「快速」。
# r：代詞，例如「我們」、「這個」。
# m：數量詞，例如「一個」、「三次」。
# d：副詞，例如「非常」、「嚴重」。

# 清理並分詞
#df['cleaned'] = df['reason_fix'].progress_apply(clean_and_segment)



# 多進程分詞函數
def parallel_segment(df, column, num_processes=4):
    with Pool(num_processes) as pool:
        # 將指定欄位的文本分配到多進程中
        results = pool.map(clean_and_segment, df[column])
    return results


# 使用多進程加速清理和分詞
df['cleaned'] = parallel_segment(df, 'corpus', num_processes=8)

# 3Min

# %%
# import jieba
# import jieba.posseg as pseg
# import re

# # 加載自定義詞典
# jieba.load_userdict('關鍵字熱詞.txt')


# # 清理文本函數
# def clean_and_segment(text):
#     if not isinstance(text, str):  # 確保文本是字串
#         return ''
#     text = re.sub(r'[^\u4e00-\u9fffa-zA-Z0-9]+', ' ', text)  # 僅保留中文、英文、數字
#     words = pseg.cut(text)  # 使用 jieba.posseg 進行分詞與詞性標註
#     return " ".join([word for word, flag in words if flag in ['n', 'nz', 'nt', 'nl', 'eng']])  # 保留名詞和專有名詞

# # n：普通名詞
# # 代表一般的名詞，例如「物料」、「廠商」、「現場」。
# # nz：專有名詞
# # 代表專有名詞，例如「SMT」、「Feeder」、「Lenovo」。
# # nt：機構團體名
# # 代表組織或機構的名稱，例如「公司」、「工廠」。
# # nl：地名
# # 代表地點或地名，例如「深圳」、「台北」。
# # eng：英文單詞
# # 代表英文字詞，例如「Rail」、「pin」、「ICT」。

# # v：動詞，例如「操作」、「檢查」。
# # a：形容詞，例如「不良」、「快速」。
# # r：代詞，例如「我們」、「這個」。
# # m：數量詞，例如「一個」、「三次」。
# # d：副詞，例如「非常」、「嚴重」。

# # 清理並分詞
# df['cleaned'] = df['corpus'].progress_apply(clean_and_segment)

# %%
input_text = df.loc[340,'corpus']
text = re.sub(r'[^\u4e00-\u9fffa-zA-Z0-9]+', ' ', input_text)  # 僅保留中文、英文、數字
words = pseg.cut(input_text)

for word, flag in words:
    print(word, flag)
# Out:
# 1 x
# , x
# 查看 v
# 不良板 n
# ， x
# 確認 v
# CPU1 eng
# 偏位 n
#   x
# 2 x
# , x
# 不良板 n
# 均 d
# 為 p
# D07B eng
#   x
# 5 x
# : x
# 00 m
# - x
# 5 x
# : x
# 09 m
# 產出 v
#   x
# 3 x
# ， x
# 與 p
# 在 p
# 線 n
# 生技 n
# 確認 v
# 為 p
# 固定 n
# 相機 n
# 內 zg
# 掉落 n
# 一顆 m
# PCI eng
# 零件 n
# 導致 v
# ， x
# 取出 v
# 零件 n
# 後 nr
# 跟 p
# 進無 v
# 不良 a
#   x
# 綜上 n
# ： x
# 初步 d
# 確認 v
# 為 p
# 設備異常 n
# ， x
# 請 zg
# 生技 n
# 及時 c
# 改善 v
#   x
# D07 eng
# 線 n
# 在 p
# 生產 n
# D12 eng
# - x
# KYOTO eng
# - x
# SFF eng
# 機種 n
# 時 zg
# ， x
# SMT n
# - x
# R x
# 維修 n
# 區 n
# 有 v
# 發現 v
# CPU1 eng
# 偏位 n
# 不良 a
# * x
# 11 m
# PCS eng
# ， x
# 不良率 n
# 為 zg
# ： x
# 3.42 m
# % x
# （ x
# 11 m
# / x
# 321 m
# ） x
# ， x
# 還 d
# 請 v
# 相關 v
# 單位 n
# 協助 v
# 分析 vn
# 改善 v
# ！ x

# %% [markdown]
# ## TF-IDF 計算

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(ngram_range=(1, 1), max_features=1000)  # 可調整 max_features 控制關鍵字數量
tfidf_matrix = vectorizer.fit_transform(df['cleaned'])
keywords = vectorizer.get_feature_names_out()

# %% [markdown]
# ## 關鍵詞過濾

# %%
len(tfidf_matrix.toarray()[0])
# Out:
# 1000

# %%
len(keywords)
# Out:
# 1000

# %%
THRESHOLD = 0.2
# 不需要的關鍵詞
BLACKLIST = {
    '綜上', '狀況', '現象',  
    '廠商', '晚班', '對策', '部分', '功能', '時間', '報警', '記錄', '人員', '員工', '新人',
    '問題', '效果', '方向', '參數', '信息', '作業', '現場', '面板', '痕跡', '用量', '規格',
    '物料', '來料', '件數', '結果', '方式', '流程', '環境', '位置', '區域',
    "產生", "led", "dp", "mm", "spec", "外觀", "ok", "t4", "手法", "機種",
    "產線", "立碑", "元件", "cover", "無法", 
    "真空", "parts", "手動", "j210", "qfn", "校正", "環球", "tbl1", "插件", "fail", "ft",
    "pass", "工站", "成品", "過程", "風險", "建議", "pad", "class", "juki", "obe", "全面",
    "插件", "補件", "裝箱", "重點", "開箱", "t3", "高度", "s3", "typec", "用料", "综上", "厂商",
    "定位", "时间", "pth", "實際", "问题", "teach", "夜班", "拋料", "過爐", "sqe", "本體", "参数",
    "时间", "机台", "现场", "用料", "痕迹", "p29a", "厚度", "用料", "tbl2", "p27a", 
    "无法", "pcs", "絲印", "工站", "mm", "um", "情況", "pcs", "夜班", "时间", "t1", "产线",
    "建舜", "成品", "来料", "状况", "高度", "joinsoon", "sqe", "人员", "现场", "痕迹", "錯誤",
    "deren", "Foxconn", "pcie", "slot2", "变形", "定位", "现象", "產生", "接器", "產時",
    "用料", "真空", "重點", "高空", "dc", "pci", "sn", "p29", "環球", "批量", "p27b",
    "本體", "供料", "工程", "線產", "ge", "变形", "对策", "原因", "opt", "作业",
    "神目", "鐵架", "tbl3", "異物", "对策", "過程", "範圍", "j38", "狀態", "音源", "mos", "tbl4",
    "j70", "j71", "dp2", "轨贴", "t2", "p33", "原因", "记录",
    "foxconn", 
    # 新增關鍵詞
    '測試', '校驗', '測量', '工序', '缺陷', '不良', '狀態', '流程卡', '設備', '工藝', '調整', 
    '維護', '人為', '材質', '圖紙', '編號', '分配', '上傳', '標記', '批次', '機型', '檢查', '拆裝', 
    '運行', '清單', '參數調整', '檔案', '庫存', '操作記錄', '工作表', '工藝卡', '制程卡', '版本號', 
    '表面檢查', '焊接', '熱壓', '條碼', '測試結果', '儲存', '零件清單', '生產數據', '技術標準', '設計圖',
    '黑色', '可能性', 'and', '范围', '黑色', '可能性', '科技', '部門', '黑色', '重点',
    '規範', '错误', '部門', '行程', '起子', '嫌疑人', '面積', '动作', '全成信', '人工',
    '個別', '中心', '交接班', '产生', '少件', '嫌疑人', '尺寸', '报警', '过程', '角度',
    'date', 'study', 'me', '生技'
}
    




def filter_keywords(tfidf_scores, keywords, threshold, blacklist):
    filtered_keywords = []
    for score, keyword in zip(tfidf_scores, keywords):
        if score >= threshold and keyword not in blacklist:
            filtered_keywords.append((keyword, score))
    return filtered_keywords


filtered_results = []
for idx, row in enumerate(tfidf_matrix.toarray()):
    filtered = filter_keywords(row, keywords, THRESHOLD, BLACKLIST)
    filtered_results.append(", ".join([f"{kw} ({score:.2f})" for kw, score in filtered]))
    print(f"文本 {idx + 1} 的代表性關鍵詞：")
    for keyword, score in filtered:
        print(f" - {keyword}: {score:.3f}")
# Out:
# 文本 1 的代表性關鍵詞：
#  - 偏位: 0.244
#  - 電感: 0.655
# 文本 2 的代表性關鍵詞：
#  - p31: 0.370
#  - trinidad: 0.452
#  - 效率: 0.381
#  - 直通: 0.584
#  - 重影: 0.318
# 文本 3 的代表性關鍵詞：
#  - mac: 0.243
#  - sb20t22670: 0.218
#  - volga: 0.216
#  - 工具: 0.422
#  - 撞件: 0.483
#  - 端板: 0.249
# 文本 4 的代表性關鍵詞：
#  - l76450: 0.550
#  - p37b: 0.497
#  - ppid: 0.204
#  - tywin: 0.488
#  - 產品: 0.235
#  - 零件: 0.251
# 文本 5 的代表性關鍵詞：
#  - spi: 0.213
#  - 刮刀: 0.259
#  - 鋼網: 0.238
#  - 錫量: 0.506
# 文本 6 的代表性關鍵詞：
#  - p38: 0.581
#  - 燒板: 0.508
#  - 維修: 0.210
# 文本 7 的代表性關鍵詞：
#  - juki插件機: 0.238
#  - m10197: 0.232
#  - p31a: 0.228
#  - trinidad: 0.212
#  - 壓痕: 0.265
#  - 表面: 0.236
#  - 電容: 0.237
# 文本 8 的代表性關鍵詞：
#  - buffalo: 0.245
#  - d08: 0.224
#  - d11: 0.219
#  - 剪腳: 0.583
#  - 機打: 0.215
#  - 腳長: 0.251
#  - 自動: 0.237
# 文本 9 的代表性關鍵詞：
#  - m10197: 0.296
#  - trinidad: 0.271
#  - 反白: 0.267
#  - 殘件: 0.611
# 文本 10 的代表性關鍵詞：
#  - dimm2: 0.877
#  - ohm: 0.211
#  - 阻值: 0.285
# 文本 11 的代表性關鍵詞：
#  - ict: 0.262
#  - kent5: 0.208
#  - m98850: 0.216
#  - pca: 0.234
#  - 上線: 0.220
#  - 卡板: 0.256
#  - 板邊: 0.340
#  - 線路: 0.363
#  - 軌道: 0.373
# 文本 12 的代表性關鍵詞：
#  - d07: 0.218
#  - d10: 0.259
#  - ssd: 0.479
#  - 短路: 0.293
# 文本 13 的代表性關鍵詞：
#  - d05: 0.236
#  - k5c: 0.267
#  - 上線: 0.241
#  - 壓件: 0.779
#  - 螺絲: 0.367
# 文本 14 的代表性關鍵詞：
#  - pin: 0.517
#  - rt: 0.205
#  - smt: 0.215
#  - x0y8: 0.214
#  - 結構: 0.209
# 文本 15 的代表性關鍵詞：
#  - j39: 0.286
#  - jamie: 0.293
#  - l76451: 0.318
#  - p35b: 0.261
#  - 微鏡: 0.232
#  - 膠紙: 0.289
# 文本 16 的代表性關鍵詞：
#  - p3d: 0.264
#  - tywin: 0.205
#  - 條件: 0.562
#  - 雙面: 0.247
#  - 電容: 0.366
# 文本 17 的代表性關鍵詞：
#  - final: 0.320
#  - vi: 0.297
#  - 偏位: 0.458
#  - 腳座: 0.270
#  - 貼裝頭: 0.323
#  - 電容: 0.319
# 文本 18 的代表性關鍵詞：
#  - cpu: 0.239
#  - p34b: 0.204
#  - pin: 0.299
#  - 堆板: 0.436
#  - 幹部: 0.238
#  - 背板: 0.377
#  - 螺絲: 0.321
# 文本 19 的代表性關鍵詞：
#  - pin: 0.254
#  - rt: 0.201
#  - 折角: 0.206
# 文本 20 的代表性關鍵詞：
#  - p34b: 0.237
#  - 異常: 0.278
#  - 電容: 0.772
# 文本 21 的代表性關鍵詞：
#  - d05: 0.212
#  - dimm: 0.328
#  - dimm1: 0.202
#  - jwjy: 0.245
#  - 技能: 0.233
#  - 插件機: 0.505
#  - 數量: 0.221
#  - 目檢: 0.251
# 文本 22 的代表性關鍵詞：
#  - 孔徑: 0.258
#  - 直徑: 0.570
# 文本 23 的代表性關鍵詞：
#  - m09983: 0.208
#  - pike: 0.203
#  - s31: 0.235
#  - 偏位: 0.334
#  - 電感: 0.719
# 文本 24 的代表性關鍵詞：
#  - hu: 0.233
#  - pe: 0.224
#  - 板子: 0.507
#  - 花板: 0.498
#  - 設計: 0.212
#  - 變形: 0.289
#  - 貼片機: 0.225
# 文本 25 的代表性關鍵詞：
#  - aoi: 0.270
#  - spi: 0.234
#  - 偏位: 0.424
#  - 錫膏印刷: 0.391
#  - 錫量: 0.370
# 文本 26 的代表性關鍵詞：
#  - p34a: 0.253
#  - 幹部: 0.280
#  - 技能: 0.268
#  - 撞件: 0.468
#  - 散熱片: 0.207
#  - 機台: 0.210
#  - 濾波: 0.264
# 文本 27 的代表性關鍵詞：
#  - audio: 0.598
#  - d07: 0.479
#  - repair: 0.423
#  - 處理: 0.236
# 文本 28 的代表性關鍵詞：
#  - ng: 0.284
#  - sff: 0.277
#  - 偏位: 0.499
#  - 更換: 0.258
#  - 設備異常: 0.264
#  - 電容: 0.260
# 文本 29 的代表性關鍵詞：
#  - 0402電容: 0.210
#  - refresh: 0.304
#  - salween: 0.302
#  - sb20t22662: 0.304
#  - 微鏡: 0.206
#  - 貼裝: 0.311
#  - 零件: 0.234
# 文本 30 的代表性關鍵詞：
#  - j41: 0.452
#  - p31: 0.370
#  - pike: 0.440
#  - 品質: 0.326
#  - 效率: 0.381
#  - 重影: 0.317
# 文本 31 的代表性關鍵詞：
#  - aoi: 0.272
#  - 偏位: 0.256
#  - 偶發性: 0.267
#  - 吸料: 0.284
#  - 濾波: 0.270
#  - 電容: 0.267
#  - 高三: 0.241
# 文本 32 的代表性關鍵詞：
#  - d05: 0.266
#  - p1: 0.289
#  - sfc: 0.304
#  - 目檢: 0.314
# 文本 33 的代表性關鍵詞：
#  - j94: 0.612
#  - tywin: 0.342
#  - 聯基: 0.209
#  - 變形: 0.284
# 文本 34 的代表性關鍵詞：
#  - hdmi: 0.249
#  - kent5: 0.222
#  - m98850: 0.230
#  - p3a: 0.245
#  - power: 0.283
#  - 撞件: 0.294
#  - 表量: 0.257
# 文本 35 的代表性關鍵詞：
#  - e49: 0.567
#  - m81542: 0.248
#  - p37a: 0.212
#  - pin: 0.206
#  - reno2: 0.244
#  - 短路: 0.264
# 文本 36 的代表性關鍵詞：
#  - cr15: 0.658
#  - 板子: 0.281
# 文本 37 的代表性關鍵詞：
#  - 0402電容: 0.243
#  - aoi: 0.318
#  - m09983: 0.279
#  - pike: 0.273
#  - smt: 0.234
#  - 偏出: 0.304
#  - 貼裝: 0.240
# 文本 38 的代表性關鍵詞：
#  - m09983: 0.474
#  - p31a: 0.511
#  - pike: 0.464
#  - 產品: 0.215
# 文本 39 的代表性關鍵詞：
#  - d10b: 0.245
#  - repair: 0.209
#  - type: 0.227
#  - typec1: 0.596
#  - 刮刀: 0.220
# 文本 40 的代表性關鍵詞：
#  - ec1: 0.331
#  - pin: 0.210
#  - 偏位: 0.372
#  - 引腳: 0.237
#  - 識別: 0.392
#  - 貼片機: 0.337
# 文本 41 的代表性關鍵詞：
#  - d08: 0.205
#  - d10b: 0.210
#  - pin: 0.211
#  - wlan: 0.480
#  - 機臺: 0.248
#  - 異常: 0.253
#  - 週期: 0.238
# 文本 42 的代表性關鍵詞：
#  - con: 0.476
#  - uf: 0.363
#  - 原物料: 0.278
#  - 電容: 0.218
# 文本 43 的代表性關鍵詞：
#  - p34a: 0.278
#  - smt: 0.215
#  - 微鏡: 0.218
#  - 板作業: 0.244
#  - 設備貼裝: 0.235
#  - 貼片: 0.231
#  - 雙面: 0.290
#  - 電阻: 0.225
#  - 高一: 0.233
# 文本 44 的代表性關鍵詞：
#  - d05: 0.461
#  - dimm: 0.356
#  - dimm1: 0.438
#  - k5c: 0.260
# 文本 45 的代表性關鍵詞：
#  - bent: 0.274
#  - cpu: 0.471
#  - d10a: 0.279
#  - pin: 0.523
#  - 腳座: 0.246
# 文本 46 的代表性關鍵詞：
#  - 貼裝參數: 0.259
# 文本 47 的代表性關鍵詞：
#  - d04: 0.309
#  - m81592: 0.215
#  - scrabble: 0.213
#  - 板邊: 0.213
#  - 機台: 0.233
# 文本 48 的代表性關鍵詞：
#  - d04: 0.381
#  - hu: 0.201
#  - pin: 0.401
#  - 板邊: 0.263
# 文本 49 的代表性關鍵詞：
#  - u1: 0.371
#  - 壓件: 0.349
#  - 貼裝頭: 0.517
#  - 高一: 0.414
# 文本 50 的代表性關鍵詞：
#  - c1: 0.304
#  - 阻值: 0.625
#  - 體值: 0.396
# 文本 51 的代表性關鍵詞：
#  - 固定: 0.200
#  - 料盤: 0.443
#  - 電池: 0.753
# 文本 52 的代表性關鍵詞：
#  - con: 0.393
#  - pn: 0.291
#  - 引腳: 0.411
#  - 插件機: 0.267
#  - 電容: 0.270
# 文本 53 的代表性關鍵詞：
#  - d04: 0.215
#  - npi: 0.226
#  - 螺絲: 0.437
#  - 變形: 0.280
#  - 鐵件: 0.742
# 文本 54 的代表性關鍵詞：
#  - d09: 0.262
#  - d10: 0.290
#  - dy62r: 0.312
#  - feeder: 0.205
#  - repair: 0.216
#  - 反白: 0.501
# 文本 55 的代表性關鍵詞：
#  - kent5: 0.346
#  - m98850: 0.358
#  - p3a: 0.382
#  - 上料: 0.312
#  - 上料員: 0.341
#  - 品質: 0.248
#  - 背板: 0.326
#  - 隱患: 0.352
# 文本 56 的代表性關鍵詞：
#  - kent5: 0.301
#  - m98850: 0.312
#  - 引腳: 0.254
#  - 插件機: 0.247
#  - 松下: 0.344
#  - 機打: 0.278
#  - 腳長: 0.325
#  - 電容: 0.334
# 文本 57 的代表性關鍵詞：
#  - fbt: 0.256
#  - p32b: 0.249
#  - refresh: 0.307
#  - salween: 0.305
#  - sb20t22662: 0.307
#  - smt: 0.205
#  - 機台: 0.220
#  - 貼裝: 0.209
#  - 電容: 0.273
# 文本 58 的代表性關鍵詞：
#  - d04: 0.316
#  - d09: 0.273
#  - m81592: 0.220
#  - 插件機: 0.438
# 文本 59 的代表性關鍵詞：
#  - d10b: 0.633
#  - repair: 0.540
#  - smt: 0.266
#  - 偏位: 0.340
# 文本 60 的代表性關鍵詞：
#  - d10b: 0.312
#  - repair: 0.266
#  - 偏位: 0.335
#  - 吸料位置: 0.546
#  - 跑偏: 0.335
# 文本 61 的代表性關鍵詞：
#  - d10a: 0.520
#  - repair: 0.412
#  - usb3s3: 0.550
#  - 空焊: 0.299
#  - 處理: 0.230
# 文本 62 的代表性關鍵詞：
#  - 設計: 0.325
#  - 貼裝: 0.244
# 文本 63 的代表性關鍵詞：
#  - ff: 0.329
#  - fw: 0.434
#  - hdmi: 0.226
#  - 版本: 0.713
# 文本 64 的代表性關鍵詞：
#  - 剪腳: 0.446
#  - 插件機: 0.388
# 文本 65 的代表性關鍵詞：
#  - d10a: 0.224
#  - 對板: 0.259
#  - 端板: 0.287
#  - 網絡: 0.451
#  - 零件: 0.202
# 文本 66 的代表性關鍵詞：
#  - u4003: 0.852
# 文本 67 的代表性關鍵詞：
#  - j41: 0.241
#  - joffrey: 0.279
#  - l76453: 0.297
#  - p35b: 0.230
#  - 引腳: 0.205
#  - 焊點: 0.563
#  - 維修: 0.250
# 文本 68 的代表性關鍵詞：
#  - d04: 0.425
#  - d09: 0.245
#  - j94: 0.532
#  - 半成品: 0.303
#  - 變形: 0.370
# 文本 69 的代表性關鍵詞：
#  - s34: 0.430
#  - 吸料位置: 0.313
#  - 設備異常: 0.203
#  - 電感: 0.619
# 文本 70 的代表性關鍵詞：
#  - kent5: 0.238
#  - m98850: 0.246
#  - 引腳: 0.201
#  - 機打: 0.220
#  - 漏點: 0.274
#  - 焊點: 0.368
#  - 雙面: 0.267
#  - 電容: 0.396
# 文本 71 的代表性關鍵詞：
#  - oolong: 0.489
#  - xu1: 0.373
#  - 刮刀: 0.336
#  - 錫膏: 0.232
# 文本 72 的代表性關鍵詞：
#  - d05: 0.395
#  - k5c: 0.297
#  - 印刷機: 0.248
#  - 更換: 0.210
#  - 溫度: 0.534
#  - 錫膏: 0.312
# 文本 73 的代表性關鍵詞：
#  - cpu: 0.292
#  - d07: 0.233
#  - 偏位: 0.260
#  - 吸料位置: 0.423
#  - 腳座: 0.458
#  - 跑偏: 0.259
#  - 電容: 0.271
#  - 高五: 0.236
# 文本 74 的代表性關鍵詞：
#  - cpu: 0.213
#  - m81542: 0.214
#  - ray: 0.204
#  - reno2: 0.211
#  - xu1: 0.527
#  - 腳座: 0.501
#  - 錫球: 0.229
# 文本 75 的代表性關鍵詞：
#  - fw: 0.404
#  - u7: 0.606
#  - 版本: 0.398
# 文本 76 的代表性關鍵詞：
#  - dimm1: 0.545
#  - joffrey: 0.212
#  - l76453: 0.226
#  - pin: 0.552
# 文本 77 的代表性關鍵詞：
#  - cpu: 0.395
#  - hu: 0.206
#  - 撞件: 0.218
#  - 螺絲: 0.530
# 文本 78 的代表性關鍵詞：
#  - cpu: 0.400
#  - p38: 0.212
#  - pin: 0.444
#  - 腳座: 0.627
# 文本 79 的代表性關鍵詞：
#  - m2: 0.576
#  - m81542: 0.219
#  - mj39: 0.224
#  - reno2: 0.216
# 文本 80 的代表性關鍵詞：
#  - aj78: 0.731
#  - p3: 0.564
# 文本 81 的代表性關鍵詞：
#  - cpu: 0.435
#  - p38a: 0.606
#  - pin: 0.363
#  - ppid: 0.284
#  - 產品: 0.327
# 文本 82 的代表性關鍵詞：
#  - cpu: 0.653
#  - pin: 0.218
#  - 機臺: 0.256
#  - 腳座: 0.205
# 文本 83 的代表性關鍵詞：
#  - fio: 0.336
#  - p3f: 0.429
#  - spi: 0.255
#  - v2: 0.311
#  - 生產: 0.216
# 文本 84 的代表性關鍵詞：
#  - a6: 0.204
#  - aoi: 0.221
#  - m44945: 0.210
#  - 作業員: 0.223
#  - 對板: 0.242
#  - 電容: 0.327
# 文本 85 的代表性關鍵詞：
#  - d10a: 0.220
#  - 偏位: 0.329
#  - 拖盤: 0.284
#  - 擦板: 0.238
#  - 時作業: 0.230
#  - 缺件: 0.303
#  - 高三: 0.206
# 文本 86 的代表性關鍵詞：
#  - d05: 0.214
#  - matira5: 0.232
#  - 動作: 0.246
#  - 板邊: 0.674
#  - 連片: 0.247
# 文本 87 的代表性關鍵詞：
#  - aoi: 0.247
#  - d09: 0.224
#  - dy62r: 0.267
#  - pin: 0.328
#  - wlan: 0.249
#  - 數量: 0.236
#  - 更換: 0.361
# 文本 88 的代表性關鍵詞：
#  - d09: 0.270
#  - dy62r: 0.322
#  - pin: 0.395
#  - 數量: 0.284
#  - 更換: 0.290
#  - 消失: 0.236
#  - 焊點: 0.204
# 文本 89 的代表性關鍵詞：
#  - fbt: 0.239
#  - mac: 0.306
#  - pin: 0.229
#  - 塑膠: 0.390
#  - 排針: 0.200
#  - 探針: 0.247
#  - 板角: 0.257
#  - 破損: 0.327
#  - 零件: 0.221
# 文本 90 的代表性關鍵詞：
#  - aud: 0.406
#  - j39: 0.550
#  - joffrey: 0.406
#  - l76453: 0.216
#  - p35: 0.212
#  - 空焊: 0.215
# 文本 91 的代表性關鍵詞：
#  - pin: 0.250
#  - 機臺: 0.391
# 文本 92 的代表性關鍵詞：
#  - fbt: 0.632
#  - m10314: 0.242
#  - p33b: 0.207
#  - sierra: 0.227
#  - 插拔: 0.214
# 文本 93 的代表性關鍵詞：
#  - cpu: 0.326
#  - l76450: 0.287
#  - p37a: 0.281
#  - socket: 0.266
#  - tywin: 0.254
#  - uf: 0.252
#  - 偏位: 0.290
#  - 濾波: 0.306
# 文本 94 的代表性關鍵詞：
#  - d05: 0.286
#  - pin: 0.412
#  - sorting: 0.336
#  - 上料: 0.249
#  - 上料員: 0.272
# 文本 95 的代表性關鍵詞：
#  - cpu0: 0.229
#  - driver: 0.203
#  - joffrey: 0.213
#  - p35: 0.223
#  - pn: 0.331
#  - pu210: 0.236
#  - short: 0.387
#  - 電壓: 0.295
# 文本 96 的代表性關鍵詞：
#  - j41: 0.685
#  - 空焊: 0.421
# 文本 97 的代表性關鍵詞：
#  - m10197: 0.209
#  - p31a: 0.205
#  - usb: 0.268
#  - 外殼: 0.215
#  - 板角: 0.214
#  - 破損: 0.273
#  - 網絡: 0.411
#  - 零件: 0.277
#  - 電感: 0.493
# 文本 98 的代表性關鍵詞：
#  - k5c: 0.387
#  - 偏位: 0.264
#  - 刮刀: 0.442
#  - 單片: 0.202
#  - 電感: 0.426
# 文本 99 的代表性關鍵詞：
#  - aoi: 0.209
#  - 偏位: 0.393
#  - 濾波: 0.207
#  - 電容: 0.205
# 文本 100 的代表性關鍵詞：
#  - d04: 0.331
#  - j76: 0.649
#  - repair: 0.235
#  - 泛一: 0.229
#  - 貼裝: 0.237
# 文本 101 的代表性關鍵詞：
#  - aoi: 0.551
#  - d08: 0.236
#  - ict: 0.205
#  - repair: 0.206
#  - 偏位: 0.260
#  - 吸料位置: 0.424
#  - 跑偏: 0.260
#  - 高一: 0.220
# 文本 102 的代表性關鍵詞：
#  - cpu1: 0.520
#  - eldorado: 0.251
#  - pin: 0.220
#  - 異常: 0.264
#  - 程度: 0.249
#  - 電壓: 0.527
#  - 電量: 0.244
# 文本 103 的代表性關鍵詞：
#  - hu: 0.406
#  - p31: 0.265
#  - pe: 0.390
#  - 散熱片: 0.286
#  - 模組: 0.380
#  - 機台: 0.291
#  - 生產品質: 0.401
#  - 重影: 0.227
# 文本 104 的代表性關鍵詞：
#  - aoi: 0.216
#  - kent6: 0.420
#  - l75370: 0.420
#  - p3a: 0.423
#  - 不良板: 0.229
# 文本 105 的代表性關鍵詞：
#  - d04: 0.308
#  - 短路: 0.500
#  - 錫膏: 0.213
#  - 鏈速: 0.300
# 文本 106 的代表性關鍵詞：
#  - con: 0.428
#  - d10b: 0.438
#  - 插件機: 0.436
#  - 電容: 0.294
# 文本 107 的代表性關鍵詞：
#  - reno2: 0.449
# 文本 108 的代表性關鍵詞：
#  - d08: 0.241
#  - x0y8: 0.619
#  - 吸嘴: 0.398
#  - 殘錫: 0.212
#  - 缺件: 0.366
#  - 電阻: 0.217
# 文本 109 的代表性關鍵詞：
#  - d10a: 0.428
#  - widowmaker: 0.236
#  - 插件機: 0.331
#  - 電容: 0.335
# 文本 110 的代表性關鍵詞：
#  - d09: 0.232
#  - dy62r: 0.276
#  - sorting: 0.276
#  - usb: 0.317
#  - 原物料: 0.321
#  - 變形: 0.351
# 文本 111 的代表性關鍵詞：
#  - cpu: 0.391
#  - ict: 0.274
# 文本 112 的代表性關鍵詞：
#  - pin: 0.254
#  - wlan: 0.288
#  - 機臺: 0.298
# 文本 113 的代表性關鍵詞：
#  - type: 0.324
#  - 識別: 0.220
# 文本 114 的代表性關鍵詞：
#  - 堆板: 0.375
#  - 投板: 0.582
# 文本 115 的代表性關鍵詞：
#  - fbt: 0.239
#  - m10197: 0.250
#  - p31a: 0.246
#  - trinidad: 0.229
#  - 零件: 0.664
# 文本 116 的代表性關鍵詞：
#  - cres: 0.211
#  - d04: 0.675
#  - 撞件: 0.252
# 文本 117 的代表性關鍵詞：
#  - s34: 0.691
#  - 偏位: 0.308
#  - 目檢: 0.237
# 文本 118 的代表性關鍵詞：
#  - j8: 0.640
#  - type: 0.495
# 文本 119 的代表性關鍵詞：
#  - aud: 0.256
#  - nut2: 0.591
#  - p3d: 0.266
#  - tywin: 0.207
#  - 吸嘴: 0.354
#  - 螺柱: 0.473
# 文本 120 的代表性關鍵詞：
#  - p3a: 0.511
#  - 品質: 0.332
#  - 背板: 0.437
#  - 隱患: 0.471
# 文本 121 的代表性關鍵詞：
#  - j31: 0.593
#  - juki插件機: 0.255
#  - l76450: 0.241
#  - pin: 0.228
#  - tywin: 0.213
#  - 折腳: 0.275
# 文本 122 的代表性關鍵詞：
#  - j39: 0.496
#  - j40: 0.628
#  - trinidad: 0.316
# 文本 123 的代表性關鍵詞：
#  - p6: 0.410
#  - pcb: 0.364
#  - 排針: 0.263
#  - 白色: 0.281
#  - 載具: 0.271
# 文本 124 的代表性關鍵詞：
#  - aud: 0.578
#  - nut2: 0.667
#  - 偏位: 0.266
#  - 目檢: 0.204
# 文本 125 的代表性關鍵詞：
#  - ict: 0.226
#  - m81592: 0.445
#  - scrabble: 0.441
#  - xu1: 0.533
# 文本 126 的代表性關鍵詞：
#  - m2: 0.388
#  - m81542: 0.221
#  - mj39: 0.453
#  - reno2: 0.218
#  - 塑膠: 0.313
#  - 時作業: 0.205
#  - 破損: 0.262
# 文本 127 的代表性關鍵詞：
#  - aoi: 0.295
#  - m81542: 0.315
#  - p37a: 0.270
#  - reno2: 0.311
#  - uf: 0.242
#  - 電容: 0.436
# 文本 128 的代表性關鍵詞：
#  - d12: 0.296
#  - dimm2: 0.483
#  - mtx: 0.336
#  - n0992: 0.530
#  - rota: 0.389
# 文本 129 的代表性關鍵詞：
#  - d08: 0.245
#  - d11: 0.239
#  - freeport: 0.250
#  - x0y8: 0.314
#  - 上料: 0.228
#  - 上料員: 0.249
#  - 泛用機: 0.296
# 文本 130 的代表性關鍵詞：
#  - d07: 0.242
#  - usb: 0.530
#  - 插件機: 0.208
#  - 目檢: 0.207
# 文本 131 的代表性關鍵詞：
#  - aoi: 0.252
#  - m81600: 0.222
#  - s34: 0.266
#  - 撞件: 0.444
#  - 網絡: 0.239
#  - 電容: 0.248
# 文本 132 的代表性關鍵詞：
#  - s34: 0.214
#  - 電容: 0.298
# 文本 133 的代表性關鍵詞：
#  - buffalo: 0.208
#  - x0y8: 0.244
#  - 腳座: 0.369
#  - 零件: 0.378
#  - 電池: 0.420
# 文本 134 的代表性關鍵詞：
#  - 彈片: 0.274
#  - 池座: 0.463
#  - 電池: 0.769
# 文本 135 的代表性關鍵詞：
#  - aoi: 0.211
#  - int: 0.499
#  - sfc: 0.222
#  - x0y8: 0.232
#  - 全圖: 0.205
#  - 堆板: 0.204
#  - 破損: 0.267
# 文本 136 的代表性關鍵詞：
#  - 識別: 0.476
# 文本 137 的代表性關鍵詞：
#  - 塑膠: 0.264
#  - 插卡: 0.202
#  - 破損: 0.554
#  - 零件: 0.299
# 文本 138 的代表性關鍵詞：
#  - 工具: 0.307
#  - 空焊: 0.487
#  - 變形: 0.205
#  - 載具: 0.239
# 文本 139 的代表性關鍵詞：
#  - p152: 0.366
#  - pin: 0.596
#  - 膠紙: 0.315
# 文本 140 的代表性關鍵詞：
#  - aoi: 0.553
#  - d10a: 0.209
#  - feeder: 0.472
#  - 反白: 0.384
#  - 技能: 0.223
#  - 時點: 0.216
# 文本 141 的代表性關鍵詞：
#  - dali: 0.345
#  - dimm: 0.224
#  - fbt: 0.291
#  - p34b: 0.286
#  - 投板: 0.316
#  - 貼裝: 0.238
#  - 電容: 0.310
# 文本 142 的代表性關鍵詞：
#  - dali: 0.329
#  - hh: 0.211
#  - mfr: 0.243
#  - p34a: 0.286
#  - pca: 0.601
#  - 漏銅: 0.333
# 文本 143 的代表性關鍵詞：
#  - smt: 0.345
#  - 殘件: 0.620
#  - 設備貼裝: 0.251
#  - 電阻: 0.240
# 文本 144 的代表性關鍵詞：
#  - kent6: 0.523
#  - l75370: 0.523
#  - 偏位: 0.253
#  - 爐前: 0.302
#  - 零件: 0.229
# 文本 145 的代表性關鍵詞：
#  - eldorado: 0.570
#  - ict: 0.210
#  - p32: 0.372
#  - v2: 0.447
# 文本 146 的代表性關鍵詞：
#  - d05: 0.259
#  - dell: 0.326
#  - k5c: 0.292
#  - 噴霧: 0.294
#  - 排針: 0.217
#  - 流量: 0.263
#  - 零件: 0.240
# 文本 147 的代表性關鍵詞：
#  - cpu: 0.263
#  - m81542: 0.528
#  - reno2: 0.520
# 文本 148 的代表性關鍵詞：
#  - ids: 0.296
#  - p34a: 0.264
#  - 偏位: 0.522
# 文本 149 的代表性關鍵詞：
#  - p38: 0.210
#  - pu100: 0.540
#  - 偏位: 0.469
#  - 貼裝頭: 0.497
# 文本 150 的代表性關鍵詞：
#  - p72: 0.779
#  - 殘件: 0.514
# 文本 151 的代表性關鍵詞：
#  - d09: 0.429
#  - d10: 0.475
#  - dy62r: 0.510
#  - sff: 0.248
#  - 破損: 0.298
# 文本 152 的代表性關鍵詞：
#  - 0402電容: 0.231
#  - j91: 0.320
#  - pin: 0.334
#  - usb: 0.560
# 文本 153 的代表性關鍵詞：
#  - p34: 0.263
#  - team: 0.363
#  - type: 0.299
#  - 重影: 0.228
# 文本 154 的代表性關鍵詞：
#  - dimm: 0.714
#  - 短路: 0.317
#  - 錫膏: 0.243
# 文本 155 的代表性關鍵詞：
#  - a8: 0.245
#  - m86365: 0.246
#  - p36b: 0.205
#  - 包裝: 0.347
#  - 彈片: 0.478
#  - 變形: 0.324
# 文本 156 的代表性關鍵詞：
#  - fio: 0.229
#  - j90: 0.546
#  - p3f: 0.292
#  - usb: 0.331
#  - 焊點: 0.367
# 文本 157 的代表性關鍵詞：
#  - d10a: 0.299
#  - 目檢: 0.229
#  - 螺絲: 0.452
# 文本 158 的代表性關鍵詞：
#  - 刮刀: 0.339
# 文本 159 的代表性關鍵詞：
#  - hu: 0.214
#  - ng: 0.208
#  - pe: 0.205
#  - 破損: 0.487
#  - 電感: 0.440
# 文本 160 的代表性關鍵詞：
#  - 0402電容: 0.218
#  - fbt: 0.262
#  - m81542: 0.304
#  - p33a: 0.253
#  - reno2: 0.299
#  - smt: 0.210
#  - 插件機: 0.207
#  - 板作業: 0.238
#  - 自動: 0.258
# 文本 161 的代表性關鍵詞：
#  - lot: 0.220
#  - supplier: 0.313
#  - usb: 0.470
#  - 電壓: 0.268
# 文本 162 的代表性關鍵詞：
#  - d10b: 0.305
#  - d11: 0.291
#  - option2: 0.357
#  - pin: 0.308
#  - 固定: 0.262
#  - 空焊: 0.377
# 文本 163 的代表性關鍵詞：
#  - d07: 0.315
#  - d10: 0.374
#  - dimm: 0.264
#  - dimm1: 0.326
#  - 引腳: 0.279
#  - 焊點: 0.256
#  - 目視: 0.204
# 文本 164 的代表性關鍵詞：
#  - cpu: 0.435
#  - mac: 0.580
#  - pin: 0.435
# 文本 165 的代表性關鍵詞：
#  - dimm: 0.374
#  - dimm4: 0.381
#  - 插件機: 0.384
#  - 異常: 0.248
# 文本 166 的代表性關鍵詞：
#  - p33b: 0.223
#  - 塑膠: 0.373
#  - 破損: 0.624
#  - 零件: 0.316
# 文本 167 的代表性關鍵詞：
#  - d10a: 0.275
#  - dimm1: 0.382
#  - tray: 0.305
#  - 異常: 0.360
# 文本 168 的代表性關鍵詞：
#  - d07: 0.412
#  - wlan: 0.490
#  - 堆板: 0.471
#  - 插拔: 0.454
#  - 處理: 0.203
# 文本 169 的代表性關鍵詞：
#  - feeder: 0.427
#  - p36: 0.205
#  - 供料不穩: 0.260
#  - 電感: 0.685
# 文本 170 的代表性關鍵詞：
#  - 保養: 0.422
#  - 螺絲孔: 0.459
#  - 錫珠: 0.217
# 文本 171 的代表性關鍵詞：
#  - p3a: 0.212
#  - usb: 0.268
#  - 彈片: 0.439
#  - 投板: 0.217
#  - 舌片: 0.439
#  - 變形: 0.297
# 文本 172 的代表性關鍵詞：
#  - kent5: 0.283
#  - p3a: 0.312
#  - 原物料: 0.200
#  - 品質: 0.203
#  - 板子: 0.255
#  - 機打: 0.262
#  - 異常: 0.451
#  - 隱患: 0.288
#  - 電容: 0.470
# 文本 173 的代表性關鍵詞：
#  - 插件機: 0.233
#  - 機打: 0.262
#  - 設計: 0.321
#  - 電容: 0.471
# 文本 174 的代表性關鍵詞：
#  - d08: 0.323
#  - dy62r: 0.407
#  - 保養: 0.352
#  - 缺件: 0.491
# 文本 175 的代表性關鍵詞：
#  - type: 0.426
#  - 漏點: 0.805
# 文本 176 的代表性關鍵詞：
#  - d10: 0.223
#  - d10a: 0.210
#  - 散熱片: 0.346
#  - 膠紙: 0.622
# 文本 177 的代表性關鍵詞：
#  - 0402電容: 0.210
#  - sb20n61337: 0.229
#  - smt: 0.304
#  - 維修: 0.252
# 文本 178 的代表性關鍵詞：
#  - dy62r: 0.426
#  - 擦板: 0.202
#  - 皮帶: 0.219
#  - 缺件: 0.386
# 文本 179 的代表性關鍵詞：
#  - d08: 0.207
#  - 機臺: 0.251
#  - 蓋子: 0.549
#  - 表面: 0.236
# 文本 180 的代表性關鍵詞：
#  - vi: 0.303
#  - 偏位: 0.623
#  - 貼裝: 0.249
#  - 電阻: 0.254
# 文本 181 的代表性關鍵詞：
#  - p3d: 0.745
#  - 上料員: 0.613
# 文本 182 的代表性關鍵詞：
#  - fg47g: 0.237
#  - 螺絲: 0.486
#  - 鐵件: 0.206
# 文本 183 的代表性關鍵詞：
#  - kj166: 0.393
#  - sd: 0.777
# 文本 184 的代表性關鍵詞：
#  - intel: 0.725
#  - usb: 0.403
# 文本 185 的代表性關鍵詞：
#  - d10a: 0.303
#  - pin: 0.284
#  - ssd: 0.298
#  - 機臺: 0.418
# 文本 186 的代表性關鍵詞：
#  - e49: 0.564
#  - 吸料: 0.242
#  - 排針: 0.536
#  - 空間: 0.228
#  - 缺件: 0.301
#  - 進料: 0.240
# 文本 187 的代表性關鍵詞：
#  - groot3: 0.465
#  - team: 0.241
#  - 偏位: 0.345
#  - 吸料位置: 0.375
#  - 料位跑偏: 0.257
#  - 高五: 0.209
# 文本 188 的代表性關鍵詞：
#  - feeder: 0.334
#  - m10197: 0.226
#  - s31: 0.234
#  - trinidad: 0.207
#  - y5: 0.580
#  - 供料不穩: 0.203
#  - 反白: 0.408
#  - 時點: 0.229
# 文本 189 的代表性關鍵詞：
#  - fan: 0.204
#  - vendor: 0.280
# 文本 190 的代表性關鍵詞：
#  - p3c: 0.309
#  - 不良板: 0.239
#  - 腳座: 0.251
#  - 花板: 0.284
#  - 軌道: 0.239
#  - 錫膏: 0.437
#  - 高一: 0.241
# 文本 191 的代表性關鍵詞：
#  - m09983: 0.384
#  - pike: 0.376
#  - s31: 0.435
#  - team: 0.432
#  - 偏位: 0.206
#  - 效率: 0.326
#  - 重影: 0.271
# 文本 192 的代表性關鍵詞：
#  - r6pct: 0.208
#  - 漏貼: 0.713
# 文本 193 的代表性關鍵詞：
#  - 受力: 0.396
#  - 空焊: 0.591
#  - 電阻: 0.504
# 文本 194 的代表性關鍵詞：
#  - 料槽: 0.760
# 文本 195 的代表性關鍵詞：
#  - d04: 0.314
#  - m81592: 0.219
#  - pin: 0.264
#  - repair: 0.224
#  - xu1: 0.262
#  - 幹部: 0.316
#  - 機臺: 0.311
#  - 異常: 0.211
#  - 腳座: 0.249
# 文本 196 的代表性關鍵詞：
#  - p1: 0.262
#  - 壓塊: 0.310
#  - 機台: 0.312
#  - 間距: 0.406
# 文本 197 的代表性關鍵詞：
#  - pin: 0.261
#  - short: 0.365
#  - vcore: 0.252
#  - 燒板: 0.437
#  - 空焊: 0.480
#  - 電壓: 0.209
# 文本 198 的代表性關鍵詞：
#  - aj76: 0.694
#  - open: 0.269
#  - 線量: 0.284
# 文本 199 的代表性關鍵詞：
#  - d07: 0.202
#  - pin: 0.211
#  - sff3: 0.254
#  - wlan: 0.240
#  - 撞件: 0.281
# 文本 200 的代表性關鍵詞：
#  - d11: 0.253
#  - esd: 0.280
#  - pqe: 0.273
#  - u1: 0.650
#  - 燒錄: 0.475
# 文本 201 的代表性關鍵詞：
#  - 吸嘴: 0.225
#  - 板面: 0.493
#  - 電容: 0.391
# 文本 202 的代表性關鍵詞：
#  - cr14: 0.617
#  - cr15: 0.313
#  - d09: 0.227
#  - 偏位: 0.353
#  - 時點: 0.244
#  - 設備貼裝: 0.201
# 文本 203 的代表性關鍵詞：
#  - pin: 0.200
#  - pwr: 0.201
#  - sw: 0.244
#  - 撞件: 0.266
#  - 流水: 0.227
#  - 程式: 0.232
# 文本 204 的代表性關鍵詞：
#  - j94: 0.486
#  - p3d: 0.523
#  - tywin: 0.407
#  - vi: 0.451
# 文本 205 的代表性關鍵詞：
#  - ee: 0.257
#  - m09983: 0.283
#  - p31b: 0.295
#  - pike: 0.277
#  - vi: 0.295
#  - 電阻: 0.248
#  - 高一: 0.257
# 文本 206 的代表性關鍵詞：
#  - 料槽: 0.650
# 文本 207 的代表性關鍵詞：
#  - ict: 0.275
#  - p33a: 0.218
#  - 板邊: 0.356
#  - 濾波: 0.244
#  - 背板: 0.206
#  - 電容: 0.483
# 文本 208 的代表性關鍵詞：
#  - cpu: 0.251
#  - pin: 0.313
#  - xu1: 0.414
#  - 腳座: 0.393
# 文本 209 的代表性關鍵詞：
#  - p33a: 0.246
#  - twr: 0.215
#  - uf: 0.227
#  - z2: 0.209
#  - 掉落: 0.232
#  - 插件機: 0.202
#  - 機打: 0.227
#  - 零件: 0.354
#  - 電容: 0.273
# 文本 210 的代表性關鍵詞：
#  - cpu: 0.270
#  - d05: 0.234
#  - fan: 0.530
#  - jwjy: 0.270
#  - pin: 0.225
#  - 機臺: 0.265
#  - 端子: 0.286
# 文本 211 的代表性關鍵詞：
#  - aoi: 0.207
#  - 檢測: 0.206
#  - 短路: 0.587
#  - 鋼網: 0.449
#  - 電容: 0.305
# 文本 212 的代表性關鍵詞：
#  - aoi: 0.266
#  - d08: 0.456
#  - pin: 0.471
#  - ssd: 0.247
#  - 插卡: 0.306
#  - 插拔: 0.248
# 文本 213 的代表性關鍵詞：
#  - aoi: 0.202
#  - nf: 0.428
#  - pcb: 0.216
#  - 容值: 0.211
#  - 機臺: 0.210
#  - 電容: 0.496
# 文本 214 的代表性關鍵詞：
#  - d05: 0.337
#  - k5c: 0.380
#  - 螺絲: 0.523
#  - 鐵件: 0.333
# 文本 215 的代表性關鍵詞：
#  - n0992: 0.220
#  - 吸嘴: 0.301
#  - 殘留: 0.304
#  - 缺件: 0.416
#  - 膠紙: 0.398
# 文本 216 的代表性關鍵詞：
#  - controller: 0.227
#  - cpu: 0.537
#  - dsw: 0.349
#  - x0y8: 0.222
#  - 偏位: 0.286
#  - 圖片: 0.214
#  - 電流: 0.208
# 文本 217 的代表性關鍵詞：
#  - label: 0.581
#  - 漏貼: 0.544
#  - 網絡: 0.317
# 文本 218 的代表性關鍵詞：
#  - buffalo: 0.232
#  - d08: 0.212
#  - d11: 0.207
#  - rt: 0.260
#  - x0y8: 0.272
#  - 螺絲: 0.705
#  - 鐵件: 0.224
# 文本 219 的代表性關鍵詞：
#  - dimm2: 0.239
#  - 投板: 0.254
#  - 撞件: 0.299
#  - 時作業: 0.251
#  - 殘留: 0.363
#  - 端板: 0.307
#  - 貼片: 0.201
#  - 軌道: 0.202
#  - 零件: 0.216
# 文本 220 的代表性關鍵詞：
#  - cpu: 0.322
#  - ict: 0.226
#  - scrabble: 0.440
# 文本 221 的代表性關鍵詞：
#  - groot3: 0.401
#  - m99498: 0.406
#  - p3c: 0.432
#  - pcb: 0.225
#  - 燒板: 0.311
# 文本 222 的代表性關鍵詞：
#  - card1: 0.353
#  - sd: 0.683
#  - 變形: 0.304
# 文本 223 的代表性關鍵詞：
#  - feeder: 0.534
#  - kent5: 0.222
#  - m98850: 0.230
#  - 保養: 0.234
#  - 偏位: 0.236
#  - 反白: 0.435
#  - 更換: 0.244
#  - 高四: 0.212
# 文本 224 的代表性關鍵詞：
#  - type: 0.505
# 文本 225 的代表性關鍵詞：
#  - d10a: 0.283
#  - dolphin: 0.234
#  - feeder: 0.426
#  - hd: 0.334
#  - 供料不穩: 0.259
#  - 缺件: 0.390
# 文本 226 的代表性關鍵詞：
#  - m2: 0.536
#  - p38: 0.484
#  - sb20n61337: 0.478
#  - 空焊: 0.310
# 文本 227 的代表性關鍵詞：
#  - d05: 0.236
#  - fio: 0.220
#  - matira35: 0.266
#  - sop: 0.240
#  - 爐前: 0.288
# 文本 228 的代表性關鍵詞：
#  - m81542: 0.268
#  - reno2: 0.264
#  - vj69: 0.594
# 文本 229 的代表性關鍵詞：
#  - a6: 0.472
#  - er: 0.420
#  - ic: 0.252
#  - m44945: 0.484
#  - p36a: 0.435
#  - 產品: 0.204
# 文本 230 的代表性關鍵詞：
#  - con: 0.283
#  - d08: 0.452
#  - on: 0.224
#  - x0y8: 0.290
#  - 上料員: 0.230
#  - 封裝: 0.298
#  - 電容: 0.389
# 文本 231 的代表性關鍵詞：
#  - s33: 0.607
#  - smt: 0.215
#  - twr: 0.452
#  - z2: 0.440
#  - 偏位: 0.275
# 文本 232 的代表性關鍵詞：
#  - feeder: 0.550
#  - sb20n61335: 0.212
#  - 供料不穩: 0.447
#  - 反白: 0.448
# 文本 233 的代表性關鍵詞：
#  - l76450: 0.276
#  - p37: 0.214
#  - pin: 0.261
#  - tywin: 0.244
#  - 排針: 0.684
# 文本 234 的代表性關鍵詞：
#  - l76450: 0.323
#  - p1: 0.345
#  - p37a: 0.316
#  - tywin: 0.286
#  - 維修: 0.316
#  - 腳座: 0.288
#  - 電源: 0.327
# 文本 235 的代表性關鍵詞：
#  - 壓件: 0.487
#  - 電壓: 0.341
# 文本 236 的代表性關鍵詞：
#  - dmyn9: 0.331
#  - sfc: 0.314
# 文本 237 的代表性關鍵詞：
#  - aoi: 0.272
#  - d05: 0.250
#  - jwjy: 0.288
#  - 異常: 0.288
#  - 短路: 0.463
# 文本 238 的代表性關鍵詞：
#  - d08: 0.218
#  - x0y8: 0.559
#  - 速度: 0.239
#  - 電感: 0.579
# 文本 239 的代表性關鍵詞：
#  - buffalo: 0.260
#  - d09: 0.252
#  - d11: 0.232
#  - fxd80: 0.287
#  - up: 0.222
#  - usb3s3: 0.554
#  - 打膠: 0.293
#  - 紙板: 0.284
#  - 貼裝坐標: 0.206
# 文本 240 的代表性關鍵詞：
#  - pcb: 0.344
#  - r6pct: 0.203
#  - 線路: 0.497
# 文本 241 的代表性關鍵詞：
#  - d10a: 0.202
#  - r1: 0.470
#  - usb: 0.265
#  - 殘留: 0.305
#  - 鑷子: 0.231
# 文本 242 的代表性關鍵詞：
#  - pn: 0.211
#  - u100: 0.658
# 文本 243 的代表性關鍵詞：
#  - aud: 0.488
#  - cersei: 0.502
#  - hp: 0.384
#  - p34: 0.341
#  - 燒板: 0.353
# 文本 244 的代表性關鍵詞：
#  - p3d: 0.425
#  - 不良板: 0.212
#  - 板面: 0.413
#  - 棧板: 0.206
# 文本 245 的代表性關鍵詞：
#  - l77195: 0.217
#  - 偏位: 0.367
#  - 貼裝: 0.220
#  - 電容: 0.287
# 文本 246 的代表性關鍵詞：
#  - nut1: 0.608
#  - sb20n61337: 0.219
#  - 吸料位置: 0.201
#  - 螺絲柱: 0.290
#  - 跑偏: 0.247
# 文本 247 的代表性關鍵詞：
#  - d10a: 0.311
#  - mtx: 0.215
#  - r6pct: 0.313
#  - tracer: 0.295
#  - 偏位: 0.311
# 文本 248 的代表性關鍵詞：
#  - bent: 0.242
#  - buffalo: 0.246
#  - cpu: 0.417
#  - d08: 0.224
#  - d11: 0.219
#  - pin: 0.232
#  - x0y8: 0.288
#  - 自動: 0.237
# 文本 249 的代表性關鍵詞：
#  - sb20n61337: 0.209
#  - type: 0.406
# 文本 250 的代表性關鍵詞：
#  - j41: 0.322
#  - joffrey: 0.373
#  - l76453: 0.397
#  - p35b: 0.307
#  - 焊點: 0.251
# 文本 251 的代表性關鍵詞：
#  - aoi: 0.341
#  - d07: 0.289
#  - fio: 0.293
#  - matira35: 0.354
#  - pin: 0.302
#  - 棧板: 0.351
# 文本 252 的代表性關鍵詞：
#  - bent: 0.221
#  - cpu: 0.506
#  - l77195: 0.266
#  - p34a: 0.227
#  - pin: 0.211
#  - 幹部: 0.252
#  - 技能: 0.241
#  - 時作業: 0.235
#  - 邊緣: 0.220
# 文本 253 的代表性關鍵詞：
#  - ee: 0.227
#  - m450c: 0.282
#  - p38b: 0.201
#  - 偏位: 0.268
# 文本 254 的代表性關鍵詞：
#  - d08: 0.209
#  - sfc: 0.256
#  - 電池: 0.692
# 文本 255 的代表性關鍵詞：
#  - 料帶: 0.461
#  - 更換: 0.325
#  - 異常: 0.235
# 文本 256 的代表性關鍵詞：
#  - ec: 0.268
#  - ec1: 0.242
#  - 阻值: 0.319
#  - 電阻: 0.267
# 文本 257 的代表性關鍵詞：
#  - 引腳: 0.387
#  - 識別: 0.569
# 文本 258 的代表性關鍵詞：
#  - m09983: 0.263
#  - p31b: 0.275
#  - pike: 0.258
#  - usb: 0.371
#  - 信號: 0.251
#  - 焊點: 0.206
#  - 維修: 0.274
#  - 零件: 0.383
# 文本 259 的代表性關鍵詞：
#  - d09: 0.213
#  - fxd80: 0.243
#  - option1: 0.527
#  - option2: 0.482
#  - 空焊: 0.255
#  - 貼裝高度: 0.260
# 文本 260 的代表性關鍵詞：
#  - ai: 0.241
#  - input: 0.210
#  - jamie: 0.210
#  - p35: 0.237
#  - 堆板: 0.214
#  - 維修: 0.203
# 文本 261 的代表性關鍵詞：
#  - d10a: 0.305
#  - kyoto: 0.224
#  - 偏位: 0.456
#  - 貼裝: 0.244
# 文本 262 的代表性關鍵詞：
#  - d05: 0.290
#  - matira: 0.286
#  - tvw7j: 0.348
#  - xl: 0.326
#  - 偏位: 0.447
# 文本 263 的代表性關鍵詞：
#  - cersei: 0.236
#  - p34b: 0.203
#  - pch: 0.419
#  - 撞件: 0.264
#  - 散熱片: 0.525
#  - 時作業: 0.222
#  - 零件: 0.287
# 文本 264 的代表性關鍵詞：
#  - j76: 0.672
#  - s31: 0.216
#  - team: 0.214
#  - 跑偏: 0.205
# 文本 265 的代表性關鍵詞：
#  - ict: 0.236
#  - mj39: 0.231
#  - 不良板: 0.224
#  - 撞件: 0.248
#  - 時作業: 0.208
#  - 泡棉: 0.235
#  - 流線: 0.235
#  - 濾波: 0.210
#  - 轉板: 0.227
#  - 零件: 0.270
#  - 電容: 0.208
# 文本 266 的代表性關鍵詞：
#  - 0402電容: 0.270
#  - p38b: 0.250
#  - sb20n61337: 0.295
#  - 偏位: 0.499
#  - 吸嘴: 0.250
# 文本 267 的代表性關鍵詞：
#  - cpu: 0.385
#  - driver: 0.353
#  - dsw: 0.209
#  - pin1: 0.273
#  - pin4: 0.278
#  - s0: 0.205
#  - 信號: 0.303
# 文本 268 的代表性關鍵詞：
#  - b1: 0.256
#  - f1hc1: 0.211
#  - 空焊: 0.245
# 文本 269 的代表性關鍵詞：
#  - f1: 0.383
#  - usb: 0.327
#  - 彈片: 0.357
#  - 插拔: 0.329
# 文本 270 的代表性關鍵詞：
#  - feeder: 0.458
#  - p32: 0.212
#  - sb20t22662: 0.356
#  - 供料不穩: 0.279
#  - 偏位: 0.304
#  - 電阻: 0.248
# 文本 271 的代表性關鍵詞：
#  - d09: 0.243
#  - post: 0.228
#  - ssd: 0.498
# 文本 272 的代表性關鍵詞：
#  - m99498: 0.290
#  - 板邊: 0.218
#  - 機台: 0.239
#  - 殘留: 0.215
#  - 毛刺: 0.305
# 文本 273 的代表性關鍵詞：
#  - d10b: 0.202
#  - n0992: 0.237
#  - open: 0.250
#  - pcb: 0.246
#  - pq: 0.232
#  - 漏銅: 0.254
#  - 覆蓋: 0.245
# 文本 274 的代表性關鍵詞：
#  - nile: 0.588
#  - p32b: 0.482
#  - 產品: 0.214
#  - 螺絲孔: 0.545
# 文本 275 的代表性關鍵詞：
#  - buffalo: 0.301
#  - d11: 0.268
#  - 偏位: 0.605
#  - 電感: 0.244
# 文本 276 的代表性關鍵詞：
#  - jamie: 0.254
#  - p35: 0.286
#  - post: 0.227
#  - 吸料位置: 0.206
# 文本 277 的代表性關鍵詞：
#  - p38: 0.234
#  - sb20n61335: 0.228
#  - type: 0.449
#  - 貼裝坐標: 0.205
# 文本 278 的代表性關鍵詞：
#  - d08: 0.279
#  - ee: 0.260
#  - x0y8: 0.357
#  - 焊點: 0.223
#  - 螺柱: 0.307
#  - 螺絲柱: 0.360
#  - 設備貼裝: 0.262
# 文本 279 的代表性關鍵詞：
#  - power: 0.449
#  - sb20t22670: 0.211
#  - volga: 0.209
#  - 技能: 0.200
#  - 效應: 0.226
#  - 目檢: 0.215
#  - 空焊: 0.215
#  - 腳空: 0.206
#  - 載具: 0.316
#  - 陰影: 0.218
# 文本 280 的代表性關鍵詞：
#  - hd: 0.259
#  - pin: 0.412
#  - ssd: 0.216
#  - troy: 0.230
#  - 整體: 0.221
#  - 機臺: 0.242
#  - 程度: 0.233
# 文本 281 的代表性關鍵詞：
#  - d10a: 0.336
#  - d12: 0.205
#  - f1hc1: 0.332
#  - kyoto: 0.246
#  - 外力: 0.312
#  - 掉落: 0.298
# 文本 282 的代表性關鍵詞：
#  - j39: 0.366
#  - pike: 0.340
#  - v2: 0.313
# 文本 283 的代表性關鍵詞：
#  - m81542: 0.406
#  - reno2: 0.400
#  - s34: 0.201
#  - usb: 0.236
#  - 泛三: 0.212
# 文本 284 的代表性關鍵詞：
#  - 0402電容: 0.242
#  - d07: 0.268
#  - kyoto: 0.219
#  - 偏位: 0.299
#  - 反白: 0.275
#  - 吸嘴: 0.448
#  - 目檢: 0.229
# 文本 285 的代表性關鍵詞：
#  - 板邊: 0.318
#  - 爐前: 0.247
#  - 空焊: 0.477
# 文本 286 的代表性關鍵詞：
#  - pcb: 0.226
#  - 撞件: 0.372
# 文本 287 的代表性關鍵詞：
#  - 固定: 0.242
#  - 空焊: 0.435
# 文本 288 的代表性關鍵詞：
#  - 偏位: 0.396
#  - 短路: 0.478
#  - 鑷子: 0.227
# 文本 289 的代表性關鍵詞：
#  - feeder: 0.472
#  - s31: 0.330
#  - 供料不穩: 0.288
#  - 偏位: 0.313
#  - 高四: 0.281
# 文本 290 的代表性關鍵詞：
#  - s31: 0.388
#  - 偏位: 0.552
#  - 泛二: 0.279
#  - 爐前: 0.219
#  - 零件: 0.332
# 文本 291 的代表性關鍵詞：
#  - m81542: 0.551
#  - reno2: 0.542
#  - 偏位: 0.365
# 文本 292 的代表性關鍵詞：
#  - xc300: 0.508
#  - 撞件: 0.379
#  - 目檢: 0.234
# 文本 293 的代表性關鍵詞：
#  - d09: 0.315
#  - d11: 0.291
#  - fxd80: 0.360
#  - 偏位: 0.328
#  - 貼裝高度: 0.385
# 文本 294 的代表性關鍵詞：
#  - jamie: 0.323
#  - p35b: 0.287
#  - 撞件: 0.402
#  - 板邊: 0.247
#  - 維修: 0.208
#  - 貼片: 0.271
#  - 零件: 0.291
#  - 電容: 0.336
# 文本 295 的代表性關鍵詞：
#  - j39: 0.420
#  - s31: 0.226
#  - ssd: 0.211
#  - team: 0.224
#  - 空焊: 0.246
#  - 貼裝壓力: 0.221
# 文本 296 的代表性關鍵詞：
#  - mb: 0.303
#  - 偏位: 0.288
#  - 泛一: 0.445
#  - 程式: 0.314
#  - 花板: 0.289
#  - 貼裝: 0.231
#  - 貼裝頭: 0.305
# 文本 297 的代表性關鍵詞：
#  - p32: 0.400
#  - sb20t22662: 0.672
#  - smt: 0.224
#  - 偏位: 0.286
#  - 目檢: 0.220
#  - 處理: 0.253
# 文本 298 的代表性關鍵詞：
#  - dc48c: 0.443
#  - ec1: 0.702
#  - qfp: 0.214
# 文本 299 的代表性關鍵詞：
#  - 卡板: 0.361
#  - 回焊爐: 0.359
#  - 板子: 0.353
#  - 爐前: 0.247
#  - 線體: 0.352
#  - 軌道: 0.349
# 文本 300 的代表性關鍵詞：
#  - m86349: 0.388
#  - p3d: 0.440
#  - reno: 0.383
#  - 電感: 0.315
# 文本 301 的代表性關鍵詞：
#  - fbt: 0.226
#  - j8: 0.517
#  - p3d: 0.261
#  - type: 0.399
#  - x3: 0.256
#  - 上線: 0.230
# 文本 302 的代表性關鍵詞：
#  - aoi: 0.283
#  - d08: 0.485
#  - pin: 0.250
#  - x0y8: 0.311
#  - 折腳: 0.302
#  - 板邊: 0.205
#  - 機打: 0.232
# 文本 303 的代表性關鍵詞：
#  - pu900: 0.749
#  - 偏位: 0.390
# 文本 304 的代表性關鍵詞：
#  - f209: 0.240
#  - j94: 0.214
#  - s33: 0.226
#  - twr: 0.336
#  - z2: 0.327
#  - 同廠: 0.227
#  - 泛用機: 0.449
#  - 週期: 0.216
# 文本 305 的代表性關鍵詞：
#  - aoi: 0.368
#  - d09: 0.223
#  - fxd80: 0.254
#  - r1: 0.270
#  - 折腳: 0.262
#  - 機打: 0.201
#  - 程式: 0.252
# 文本 306 的代表性關鍵詞：
#  - smt: 0.220
#  - 偶發性: 0.293
#  - 異常: 0.211
#  - 目檢: 0.216
#  - 貼裝: 0.225
#  - 雙面: 0.296
#  - 電容: 0.440
# 文本 307 的代表性關鍵詞：
#  - xc300: 0.400
#  - 干涉: 0.554
#  - 殘錫: 0.255
#  - 網卡: 0.212
#  - 錫膏: 0.246
# 文本 308 的代表性關鍵詞：
#  - 錯料: 0.642
# 文本 309 的代表性關鍵詞：
#  - cpu: 0.219
#  - d10b: 0.363
#  - fan: 0.430
#  - n0992: 0.426
#  - 原物料: 0.260
#  - 髒污: 0.444
#  - 高工: 0.210
# 文本 310 的代表性關鍵詞：
#  - 目檢: 0.208
#  - 腳長: 0.733
# 文本 311 的代表性關鍵詞：
#  - 空焊: 0.537
# 文本 312 的代表性關鍵詞：
#  - a8: 0.359
#  - er: 0.285
#  - feeder: 0.246
#  - m86365: 0.361
#  - 反白: 0.451
# 文本 313 的代表性關鍵詞：
#  - d10b: 0.220
#  - r6pct: 0.238
#  - tracer: 0.223
#  - 板作業: 0.209
# 文本 314 的代表性關鍵詞：
#  - d07: 0.316
#  - d12: 0.215
#  - kyoto: 0.259
#  - 偏位: 0.528
#  - 設備貼裝: 0.301
#  - 貼裝坐標: 0.277
# 文本 315 的代表性關鍵詞：
# 文本 316 的代表性關鍵詞：
#  - ict: 0.217
#  - m81628: 0.226
#  - oolo: 0.228
#  - p33a: 0.259
#  - 撞件: 0.343
#  - 貼片: 0.231
#  - 零件: 0.373
#  - 電阻: 0.224
# 文本 317 的代表性關鍵詞：
#  - dy62r: 0.219
#  - 殘膠: 0.404
#  - 膠紙: 0.567
#  - 螺柱: 0.382
#  - 螺絲柱: 0.224
# 文本 318 的代表性關鍵詞：
#  - spi: 0.541
#  - 偏位: 0.392
#  - 板子: 0.400
#  - 程式: 0.342
# 文本 319 的代表性關鍵詞：
#  - ib660cx: 0.265
#  - n50s: 0.333
#  - pa: 0.313
#  - pin: 0.300
#  - pin1: 0.255
#  - sb20n61335: 0.372
#  - socket: 0.390
# 文本 320 的代表性關鍵詞：
#  - fio: 0.218
#  - matira35: 0.263
#  - 散料: 0.563
#  - 料盤: 0.255
# 文本 321 的代表性關鍵詞：
#  - nb168: 0.205
#  - 插件機: 0.393
#  - 電容: 0.619
# 文本 322 的代表性關鍵詞：
#  - pn: 0.304
#  - 容值: 0.200
#  - 阻值: 0.527
# 文本 323 的代表性關鍵詞：
#  - d11: 0.563
#  - smt: 0.248
#  - 產品: 0.268
# 文本 324 的代表性關鍵詞：
#  - d04: 0.222
#  - slot1: 0.451
#  - 空焊: 0.229
# 文本 325 的代表性關鍵詞：
#  - fg47g: 0.346
#  - nf: 0.351
#  - 程式: 0.339
#  - 錯料: 0.588
# 文本 326 的代表性關鍵詞：
#  - j73: 0.537
#  - kent6: 0.306
#  - l75370: 0.306
# 文本 327 的代表性關鍵詞：
#  - fbt: 0.240
#  - hdmi: 0.518
#  - 刮刀: 0.206
#  - 壓力: 0.230
#  - 短路: 0.296
# 文本 328 的代表性關鍵詞：
#  - ib660cx: 0.355
#  - ic: 0.298
#  - p38a: 0.446
#  - pa: 0.419
#  - ppid: 0.209
#  - sb20n61337: 0.504
#  - 產品: 0.241
# 文本 329 的代表性關鍵詞：
#  - aj78: 0.346
#  - groot3: 0.285
#  - m99498: 0.288
#  - 電容: 0.294
# 文本 330 的代表性關鍵詞：
#  - dimm: 0.202
#  - dimm1: 0.249
#  - n50s: 0.210
#  - p38b: 0.202
#  - sb20n61335: 0.235
#  - 單根: 0.280
#  - 折腳: 0.304
# 文本 331 的代表性關鍵詞：
#  - j41: 0.263
#  - u100: 0.553
#  - 鋼網: 0.432
# 文本 332 的代表性關鍵詞：
#  - ib660cx: 0.293
#  - j41: 0.440
#  - p38: 0.422
#  - sb20n61336: 0.477
#  - ytm400: 0.447
# 文本 333 的代表性關鍵詞：
#  - u100: 0.808
# 文本 334 的代表性關鍵詞：
#  - domino: 0.359
#  - feeder: 0.284
#  - m81600: 0.352
#  - s33: 0.208
#  - 偏位: 0.282
#  - 花板: 0.565
# 文本 335 的代表性關鍵詞：
#  - a6: 0.222
#  - feeder: 0.342
#  - ic: 0.237
#  - m44945: 0.228
#  - 供料不穩: 0.208
#  - 偏位: 0.567
#  - 貼裝: 0.272
#  - 高四: 0.203
# 文本 336 的代表性關鍵詞：
#  - sb20n61337: 0.207
#  - 外力: 0.218
#  - 板作業: 0.207
#  - 電容: 0.366
# 文本 337 的代表性關鍵詞：
#  - j43: 0.781
#  - s31: 0.221
#  - 爐前: 0.250
# 文本 338 的代表性關鍵詞：
#  - d09: 0.220
#  - d11: 0.203
#  - fxd80: 0.252
#  - option1: 0.545
#  - rt: 0.255
#  - 空焊: 0.263
# 文本 339 的代表性關鍵詞：
#  - aoi: 0.217
#  - 偏位: 0.410
#  - 偏出: 0.208
#  - 技能: 0.220
#  - 整體: 0.206
#  - 目檢: 0.236
#  - 識別: 0.359
# 文本 340 的代表性關鍵詞：
#  - mb: 0.264
#  - p33a: 0.237
#  - 不良板: 0.212
#  - 撞件: 0.471
#  - 濾波: 0.265
#  - 電容: 0.394
# 文本 341 的代表性關鍵詞：
#  - cpu1: 0.597
#  - d07: 0.242
#  - 偏位: 0.269
#  - 固定: 0.215
#  - 掉落: 0.239
#  - 相機: 0.291
#  - 零件: 0.243
# 文本 342 的代表性關鍵詞：
#  - d09: 0.274
#  - fxd80: 0.313
#  - 大圖: 0.251
#  - 鐵件: 0.274
# 文本 343 的代表性關鍵詞：
#  - 條件: 0.266
#  - 雙面: 0.467
#  - 電容: 0.462
# 文本 344 的代表性關鍵詞：
#  - 塑膠: 0.498
#  - 外殼: 0.328
#  - 裂痕: 0.376
#  - 零件: 0.422
#  - 電感: 0.251
# 文本 345 的代表性關鍵詞：
#  - s33: 0.280
#  - 板子: 0.215
# 文本 346 的代表性關鍵詞：
#  - aoi: 0.429
#  - smt: 0.237
#  - 不良板: 0.284
#  - 信號: 0.359
#  - 半成品: 0.241
# 文本 347 的代表性關鍵詞：
#  - joffrey: 0.241
#  - l76453: 0.256
#  - p2: 0.254
#  - pin: 0.312
#  - sorting: 0.254
#  - 白色: 0.389
#  - 電源: 0.444
# 文本 348 的代表性關鍵詞：
#  - a8: 0.285
#  - er: 0.226
#  - feeder: 0.391
#  - usb: 0.341
#  - 吸料位置: 0.211
#  - 貼裝: 0.208
#  - 進料: 0.285
# 文本 349 的代表性關鍵詞：
#  - 容值: 0.403
#  - 流線: 0.214
#  - 電容: 0.284
# 文本 350 的代表性關鍵詞：
#  - ib660cx: 0.278
#  - ic: 0.233
#  - p38a: 0.349
#  - pa: 0.327
#  - sb20n61337: 0.394
#  - xc300: 0.558
#  - 撞件: 0.278
# 文本 351 的代表性關鍵詞：
#  - adl: 0.337
#  - d10b: 0.284
#  - mtx: 0.211
#  - r6pct: 0.307
#  - tracer: 0.289
#  - 擦板: 0.331
#  - 缺件: 0.210
#  - 載具: 0.258
# 文本 352 的代表性關鍵詞：
#  - 燒錄: 0.847
#  - 網絡: 0.307
# 文本 353 的代表性關鍵詞：
#  - 0402電容: 0.306
#  - a8: 0.207
#  - m86365: 0.208
#  - 機臺: 0.208
# 文本 354 的代表性關鍵詞：
#  - mosfet: 0.367
#  - supplier: 0.224
#  - 內存: 0.290
#  - 短路: 0.462
#  - 電壓: 0.383
# 文本 355 的代表性關鍵詞：
#  - s33: 0.344
#  - 偏位: 0.468
#  - 泛一: 0.241
#  - 貼裝頭: 0.330
# 文本 356 的代表性關鍵詞：
#  - p3f: 0.378
#  - 主板: 0.381
#  - 撞件: 0.203
#  - 板邊: 0.250
#  - 泡棉: 0.386
# 文本 357 的代表性關鍵詞：
#  - l77195: 0.384
#  - tywin: 0.285
#  - y5: 0.638
#  - 反白: 0.448
# 文本 358 的代表性關鍵詞：
#  - aoi: 0.324
#  - f1hc1: 0.201
#  - 偏位: 0.305
#  - 全圖: 0.209
#  - 貼裝: 0.244
# 文本 359 的代表性關鍵詞：
#  - d07: 0.241
#  - dc48c: 0.281
#  - ee: 0.227
#  - 不良板: 0.226
#  - 端板: 0.344
# 文本 360 的代表性關鍵詞：
#  - 0402電容: 0.200
#  - input: 0.249
#  - jamie: 0.248
#  - l76451: 0.269
#  - p35: 0.280
#  - 偏出: 0.251
#  - 堆板: 0.253
#  - 投板: 0.262
#  - 零件: 0.223
# 文本 361 的代表性關鍵詞：
#  - m2: 0.223
#  - matira: 0.215
#  - u1: 0.511
#  - 生產: 0.262
#  - 短路: 0.270
#  - 空焊: 0.387
# 文本 362 的代表性關鍵詞：
#  - alw: 0.200
#  - short: 0.318
#  - 壓件: 0.519
#  - 燒板: 0.253
#  - 電壓: 0.363
# 文本 363 的代表性關鍵詞：
#  - pcb: 0.217
#  - smt: 0.299
#  - 空焊: 0.329
#  - 貼裝: 0.229
#  - 雙面: 0.201
# 文本 364 的代表性關鍵詞：
#  - d08: 0.381
#  - d10: 0.447
#  - dp1: 0.463
#  - mlk: 0.354
#  - sff: 0.233
# 文本 365 的代表性關鍵詞：
#  - m2: 0.248
#  - matira: 0.240
#  - u1: 0.568
#  - 生產: 0.291
#  - 短路: 0.301
#  - 空焊: 0.287
# 文本 366 的代表性關鍵詞：
#  - 機臺: 0.215
# 文本 367 的代表性關鍵詞：
#  - d05: 0.316
#  - 擦板: 0.351
#  - 螺絲: 0.245
#  - 螺絲孔: 0.349
#  - 鋼板: 0.353
# 文本 368 的代表性關鍵詞：
#  - cpu: 0.248
#  - driver: 0.546
#  - mosfet: 0.253
#  - on: 0.397
#  - pin1: 0.211
#  - pin4: 0.322
#  - side: 0.273
# 文本 369 的代表性關鍵詞：
#  - ict: 0.286
#  - j91: 0.272
#  - kent6: 0.250
#  - l75370: 0.250
#  - 撞件: 0.301
#  - 板角: 0.254
#  - 自動化: 0.270
#  - 零件: 0.328
# 文本 370 的代表性關鍵詞：
#  - d07: 0.501
#  - dc48c: 0.586
#  - ppid: 0.205
# 文本 371 的代表性關鍵詞：
#  - eldorado: 0.271
#  - m10315: 0.284
#  - pq650: 0.617
#  - 反白: 0.466
#  - 識別: 0.222
# 文本 372 的代表性關鍵詞：
#  - aud: 0.549
#  - j39: 0.496
#  - p35: 0.573
# 文本 373 的代表性關鍵詞：
#  - d07: 0.252
#  - front: 0.332
#  - tc: 0.345
#  - touch: 0.241
#  - up: 0.238
#  - 異常: 0.210
# 文本 374 的代表性關鍵詞：
#  - cersei: 0.321
#  - ee: 0.244
#  - p34b: 0.277
#  - 偶發性: 0.300
#  - 微鏡: 0.228
#  - 電容: 0.300
# 文本 375 的代表性關鍵詞：
#  - au14: 0.646
#  - l75370: 0.527
#  - 偏位: 0.255
#  - 短路: 0.308
# 文本 376 的代表性關鍵詞：
#  - d08: 0.318
#  - 流線: 0.206
#  - 螺絲孔: 0.752
# 文本 377 的代表性關鍵詞：
#  - d10a: 0.210
#  - pwr: 0.396
#  - sw1: 0.520
#  - wxmx: 0.223
#  - 塑膠: 0.335
#  - 破損: 0.421
# 文本 378 的代表性關鍵詞：
#  - jonhon: 0.312
#  - p3: 0.504
#  - sop: 0.296
#  - 極性: 0.346
# 文本 379 的代表性關鍵詞：
#  - 0402電容: 0.219
#  - a6: 0.264
#  - er: 0.235
#  - m44945: 0.271
#  - p36b: 0.248
#  - 偏位: 0.269
#  - 偏出: 0.274
#  - 機臺: 0.298
#  - 線路: 0.221
#  - 貼裝: 0.216
#  - 高一: 0.228
# 文本 380 的代表性關鍵詞：
#  - 0402電容: 0.240
#  - sorting: 0.339
#  - 堆板: 0.304
#  - 掉落: 0.263
#  - 撞件: 0.554
# 文本 381 的代表性關鍵詞：
#  - pn: 0.287
#  - short: 0.224
#  - vccia1: 0.406
#  - vin: 0.322
#  - 不良板: 0.240
#  - 電壓: 0.384
# 文本 382 的代表性關鍵詞：
#  - au14: 0.748
#  - kent6: 0.203
#  - l75370: 0.203
#  - 偏位: 0.394
# 文本 383 的代表性關鍵詞：
#  - feeder: 0.540
#  - vi: 0.348
#  - 供料不穩: 0.329
#  - 電容: 0.374
# 文本 384 的代表性關鍵詞：
#  - l76450: 0.370
#  - tywin: 0.328
#  - 焊點: 0.544
# 文本 385 的代表性關鍵詞：
#  - dc48c: 0.456
#  - ec1: 0.723
#  - qfp: 0.220
# 文本 386 的代表性關鍵詞：
#  - feeder: 0.417
#  - n50s: 0.217
#  - p38: 0.248
#  - p38a: 0.217
#  - pa: 0.203
#  - sb20n61335: 0.242
#  - 供料不穩: 0.254
#  - 反白: 0.509
# 文本 387 的代表性關鍵詞：
#  - j8: 0.657
#  - m86349: 0.292
#  - pin: 0.276
#  - reno: 0.289
#  - 光板: 0.256
#  - 固定: 0.236
# 文本 388 的代表性關鍵詞：
#  - dimm: 0.234
#  - dimm4: 0.358
#  - jamie: 0.312
#  - p35b: 0.277
#  - 單根: 0.324
#  - 折腳: 0.352
#  - 焊點: 0.226
# 文本 389 的代表性關鍵詞：
#  - cersei: 0.314
#  - p34a: 0.285
#  - 回焊爐: 0.244
#  - 濾波: 0.297
#  - 網絡: 0.284
#  - 腳座: 0.249
#  - 設備貼裝: 0.241
#  - 電容: 0.294
# 文本 390 的代表性關鍵詞：
#  - kombucha: 0.309
#  - m81626: 0.225
#  - p33a: 0.265
#  - 堆板: 0.289
#  - 板子: 0.239
# 文本 391 的代表性關鍵詞：
#  - d10a: 0.502
#  - d12: 0.306
#  - 品質: 0.338
#  - 處理: 0.221
#  - 螺絲: 0.379
#  - 隱患: 0.480
# 文本 392 的代表性關鍵詞：
#  - d10b: 0.288
#  - 偶發性: 0.323
#  - 插件機: 0.478
#  - 異常: 0.348
#  - 電容: 0.323
# 文本 393 的代表性關鍵詞：
#  - aoi: 0.290
#  - ppid: 0.201
#  - 不良板: 0.256
#  - 流線: 0.215
# 文本 394 的代表性關鍵詞：
#  - cpu: 0.461
#  - p36: 0.592
#  - 單位: 0.208
# 文本 395 的代表性關鍵詞：
#  - d08: 0.212
#  - d10: 0.248
#  - wlan: 0.248
#  - 偏位: 0.349
#  - 吸嘴: 0.349
#  - 貼片機: 0.264
# 文本 396 的代表性關鍵詞：
#  - bohemia: 0.232
#  - s31: 0.230
#  - team: 0.229
#  - 偏位: 0.546
#  - 印刷機: 0.201
#  - 直通: 0.264
#  - 隱患: 0.209
# 文本 397 的代表性關鍵詞：
#  - bohemia: 0.226
#  - dimm: 0.481
#  - s31: 0.225
#  - team: 0.223
#  - 空焊: 0.367
#  - 隱患: 0.204
# 文本 398 的代表性關鍵詞：
#  - agp: 0.768
#  - sop: 0.336
#  - 效應: 0.205
# 文本 399 的代表性關鍵詞：
#  - cpu: 0.526
#  - p37a: 0.226
#  - pin: 0.219
#  - sb20n61337: 0.206
#  - socket: 0.214
#  - 背板: 0.414
#  - 螺絲: 0.353
# 文本 400 的代表性關鍵詞：
#  - d07: 0.279
#  - d11: 0.276
#  - repair: 0.247
#  - 保養: 0.308
#  - 偏位: 0.311
#  - 回焊爐: 0.269
#  - 結構: 0.354
#  - 週期: 0.329
#  - 電感: 0.250
# 文本 401 的代表性關鍵詞：
#  - aj76: 0.494
#  - m86349: 0.412
#  - p3d: 0.467
#  - 品質: 0.280
#  - 效率: 0.327
# 文本 402 的代表性關鍵詞：
#  - cpu: 0.598
#  - p31b: 0.207
#  - pin: 0.299
#  - 時作業: 0.222
# 文本 403 的代表性關鍵詞：
#  - cpu: 0.355
#  - fbt: 0.206
#  - ib660cx: 0.262
#  - ic: 0.220
#  - pa: 0.309
#  - pin: 0.395
#  - 幹部: 0.236
# 文本 404 的代表性關鍵詞：
#  - p8: 0.588
#  - 破損: 0.355
#  - 自動: 0.255
# 文本 405 的代表性關鍵詞：
#  - dali: 0.432
#  - dimm2: 0.745
#  - 泛用機: 0.205
# 文本 406 的代表性關鍵詞：
#  - d08: 0.216
#  - hp: 0.203
#  - pcb: 0.540
#  - supplier: 0.208
#  - 漏銅: 0.279
#  - 線路: 0.390
#  - 表面: 0.247
#  - 覆蓋: 0.269
# 文本 407 的代表性關鍵詞：
#  - rpl: 0.201
#  - 偏位: 0.245
#  - 整體: 0.247
#  - 設備貼裝: 0.210
# 文本 408 的代表性關鍵詞：
#  - m86349: 0.250
#  - p3d: 0.284
#  - reno: 0.247
#  - 撞件: 0.315
#  - 板作業: 0.223
# 文本 409 的代表性關鍵詞：
#  - rpl: 0.202
#  - 反白: 0.453
#  - 設備貼裝: 0.210
# 文本 410 的代表性關鍵詞：
#  - ec1: 0.372
#  - tray: 0.558
#  - 空焊: 0.289
# 文本 411 的代表性關鍵詞：
#  - j90: 0.448
#  - j91: 0.465
#  - 功能pin: 0.446
#  - 原物料: 0.276
# 文本 412 的代表性關鍵詞：
#  - d10a: 0.343
#  - pcb: 0.389
#  - wxmx: 0.364
#  - 包裝: 0.267
#  - 板子: 0.291
#  - 目檢: 0.263
#  - 維修: 0.332
# 文本 413 的代表性關鍵詞：
#  - p00: 0.203
#  - sw2: 0.614
#  - vendor: 0.261
# 文本 414 的代表性關鍵詞：
#  - card: 0.477
#  - d11: 0.401
#  - d12: 0.277
#  - dolphin: 0.374
#  - sd: 0.443
#  - 空焊: 0.260
# 文本 415 的代表性關鍵詞：
#  - l77195: 0.260
#  - p34b: 0.211
#  - 偶發性: 0.229
#  - 容值: 0.244
#  - 撞件: 0.274
#  - 電容: 0.459
# 文本 416 的代表性關鍵詞：
#  - feeder: 0.321
#  - intel: 0.252
#  - mb: 0.447
#  - 反白: 0.588
#  - 晶振: 0.250
# 文本 417 的代表性關鍵詞：
#  - bent: 0.231
#  - cpu: 0.529
#  - d10b: 0.219
#  - pin: 0.331
#  - r6pct: 0.237
#  - 單根: 0.245
#  - 背板: 0.209
# 文本 418 的代表性關鍵詞：
#  - m98850: 0.203
#  - usb: 0.274
#  - 定位腳: 0.385
#  - 料帶: 0.204
# 文本 419 的代表性關鍵詞：
#  - front: 0.230
#  - tc: 0.239
#  - 短路: 0.234
#  - 錫膏: 0.299
#  - 零件: 0.439
# 文本 420 的代表性關鍵詞：
#  - d05: 0.260
#  - k5c: 0.294
#  - 回焊爐: 0.231
#  - 殘留: 0.202
#  - 濾波: 0.282
#  - 缺件: 0.369
#  - 腳座: 0.236
#  - 設備貼裝: 0.228
#  - 零件: 0.241
#  - 電容: 0.279
# 文本 421 的代表性關鍵詞：
#  - feeder: 0.356
#  - m450c: 0.249
#  - p38: 0.212
#  - 反白: 0.651
# 文本 422 的代表性關鍵詞：
#  - pcb: 0.210
#  - sw: 0.211
# 文本 423 的代表性關鍵詞：
#  - cpu: 0.450
#  - driver: 0.471
#  - dsw: 0.209
#  - ic: 0.298
#  - on: 0.309
# 文本 424 的代表性關鍵詞：
#  - card: 0.315
#  - dolphin: 0.248
#  - sd: 0.586
#  - 爐前: 0.356
# 文本 425 的代表性關鍵詞：
#  - d08: 0.545
#  - 安裝: 0.278
#  - 機臺: 0.331
#  - 異常: 0.225
#  - 電池: 0.602
# 文本 426 的代表性關鍵詞：
#  - p3c: 0.496
#  - 燒板: 0.714
# 文本 427 的代表性關鍵詞：
#  - dmyn9: 0.273
#  - npi: 0.273
#  - pin: 0.218
#  - pwr: 0.440
# 文本 428 的代表性關鍵詞：
#  - s33: 0.446
#  - usb: 0.265
#  - 設備異常: 0.213
#  - 貼裝坐標: 0.318
# 文本 429 的代表性關鍵詞：
#  - esd: 0.255
#  - ic: 0.271
#  - kent6: 0.268
#  - l75370: 0.268
#  - pin: 0.244
#  - 殘件: 0.548
# 文本 430 的代表性關鍵詞：
#  - usb: 0.416
#  - 破損: 0.424
#  - 舌片: 0.510
# 文本 431 的代表性關鍵詞：
#  - d07: 0.342
#  - pq5001: 0.472
#  - pq5002: 0.513
#  - qe: 0.205
#  - sff3: 0.214
#  - 爐溫: 0.208
# 文本 432 的代表性關鍵詞：
#  - a8: 0.244
#  - m86365: 0.245
#  - 鋼網: 0.511
#  - 錫膏: 0.512
# 文本 433 的代表性關鍵詞：
#  - usb: 0.245
#  - 舌片: 0.669
# 文本 434 的代表性關鍵詞：
#  - u1: 0.672
#  - 偏位: 0.393
#  - 拖盤: 0.254
# 文本 435 的代表性關鍵詞：
#  - d08: 0.240
#  - pin: 0.248
#  - x0y8: 0.308
#  - 不良板: 0.297
#  - 更換: 0.273
#  - 機臺: 0.292
# 文本 436 的代表性關鍵詞：
#  - j90: 0.489
#  - j91: 0.508
#  - kent6: 0.310
#  - 空焊: 0.345
# 文本 437 的代表性關鍵詞：
#  - ids: 0.371
#  - l09623: 0.369
#  - nut1: 0.402
#  - nut2: 0.410
#  - p32: 0.229
#  - team: 0.343
#  - trinidad: 0.306
#  - 螺絲: 0.248
# 文本 438 的代表性關鍵詞：
#  - ib660cx: 0.313
#  - m450c: 0.530
#  - p38: 0.451
#  - vb: 0.543
# 文本 439 的代表性關鍵詞：
#  - m09983: 0.229
#  - p31a: 0.247
#  - pike: 0.224
#  - 焊劑: 0.245
#  - 空焊: 0.282
#  - 載具: 0.623
# 文本 440 的代表性關鍵詞：
#  - dimm: 0.312
#  - kent6: 0.214
#  - l75370: 0.214
#  - pan: 0.225
#  - pcb: 0.236
#  - 清洗: 0.240
#  - 焊劑: 0.206
# 文本 441 的代表性關鍵詞：
#  - 0402電容: 0.208
#  - l76450: 0.508
#  - tywin: 0.450
#  - 偏位: 0.385
#  - 貼裝: 0.205
# 文本 442 的代表性關鍵詞：
#  - pqe: 0.503
#  - 錯料: 0.497
# 文本 443 的代表性關鍵詞：
#  - aj76: 0.565
#  - kent5: 0.223
#  - m98850: 0.231
#  - p37b: 0.212
#  - pca: 0.251
#  - 焊劑: 0.236
# 文本 444 的代表性關鍵詞：
#  - d10b: 0.265
#  - grs: 0.310
#  - lotes: 0.280
#  - widowmaker: 0.314
#  - 效率: 0.225
#  - 背板: 0.253
#  - 良率: 0.263
#  - 螺紋: 0.356
#  - 鐵件: 0.274
#  - 響產線: 0.241
# 文本 445 的代表性關鍵詞：
#  - d05: 0.354
#  - juki插件機: 0.381
#  - tvw7j: 0.424
#  - 不良板: 0.204
#  - 電容: 0.379
# 文本 446 的代表性關鍵詞：
#  - joffrey: 0.225
#  - l76453: 0.239
#  - pin: 0.292
#  - wlan: 0.221
#  - 單根: 0.216
#  - 機臺: 0.343
#  - 金手指: 0.249
# 文本 447 的代表性關鍵詞：
#  - d09: 0.248
#  - 上料員: 0.238
#  - 包裝: 0.201
#  - 白色: 0.225
#  - 電源: 0.515
#  - 髒污: 0.586
# 文本 448 的代表性關鍵詞：
#  - d05: 0.250
#  - jwjy: 0.289
#  - 塑膠: 0.205
#  - 板子: 0.218
#  - 機臺: 0.283
#  - 破損: 0.343
#  - 蓋子: 0.310
#  - 表面: 0.266
# 文本 449 的代表性關鍵詞：
#  - d05: 0.520
#  - jwjy: 0.601
#  - repair: 0.423
#  - smt: 0.209
#  - 偏位: 0.267
# 文本 450 的代表性關鍵詞：
#  - d09: 0.245
#  - sb20n61337: 0.225
#  - 外力: 0.237
#  - 引腳: 0.202
#  - 板子: 0.216
#  - 變形: 0.370
#  - 電容: 0.531
# 文本 451 的代表性關鍵詞：
#  - d05: 0.274
#  - jwjy: 0.316
#  - repair: 0.223
#  - 偏位: 0.281
#  - 爐前: 0.334
#  - 短路: 0.338
#  - 貼裝: 0.225
# 文本 452 的代表性關鍵詞：
#  - aoi: 0.225
#  - d09: 0.204
#  - pch: 0.419
#  - u4: 0.431
#  - 撞件: 0.396
#  - 電容: 0.221
# 文本 453 的代表性關鍵詞：
#  - m2: 0.521
#  - p38: 0.471
#  - sb20n61337: 0.465
#  - 空焊: 0.302
#  - 處理: 0.232
# 文本 454 的代表性關鍵詞：
#  - cersei: 0.255
#  - p72: 0.731
#  - s31: 0.241
#  - team: 0.239
# 文本 455 的代表性關鍵詞：
#  - p38: 0.225
#  - 空焊: 0.288
# 文本 456 的代表性關鍵詞：
#  - 塑膠: 0.234
#  - 引腳: 0.620
#  - 空焊: 0.280
#  - 鑷子: 0.335
#  - 零件: 0.220
# 文本 457 的代表性關鍵詞：
#  - cersei: 0.253
#  - j39: 0.444
#  - j40: 0.563
#  - post: 0.204
#  - 零件: 0.205
# 文本 458 的代表性關鍵詞：
#  - d10a: 0.272
#  - fan: 0.300
#  - pin: 0.383
#  - wxmx: 0.289
#  - 微鏡: 0.216
#  - 排針: 0.223
#  - 機台: 0.229
#  - 異常: 0.204
#  - 白色: 0.238
# 文本 459 的代表性關鍵詞：
#  - dimm: 0.203
#  - dimm1: 0.499
#  - p32a: 0.256
#  - sb20t22670: 0.303
#  - volga: 0.300
#  - 板子: 0.229
#  - 焊點: 0.392
#  - 點位: 0.210
# 文本 460 的代表性關鍵詞：
#  - lpt1: 0.657
#  - m450c: 0.257
#  - p38: 0.218
#  - sb20n61553: 0.268
#  - vb: 0.263
#  - 偏位: 0.244
#  - 設備異常: 0.258
# 文本 461 的代表性關鍵詞：
#  - qfp: 0.348
#  - spi: 0.237
#  - 刮刀: 0.287
#  - 殘留: 0.260
#  - 短路: 0.311
#  - 鋼網: 0.264
#  - 錫膏: 0.397
# 文本 462 的代表性關鍵詞：
#  - 封裝: 0.769
# 文本 463 的代表性關鍵詞：
#  - type: 0.371
#  - 受力: 0.208
#  - 外殼: 0.227
#  - 撞件: 0.269
#  - 距離: 0.259
#  - 電容: 0.225
# 文本 464 的代表性關鍵詞：
#  - p3c: 0.441
#  - 品質: 0.273
#  - 效率: 0.320
#  - 良率: 0.375
#  - 重影: 0.266
#  - 隱患: 0.388
#  - 電容: 0.211
#  - 響產線: 0.343
# 文本 465 的代表性關鍵詞：
#  - hu: 0.297
#  - p31a: 0.507
#  - pe: 0.285
#  - 撞件: 0.315
#  - 泡棉: 0.299
#  - 雙面: 0.266
# 文本 466 的代表性關鍵詞：
#  - aj78: 0.589
#  - m99498: 0.245
#  - 高工: 0.259
# 文本 467 的代表性關鍵詞：
#  - feeder: 0.475
#  - g9: 0.258
#  - m81626: 0.252
#  - s33: 0.348
#  - twr: 0.259
#  - z2: 0.252
#  - 供料不穩: 0.290
#  - 電阻: 0.258
# 文本 468 的代表性關鍵詞：
#  - speedtech: 0.473
#  - type: 0.334
# 文本 469 的代表性關鍵詞：
#  - m09983: 0.521
#  - p31a: 0.562
#  - pike: 0.510
#  - ppid: 0.206
#  - 產品: 0.236
# 文本 470 的代表性關鍵詞：
#  - m09983: 0.294
#  - p31a: 0.317
#  - pike: 0.288
#  - 撞件: 0.394
#  - 板作業: 0.280
#  - 貼片: 0.265
# 文本 471 的代表性關鍵詞：
#  - vu67: 0.753
#  - 錫溫: 0.204
# 文本 472 的代表性關鍵詞：
#  - bga: 0.206
#  - kent5: 0.207
#  - p3a: 0.229
#  - u4: 0.448
#  - 短路: 0.531
# 文本 473 的代表性關鍵詞：
#  - d10b: 0.420
#  - kg: 0.262
#  - tracer: 0.214
#  - 壓力: 0.422
#  - 短路: 0.408
# 文本 474 的代表性關鍵詞：
#  - d13: 0.331
#  - ic: 0.323
#  - low: 0.529
#  - ppid: 0.227
#  - sff: 0.343
#  - ven: 0.461
# 文本 475 的代表性關鍵詞：
#  - d07: 0.229
#  - dolphin: 0.211
#  - hd: 0.302
#  - hrfmr: 0.302
#  - 空焊: 0.293
#  - 貼裝: 0.204
# 文本 476 的代表性關鍵詞：
#  - pin: 0.326
#  - wlan: 0.557
#  - 機臺: 0.384
# 文本 477 的代表性關鍵詞：
#  - d09: 0.240
#  - sb20n61337: 0.221
#  - u100: 0.654
# 文本 478 的代表性關鍵詞：
#  - d04: 0.257
#  - ict: 0.273
#  - sb20n61336: 0.234
#  - vga: 0.267
#  - ytm400: 0.219
#  - 撞件: 0.288
#  - 線路: 0.379
# 文本 479 的代表性關鍵詞：
#  - groot3: 0.224
#  - m99498: 0.227
#  - p3c: 0.241
#  - pin: 0.208
#  - 溫度: 0.219
#  - 短路: 0.534
#  - 錫珠: 0.226
# 文本 480 的代表性關鍵詞：
#  - p31b: 0.321
#  - sierra: 0.347
#  - 目檢: 0.254
#  - 電容: 0.517
# 文本 481 的代表性關鍵詞：
#  - aoi: 0.250
#  - cpu1: 0.261
#  - d05: 0.229
#  - matira5: 0.249
#  - vcore: 0.213
#  - 濾波: 0.248
#  - 異常: 0.265
#  - 網絡: 0.237
#  - 背板: 0.209
#  - 電容: 0.368
# 文本 482 的代表性關鍵詞：
#  - npi: 0.582
#  - 包裝: 0.387
#  - 漏貼: 0.286
# 文本 483 的代表性關鍵詞：
#  - l77195: 0.227
#  - s34: 0.215
#  - 條件: 0.230
#  - 雙面: 0.405
#  - 電容: 0.301
# 文本 484 的代表性關鍵詞：
#  - ids: 0.250
#  - nut1: 0.543
#  - nut2: 0.553
#  - trinidad: 0.207
#  - 螺絲柱: 0.259
# 文本 485 的代表性關鍵詞：
#  - d09: 0.206
#  - fxd80: 0.235
#  - 殘錫: 0.683
#  - 維修: 0.207
# 文本 486 的代表性關鍵詞：
#  - ids: 0.406
#  - l09623: 0.404
#  - trinidad: 0.335
#  - 不良板: 0.202
#  - 偏位: 0.359
#  - 設備異常: 0.379
# 文本 487 的代表性關鍵詞：
#  - audio: 0.612
#  - d10b: 0.254
#  - 微鏡: 0.217
#  - 焊點: 0.398
#  - 空焊: 0.314
#  - 點位: 0.213
# 文本 488 的代表性關鍵詞：
#  - 料帶: 0.701
#  - 缺件: 0.371
#  - 貼片機: 0.203
# 文本 489 的代表性關鍵詞：
#  - pin: 0.492
#  - winters: 0.240
#  - 排針: 0.645
# 文本 490 的代表性關鍵詞：
#  - d08: 0.203
#  - hp: 0.381
#  - x0y8: 0.261
#  - 幹部: 0.251
#  - 時作業: 0.234
#  - 螺柱: 0.448
#  - 螺絲柱: 0.525
# 文本 491 的代表性關鍵詞：
#  - ict: 0.302
#  - p34: 0.580
#  - 維修: 0.248
# 文本 492 的代表性關鍵詞：
#  - a6: 0.226
#  - er: 0.201
#  - m44945: 0.231
#  - p36a: 0.208
#  - 松下: 0.248
#  - 殘件: 0.486
#  - 高二: 0.224
# 文本 493 的代表性關鍵詞：
#  - d10a: 0.575
#  - f1hc1: 0.569
#  - repair: 0.456
#  - smt: 0.225
# 文本 494 的代表性關鍵詞：
#  - hdmi: 0.433
#  - 同廠: 0.228
#  - 投板: 0.218
#  - 散料: 0.241
#  - 開線: 0.235
# 文本 495 的代表性關鍵詞：
#  - d07: 0.373
#  - d11: 0.369
#  - sff: 0.231
#  - 系統: 0.401
# 文本 496 的代表性關鍵詞：
#  - dimm4: 0.745
#  - pin: 0.303
#  - 維修: 0.209
# 文本 497 的代表性關鍵詞：
#  - s33: 0.234
#  - 實物: 0.211
#  - 貼片機: 0.480
# 文本 498 的代表性關鍵詞：
#  - fbt: 0.376
#  - xc300: 0.241
#  - 撞件: 0.240
#  - 開線: 0.441
# 文本 499 的代表性關鍵詞：
#  - p3c: 0.402
#  - pcb: 0.210
#  - 毛刺: 0.596
#  - 漏銅: 0.217
#  - 螺絲: 0.279
#  - 週期: 0.391
# 文本 500 的代表性關鍵詞：
#  - 殘錫: 0.572
#  - 載具: 0.505
#  - 錫餅: 0.408
# 文本 501 的代表性關鍵詞：
#  - p34: 0.483
#  - 主板: 0.373
#  - 燒板: 0.500
#  - 處理: 0.282
# 文本 502 的代表性關鍵詞：
#  - cpu: 0.245
#  - m86349: 0.216
#  - p8: 0.241
#  - reno: 0.213
#  - 塑膠: 0.348
#  - 排針: 0.534
#  - 破損: 0.291
#  - 電源: 0.218
# 文本 503 的代表性關鍵詞：
#  - m450c: 0.283
#  - p38: 0.240
#  - sb20n61553: 0.295
#  - vb: 0.289
#  - 空焊: 0.308
#  - 錫膏印刷: 0.617
# 文本 504 的代表性關鍵詞：
#  - groot3: 0.239
#  - m99498: 0.242
#  - p2: 0.541
#  - p3c: 0.257
#  - 大圖: 0.208
#  - 時作業: 0.247
#  - 破損: 0.317
#  - 電源: 0.237
# 文本 505 的代表性關鍵詞：
#  - d10b: 0.487
#  - d12: 0.319
#  - mtx: 0.362
#  - r6pct: 0.526
#  - 處理: 0.231
# 文本 506 的代表性關鍵詞：
#  - supplier: 0.288
#  - 網卡: 0.437
#  - 網絡: 0.331
# 文本 507 的代表性關鍵詞：
#  - j39: 0.537
#  - joffrey: 0.297
#  - p35: 0.311
#  - 空焊: 0.315
#  - 設備貼裝: 0.235
#  - 貼裝坐標: 0.216
# 文本 508 的代表性關鍵詞：
#  - ib660cx: 0.270
#  - m450c: 0.458
#  - p38a: 0.340
#  - sb20n61553: 0.477
#  - vb: 0.469
#  - 空焊: 0.250
# 文本 509 的代表性關鍵詞：
#  - d04: 0.261
#  - sc15: 0.758
#  - 撞件: 0.292
# 文本 510 的代表性關鍵詞：
#  - d10a: 0.219
#  - f1hc1: 0.216
#  - 交叉: 0.241
#  - 錯位: 0.747
# 文本 511 的代表性關鍵詞：
#  - d10b: 0.276
#  - repair: 0.235
#  - 吸嘴: 0.222
#  - 缺件: 0.409
#  - 螺絲柱: 0.696
# 文本 512 的代表性關鍵詞：
#  - aj76: 0.693
#  - open: 0.268
#  - 線量: 0.284
# 文本 513 的代表性關鍵詞：
#  - bent: 0.442
#  - cpu: 0.254
#  - d09: 0.433
#  - final: 0.471
#  - pin: 0.211
#  - vi: 0.438
# 文本 514 的代表性關鍵詞：
#  - p37a: 0.249
#  - p3a: 0.266
#  - sb20n61337: 0.227
#  - 干涉: 0.222
#  - 板作業: 0.227
#  - 機台: 0.215
#  - 貼裝: 0.205
#  - 開線: 0.294
#  - 雙面: 0.270
#  - 零件: 0.347
# 文本 515 的代表性關鍵詞：
#  - pcb: 0.231
#  - 偏位: 0.203
#  - 空焊: 0.351
#  - 雙面: 0.214
# 文本 516 的代表性關鍵詞：
#  - p38a: 0.342
#  - spi: 0.401
#  - u4: 0.444
#  - 偏位: 0.291
#  - 鋼網: 0.335
# 文本 517 的代表性關鍵詞：
#  - m450c: 0.248
#  - p38: 0.211
#  - sb20n61553: 0.258
#  - vb: 0.254
#  - 空焊: 0.270
#  - 錫膏印刷: 0.542
# 文本 518 的代表性關鍵詞：
#  - hd: 0.230
#  - hrfmr: 0.230
#  - 濾波: 0.205
#  - 空焊: 0.336
#  - 電容: 0.305
# 文本 519 的代表性關鍵詞：
#  - groot3: 0.352
#  - m99498: 0.356
#  - p3c: 0.379
# 文本 520 的代表性關鍵詞：
#  - aoi: 0.253
#  - d08: 0.217
#  - 不良板: 0.201
#  - 偏位: 0.238
#  - 缺件: 0.329
#  - 設備異常: 0.252
# 文本 521 的代表性關鍵詞：
#  - hsbp: 0.596
#  - matira5: 0.566
#  - smt: 0.209
#  - 排針: 0.438
# 文本 522 的代表性關鍵詞：
#  - ict: 0.218
#  - p31: 0.423
#  - sierra: 0.580
#  - v2: 0.463
# 文本 523 的代表性關鍵詞：
#  - fio: 0.237
#  - v2: 0.219
#  - 短路: 0.236
#  - 鐵殼: 0.738
# 文本 524 的代表性關鍵詞：
#  - cersei: 0.257
#  - j94: 0.241
#  - s33: 0.254
#  - 光板: 0.200
#  - 爐前: 0.274
#  - 程度: 0.245
#  - 聯基: 0.247
#  - 貼裝壓力: 0.237
# 文本 525 的代表性關鍵詞：
#  - lot: 0.242
#  - usb: 0.388
#  - 外殼: 0.415
#  - 變形: 0.430
# 文本 526 的代表性關鍵詞：
#  - dimm: 0.222
#  - p34b: 0.284
#  - 干涉: 0.256
#  - 撞件: 0.368
#  - 板作業: 0.262
#  - 機台: 0.248
#  - 貼片: 0.248
#  - 雙面: 0.312
# 文本 527 的代表性關鍵詞：
#  - l09623: 0.657
#  - p31: 0.446
#  - 燒板: 0.457
# 文本 528 的代表性關鍵詞：
#  - j39: 0.531
#  - pike: 0.329
#  - v2: 0.303
#  - 空焊: 0.208
# 文本 529 的代表性關鍵詞：
#  - m09983: 0.288
#  - pike: 0.282
#  - s31: 0.326
#  - v2: 0.260
#  - 保養: 0.306
#  - 偏位: 0.309
#  - 花板: 0.310
#  - 高一: 0.262
# 文本 530 的代表性關鍵詞：
#  - m09983: 0.275
#  - uf: 0.256
#  - v2: 0.248
#  - 機打: 0.257
#  - 電容: 0.615
# 文本 531 的代表性關鍵詞：
#  - d09: 0.226
#  - d10: 0.250
#  - dy62r: 0.269
#  - 夾邊: 0.594
#  - 時點: 0.243
#  - 花板: 0.235
#  - 軌道: 0.395
# 文本 532 的代表性關鍵詞：
#  - matira5: 0.209
#  - slot1: 0.670
#  - 技能: 0.211
#  - 方案: 0.233
# 文本 533 的代表性關鍵詞：
#  - d08: 0.225
#  - dy62r: 0.283
#  - ss: 0.312
#  - usb: 0.487
#  - 外殼: 0.260
#  - 變形: 0.359
# 文本 534 的代表性關鍵詞：
#  - d08: 0.240
#  - d10: 0.282
#  - dy62r: 0.303
#  - 不良板: 0.223
#  - 空焊: 0.456
#  - 進料: 0.291
# 文本 535 的代表性關鍵詞：
#  - a6: 0.256
#  - er: 0.228
#  - m44945: 0.263
#  - p36b: 0.241
#  - 對板: 0.303
#  - 濾波: 0.276
#  - 背板: 0.232
#  - 貼裝: 0.209
#  - 雙面: 0.276
#  - 電容: 0.273
# 文本 536 的代表性關鍵詞：
#  - hsbp: 0.596
#  - matira5: 0.566
#  - smt: 0.209
#  - 排針: 0.438
# 文本 537 的代表性關鍵詞：
#  - a6: 0.455
#  - er: 0.405
#  - ic: 0.243
#  - m44945: 0.467
#  - p36a: 0.420
#  - 空焊: 0.267
# 文本 538 的代表性關鍵詞：
#  - a6: 0.472
#  - er: 0.420
#  - ic: 0.252
#  - m44945: 0.484
#  - p36a: 0.435
#  - 產品: 0.204
# 文本 539 的代表性關鍵詞：
#  - groot3: 0.457
#  - m99498: 0.462
#  - 端子: 0.538
# 文本 540 的代表性關鍵詞：
#  - p36: 0.493
#  - 燒板: 0.534
#  - 短路: 0.411
# 文本 541 的代表性關鍵詞：
#  - hdmi: 0.677
#  - pin: 0.301
#  - 插件機: 0.372
# 文本 542 的代表性關鍵詞：
#  - p32: 0.238
#  - twr: 0.280
#  - z2: 0.272
#  - 吸嘴: 0.510
#  - 殘錫: 0.272
#  - 電感: 0.274
# 文本 543 的代表性關鍵詞：
#  - j90: 0.545
#  - j91: 0.566
#  - p3c: 0.274
# 文本 544 的代表性關鍵詞：
#  - 混料: 0.632
# 文本 545 的代表性關鍵詞：
#  - card: 0.462
#  - ict: 0.346
#  - p3f: 0.507
#  - usb: 0.288
#  - 不良板: 0.246
# 文本 546 的代表性關鍵詞：
#  - j90: 0.445
#  - j91: 0.463
#  - usb: 0.270
#  - 空焊: 0.236
# 文本 547 的代表性關鍵詞：
#  - domino: 0.238
#  - m81600: 0.233
#  - 偏位: 0.249
#  - 間距: 0.409
# 文本 548 的代表性關鍵詞：
#  - 偏位: 0.457
#  - 設計: 0.279
#  - 間隙: 0.280
#  - 電感: 0.210
# 文本 549 的代表性關鍵詞：
#  - d08: 0.514
#  - d10: 0.603
#  - ict: 0.223
#  - sff: 0.314
#  - 空焊: 0.325
# 文本 550 的代表性關鍵詞：
#  - d10b: 0.264
#  - ict: 0.336
#  - r6pct: 0.286
#  - tracer: 0.269
#  - 撞件: 0.530
#  - 路由: 0.221
# 文本 551 的代表性關鍵詞：
#  - d10a: 0.299
#  - dp1: 0.330
#  - pcb: 0.255
#  - 短路: 0.450
#  - 間隙: 0.320
# 文本 552 的代表性關鍵詞：
#  - m10314: 0.310
#  - p31a: 0.278
#  - sierra: 0.291
#  - v2: 0.232
#  - 撞件: 0.345
#  - 時作業: 0.290
#  - 目檢: 0.212
#  - 貼片: 0.233
#  - 電感: 0.223
# 文本 553 的代表性關鍵詞：
#  - 爐前: 0.411
# 文本 554 的代表性關鍵詞：
#  - d05: 0.437
#  - p1: 0.237
#  - sata: 0.232
#  - slot1: 0.254
#  - 噴霧: 0.249
#  - 清洗: 0.260
#  - 焊劑: 0.223
# 文本 555 的代表性關鍵詞：
#  - bent: 0.408
#  - cpu: 0.234
#  - pin: 0.292
#  - sfc: 0.231
#  - 單根: 0.217
#  - 邊緣: 0.203
# 文本 556 的代表性關鍵詞：
#  - m81592: 0.399
#  - scrabble: 0.395
#  - 偏位: 0.385
#  - 墊片: 0.308
# 文本 557 的代表性關鍵詞：
#  - 0402電容: 0.252
#  - feeder: 0.469
#  - pa: 0.229
#  - sb20n61336: 0.315
#  - ytm400: 0.295
# 文本 558 的代表性關鍵詞：
#  - pu900: 0.703
#  - 偏位: 0.458
# 文本 559 的代表性關鍵詞：
#  - m86349: 0.356
# ...
#  - 板作業: 0.266
#  - 機台: 0.252
#  - 流線: 0.354
#  - 電阻: 0.245
# 文本 7148 的代表性關鍵詞：
#  - p20a: 0.276
#  - pcb: 0.364
#  - pin: 0.301
#  - spi: 0.221
#  - 板子: 0.272
#  - 機臺: 0.354
# 文本 7149 的代表性關鍵詞：
#  - aj76: 0.677
#  - akali: 0.243
#  - m87866: 0.254
#  - p37: 0.218
# 文本 7150 的代表性關鍵詞：
#  - ib660cx: 0.247
#  - input: 0.399
#  - n50s: 0.310
#  - p36: 0.287
#  - rplr: 0.365
#  - sb21d13551: 0.412
#  - 機打: 0.345
#  - 電容: 0.207
# 文本 7151 的代表性關鍵詞：
#  - usb: 0.354
#  - 機臺: 0.223
#  - 舌片: 0.579
# 文本 7152 的代表性關鍵詞：
#  - d14: 0.357
#  - mtx: 0.227
#  - p32: 0.229
#  - sd: 0.321
#  - tracer: 0.311
#  - 品質: 0.221
#  - 效率: 0.259
#  - 重影: 0.216
# 文本 7153 的代表性關鍵詞：
#  - dominor: 0.243
#  - n18256: 0.246
#  - 上料: 0.203
#  - 折角: 0.273
#  - 機打: 0.416
#  - 焊點: 0.348
#  - 貼片: 0.201
#  - 高工: 0.258
# 文本 7154 的代表性關鍵詞：
#  - d14: 0.461
#  - p25: 0.333
#  - vr: 0.487
#  - 散熱片: 0.350
#  - 螺柱: 0.423
# 文本 7155 的代表性關鍵詞：
#  - p20a: 0.781
#  - pin: 0.425
#  - 單位: 0.230
# 文本 7156 的代表性關鍵詞：
#  - 偶發性: 0.336
# 文本 7157 的代表性關鍵詞：
#  - glacier: 0.266
#  - n10298: 0.270
#  - winters: 0.227
#  - 回焊爐: 0.214
#  - 破損: 0.497
#  - 螺絲: 0.374
#  - 載具: 0.209
#  - 電感: 0.399
# 文本 7158 的代表性關鍵詞：
#  - dp3: 0.249
#  - p2aa: 0.297
#  - r93r: 0.213
#  - sigsaly: 0.225
#  - xe: 0.201
#  - 變形: 0.590
# 文本 7159 的代表性關鍵詞：
#  - ict: 0.227
#  - xl: 0.209
#  - 不良板: 0.323
#  - 短路: 0.461
# 文本 7160 的代表性關鍵詞：
#  - aux: 0.418
#  - pq5001: 0.436
#  - s0: 0.317
#  - vccin: 0.439
#  - 線路: 0.404
# 文本 7161 的代表性關鍵詞：
#  - glan: 0.204
#  - ref: 0.208
#  - xl: 0.210
#  - 板面: 0.210
#  - 殘件: 0.202
#  - 殘膠: 0.203
#  - 缺件: 0.530
#  - 貼裝頭: 0.406
# 文本 7162 的代表性關鍵詞：
#  - p32: 0.449
#  - 裂痕: 0.778
# 文本 7163 的代表性關鍵詞：
#  - pcb: 0.264
#  - 全部: 0.464
#  - 干涉: 0.268
#  - 板邊: 0.356
#  - 破損: 0.207
# 文本 7164 的代表性關鍵詞：
#  - 系統: 1.000
# 文本 7165 的代表性關鍵詞：
#  - p6y94: 0.234
#  - 殘錫: 0.369
# 文本 7166 的代表性關鍵詞：
# 文本 7167 的代表性關鍵詞：
#  - cxr46: 0.211
#  - d2502: 0.507
#  - p28a: 0.444
#  - 擦板: 0.231
#  - 皮帶: 0.250
#  - 缺件: 0.294
# 文本 7168 的代表性關鍵詞：
#  - lm: 0.311
#  - 空焊: 0.330
#  - 貼裝: 0.230
# 文本 7169 的代表性關鍵詞：
#  - pin: 0.556
#  - 更換: 0.204
#  - 機臺: 0.363
# 文本 7170 的代表性關鍵詞：
#  - dimm: 0.237
#  - dimm1: 0.291
#  - dominor: 0.319
#  - n18256: 0.323
#  - p34: 0.238
#  - p34b: 0.302
# 文本 7171 的代表性關鍵詞：
#  - ff1: 0.228
#  - ff3: 0.256
#  - ff4: 0.245
#  - ng: 0.349
#  - p6y94: 0.207
#  - 打膠: 0.229
#  - 紙板: 0.221
# 文本 7172 的代表性關鍵詞：
#  - p31: 0.499
#  - 品質: 0.440
#  - 效率: 0.515
# 文本 7173 的代表性關鍵詞：
#  - ict: 0.275
#  - p2aa: 0.511
#  - r93r: 0.732
#  - 維修: 0.225
# 文本 7174 的代表性關鍵詞：
#  - n25951: 0.275
#  - renor2: 0.271
#  - touch: 0.201
#  - 殘錫: 0.560
#  - 錫溫: 0.246
#  - 錫珠: 0.238
# 文本 7175 的代表性關鍵詞：
#  - j64: 0.640
#  - n18252: 0.212
#  - p34: 0.201
#  - p34a: 0.268
#  - scrabbler: 0.217
#  - 零件: 0.239
# 文本 7176 的代表性關鍵詞：
#  - alexandria: 0.222
#  - freeport: 0.435
#  - lot: 0.288
#  - pqe: 0.224
#  - usb: 0.308
#  - y7v6m: 0.226
#  - 變形: 0.341
#  - 鐵殼: 0.265
# 文本 7177 的代表性關鍵詞：
#  - dolphin: 0.286
#  - faillocation: 0.396
#  - mlk2: 0.354
#  - p28: 0.257
#  - pvrxf: 0.406
#  - rpl: 0.283
#  - 短路: 0.208
#  - 腳座: 0.305
# 文本 7178 的代表性關鍵詞：
#  - 噴霧: 0.237
#  - 寬度: 0.244
#  - 軌道: 0.721
# 文本 7179 的代表性關鍵詞：
#  - j81: 0.582
#  - usb: 0.238
#  - 變形: 0.396
#  - 鐵殼: 0.410
# 文本 7180 的代表性關鍵詞：
#  - bat: 0.333
#  - failed: 0.325
#  - feeder: 0.464
#  - slot1: 0.349
#  - usb: 0.202
# 文本 7181 的代表性關鍵詞：
#  - n18252: 0.212
#  - p31: 0.406
#  - scrabbler: 0.217
#  - 回焊爐: 0.229
#  - 掉落: 0.235
#  - 殘件: 0.559
#  - 零件: 0.239
#  - 電阻: 0.216
# 文本 7182 的代表性關鍵詞：
#  - galior: 0.209
#  - j74: 0.732
#  - n27946: 0.208
# 文本 7183 的代表性關鍵詞：
#  - smt: 0.257
#  - 回焊爐: 0.284
#  - 料帶: 0.322
#  - 殘膠: 0.695
# 文本 7184 的代表性關鍵詞：
#  - 板邊: 0.253
#  - 殘留: 0.500
#  - 軌道: 0.417
# 文本 7185 的代表性關鍵詞：
#  - d14: 0.240
#  - p32b: 0.209
#  - tracer: 0.208
#  - 殘留: 0.333
#  - 殘錫: 0.351
#  - 清洗: 0.255
#  - 載具: 0.372
# 文本 7186 的代表性關鍵詞：
#  - freeport: 0.307
#  - p28: 0.246
#  - 固定: 0.529
#  - 更換: 0.256
# 文本 7187 的代表性關鍵詞：
#  - alexandria: 0.337
#  - high: 0.268
#  - mtp: 0.263
#  - p2aa: 0.260
#  - qe: 0.382
#  - y7v6m: 0.343
#  - 品質: 0.240
#  - 重影: 0.233
# 文本 7188 的代表性關鍵詞：
#  - slot1: 0.761
# 文本 7189 的代表性關鍵詞：
#  - lm: 0.283
#  - 貼裝坐標: 0.274
# 文本 7190 的代表性關鍵詞：
#  - akalir: 0.212
#  - j8: 0.704
#  - n25948: 0.217
# 文本 7191 的代表性關鍵詞：
#  - dimm: 0.378
#  - p25: 0.395
#  - 品質: 0.339
#  - 破損: 0.336
#  - 處理: 0.222
#  - 重影: 0.329
#  - 響產線: 0.425
# 文本 7192 的代表性關鍵詞：
#  - con: 0.221
#  - elite: 0.227
#  - 噴霧: 0.431
#  - 軌道: 0.327
#  - 電容: 0.405
# 文本 7193 的代表性關鍵詞：
#  - p36: 0.721
#  - ppid: 0.366
#  - 產品: 0.421
# 文本 7194 的代表性關鍵詞：
#  - cpu: 0.428
#  - cpu1: 0.241
#  - dimm2: 0.650
#  - socket: 0.298
# 文本 7195 的代表性關鍵詞：
#  - 板子: 0.391
#  - 焊點: 0.223
#  - 皮帶: 0.360
#  - 直通: 0.371
#  - 髒污: 0.524
# 文本 7196 的代表性關鍵詞：
#  - bent: 0.268
#  - cpu: 0.462
#  - p20a: 0.235
#  - pin: 0.385
#  - rota2: 0.262
#  - vtky7: 0.259
#  - 外力: 0.254
#  - 自動: 0.262
# 文本 7197 的代表性關鍵詞：
#  - p20a: 0.256
#  - rota2: 0.284
#  - vtky7: 0.281
#  - 撞件: 0.370
#  - 板作業: 0.263
#  - 板邊: 0.228
#  - 貼片: 0.250
# 文本 7198 的代表性關鍵詞：
#  - high: 0.265
#  - mlk: 0.296
#  - p6y94: 0.355
#  - ven: 0.262
#  - 品質: 0.237
#  - 實物: 0.349
#  - 標準: 0.393
#  - 重影: 0.230
# 文本 7199 的代表性關鍵詞：
#  - card: 0.386
#  - f284y: 0.399
#  - input: 0.369
#  - p28: 0.273
#  - sd: 0.359
#  - sff: 0.204
# 文本 7200 的代表性關鍵詞：
#  - cpu: 0.359
#  - cres: 0.221
#  - glan: 0.225
#  - kg: 0.492
#  - ref: 0.230
#  - 短路: 0.256
# 文本 7201 的代表性關鍵詞：
#  - dimm4: 0.563
#  - p3: 0.309
#  - 插件機: 0.472
#  - 耳扣: 0.300
#  - 電源: 0.245
# 文本 7202 的代表性關鍵詞：
#  - cres: 0.216
#  - sw: 0.237
#  - 破損: 0.277
# 文本 7203 的代表性關鍵詞：
#  - alexandria: 0.303
#  - high: 0.240
#  - mtp: 0.236
#  - p2aa: 0.234
#  - sop: 0.316
#  - y7v6m: 0.308
#  - 全部: 0.319
#  - 泡棉: 0.377
# 文本 7204 的代表性關鍵詞：
#  - pin: 0.245
#  - 機打: 0.228
#  - 電源: 0.523
# 文本 7205 的代表性關鍵詞：
#  - 系統: 1.000
# 文本 7206 的代表性關鍵詞：
#  - aoi: 0.303
#  - dimm2: 0.380
#  - 地點: 0.447
# 文本 7207 的代表性關鍵詞：
#  - npi: 0.212
#  - 板面: 0.395
#  - 腳長: 0.734
# 文本 7208 的代表性關鍵詞：
#  - bios: 0.482
#  - d14: 0.227
#  - 偏位: 0.208
#  - 放板: 0.231
#  - 爐前: 0.248
#  - 貼裝: 0.333
# 文本 7209 的代表性關鍵詞：
#  - p21: 0.244
#  - 偏位: 0.395
#  - 貼裝: 0.211
#  - 連片: 0.297
#  - 零件: 0.238
#  - 高三: 0.247
# 文本 7210 的代表性關鍵詞：
#  - aoi: 0.320
#  - galior: 0.301
#  - ict: 0.358
#  - n27946: 0.300
#  - p37: 0.232
# 文本 7211 的代表性關鍵詞：
#  - y7v6m: 0.317
#  - 吸嘴: 0.246
#  - 殘件: 0.347
#  - 殘膠: 0.348
#  - 缺件: 0.227
#  - 高三: 0.309
# 文本 7212 的代表性關鍵詞：
#  - n18252: 0.230
#  - p31b: 0.279
#  - scrabbler: 0.235
#  - smt: 0.225
#  - 回焊爐: 0.248
#  - 堆板: 0.294
#  - 板邊: 0.441
#  - 殘膠: 0.304
#  - 路由: 0.224
#  - 髒污: 0.327
# 文本 7213 的代表性關鍵詞：
#  - bastion: 0.400
#  - d14: 0.387
#  - p26: 0.250
#  - 殘錫: 0.567
# 文本 7214 的代表性關鍵詞：
#  - cres: 0.320
#  - dimm: 0.231
#  - glan: 0.326
#  - input: 0.309
#  - p25: 0.242
#  - ref: 0.333
#  - 殘留: 0.232
#  - 殘錫: 0.245
#  - 良品: 0.295
# 文本 7215 的代表性關鍵詞：
#  - pin: 0.675
#  - 白色: 0.504
#  - 電源: 0.288
# 文本 7216 的代表性關鍵詞：
#  - pin: 0.332
# 文本 7217 的代表性關鍵詞：
#  - fw8: 0.364
#  - hvar: 0.325
#  - p25: 0.256
#  - pwr: 0.307
#  - sw: 0.372
#  - tramore: 0.386
#  - 自動: 0.312
#  - 載具: 0.274
# 文本 7218 的代表性關鍵詞：
#  - feeder: 0.229
#  - 料帶: 0.297
#  - 更換: 0.235
#  - 異常: 0.228
# 文本 7219 的代表性關鍵詞：
#  - aoi: 0.221
#  - cxr46: 0.207
#  - sff3: 0.235
#  - 全圖: 0.429
#  - 殘留: 0.316
#  - 空焊: 0.359
# 文本 7220 的代表性關鍵詞：
#  - bga: 0.292
#  - p21: 0.289
#  - short: 0.205
#  - winters: 0.286
#  - 偏位: 0.312
#  - 吸嘴: 0.234
#  - 吸料位置: 0.254
#  - 泛二: 0.236
# 文本 7221 的代表性關鍵詞：
#  - d12: 0.238
#  - mtp: 0.288
#  - p2aa: 0.285
#  - 效率: 0.307
#  - 良率: 0.360
#  - 識別: 0.340
#  - 重影: 0.255
#  - 響產線: 0.329
# 文本 7222 的代表性關鍵詞：
#  - mb: 0.214
#  - pn: 0.343
#  - 不良板: 0.229
#  - 交叉: 0.225
#  - 異常: 0.229
#  - 電量: 0.212
# 文本 7223 的代表性關鍵詞：
#  - 光板: 0.253
#  - 短路: 0.351
# 文本 7224 的代表性關鍵詞：
#  - hd: 0.254
#  - p32b: 0.204
#  - pin: 0.504
#  - 排針: 0.528
#  - 探針: 0.218
# 文本 7225 的代表性關鍵詞：
#  - aux: 0.409
#  - pq5002: 0.464
#  - s0: 0.310
#  - vccin: 0.429
#  - 線路: 0.395
# 文本 7226 的代表性關鍵詞：
#  - fw8: 0.246
#  - glan: 0.233
#  - hvar: 0.220
#  - int: 0.550
#  - jonhon: 0.229
#  - pin: 0.309
#  - ref: 0.238
#  - usb: 0.288
# 文本 7227 的代表性關鍵詞：
#  - cxr46: 0.294
#  - p28: 0.220
#  - 光板: 0.257
#  - 大圖: 0.260
#  - 微鏡: 0.235
#  - 焊點: 0.215
#  - 異常: 0.333
#  - 程度: 0.314
# 文本 7228 的代表性關鍵詞：
#  - m86349: 0.352
#  - p38b: 0.267
#  - reno: 0.348
#  - 單根: 0.370
#  - 引腳: 0.282
#  - 焊點: 0.259
#  - 目視: 0.206
#  - 端板: 0.228
# 文本 7229 的代表性關鍵詞：
#  - post: 0.221
#  - rota2: 0.236
#  - vtky7: 0.233
#  - 主板: 0.288
#  - 機臺: 0.408
#  - 零件: 0.334
# 文本 7230 的代表性關鍵詞：
#  - cpu: 0.682
#  - xu1: 0.281
#  - 電壓: 0.227
#  - 電量: 0.315
# 文本 7231 的代表性關鍵詞：
#  - pan: 0.242
#  - pcb: 0.254
#  - pn: 0.376
#  - 來件: 0.498
#  - 短路: 0.269
# 文本 7232 的代表性關鍵詞：
#  - ict: 0.268
#  - m87866: 0.202
#  - 破損: 0.302
#  - 空間: 0.236
#  - 良品: 0.217
#  - 載板: 0.283
# 文本 7233 的代表性關鍵詞：
#  - fw8: 0.374
#  - hvar: 0.334
#  - int: 0.418
#  - p26: 0.235
#  - usb: 0.438
# 文本 7234 的代表性關鍵詞：
#  - akali: 0.424
#  - m87866: 0.443
#  - p37: 0.380
#  - short: 0.325
#  - xu1: 0.460
# 文本 7235 的代表性關鍵詞：
#  - p36: 0.699
#  - ppid: 0.355
#  - 單位: 0.245
#  - 產品: 0.408
# 文本 7236 的代表性關鍵詞：
#  - glacier: 0.286
#  - j41: 0.249
#  - n10298: 0.290
#  - p32b: 0.253
#  - winters: 0.244
#  - 焊劑: 0.529
#  - 系統: 0.257
# 文本 7237 的代表性關鍵詞：
#  - feeder: 0.353
#  - lm: 0.255
#  - p28a: 0.326
#  - 反白: 0.288
# 文本 7238 的代表性關鍵詞：
#  - f284y: 0.221
#  - mlk2: 0.208
#  - p28a: 0.423
#  - 幹部: 0.227
# 文本 7239 的代表性關鍵詞：
#  - p26: 0.250
#  - pcb: 0.403
#  - 偏位: 0.444
#  - 有所: 0.207
#  - 鋼網: 0.273
# 文本 7240 的代表性關鍵詞：
#  - aux: 0.263
#  - cpu: 0.299
#  - pq5001: 0.659
#  - supplier: 0.233
#  - vccin: 0.276
# 文本 7241 的代表性關鍵詞：
#  - ai: 0.419
#  - d14: 0.396
#  - input: 0.366
#  - p32: 0.254
#  - tracer: 0.344
#  - 品質: 0.245
#  - 重影: 0.239
# 文本 7242 的代表性關鍵詞：
#  - ict: 0.294
#  - p27: 0.273
#  - 殘留: 0.282
#  - 目檢: 0.286
#  - 破損: 0.498
# 文本 7243 的代表性關鍵詞：
#  - n26799: 0.278
#  - 散熱片: 0.463
#  - 線長: 0.649
#  - 隱患: 0.268
# 文本 7244 的代表性關鍵詞：
#  - p00: 0.211
#  - 料帶: 0.349
# 文本 7245 的代表性關鍵詞：
#  - vccgt: 0.589
#  - vccia0: 0.203
#  - vgt: 0.237
#  - 短路: 0.235
#  - 線路: 0.479
# 文本 7246 的代表性關鍵詞：
#  - ff: 0.322
#  - ff1: 0.586
#  - ff3: 0.263
#  - ng: 0.419
# 文本 7247 的代表性關鍵詞：
#  - ict: 0.221
#  - m87866: 0.501
#  - p37: 0.429
#  - xu1: 0.520
#  - 短路: 0.337
# 文本 7248 的代表性關鍵詞：
#  - bios: 0.450
#  - d14: 0.423
#  - ng: 0.443
#  - 安裝: 0.360
#  - 螺絲: 0.294
# 文本 7249 的代表性關鍵詞：
#  - d14: 0.418
#  - high: 0.290
#  - p31: 0.294
#  - sff: 0.213
#  - 爐前: 0.229
#  - 空焊: 0.441
# 文本 7250 的代表性關鍵詞：
#  - cr10: 0.673
#  - n26178: 0.271
#  - nebula: 0.243
#  - p39b: 0.214
#  - 撞件: 0.320
# 文本 7251 的代表性關鍵詞：
#  - pq: 0.270
#  - spi: 0.347
#  - 點位: 0.295
# 文本 7252 的代表性關鍵詞：
#  - 系統: 1.000
# 文本 7253 的代表性關鍵詞：
#  - b1: 0.211
#  - lm: 0.287
#  - step: 0.302
#  - 偏位: 0.264
#  - 空焊: 0.202
# 文本 7254 的代表性關鍵詞：
#  - r93r: 0.243
#  - sigsaly: 0.257
#  - xe: 0.229
#  - 回焊爐: 0.401
#  - 寬度: 0.264
#  - 板邊: 0.356
#  - 軌道: 0.390
#  - 速度: 0.231
# 文本 7255 的代表性關鍵詞：
#  - dimm: 0.299
#  - 壓痕: 0.464
#  - 托盤: 0.591
#  - 變形: 0.289
# 文本 7256 的代表性關鍵詞：
#  - f284y: 0.235
#  - mlk2: 0.222
#  - p28b: 0.438
#  - 花板: 0.216
#  - 電磁閥: 0.257
#  - 頂pin: 0.225
#  - 高三: 0.203
# 文本 7257 的代表性關鍵詞：
#  - slot3: 0.415
#  - slot5: 0.447
#  - 爐前: 0.203
#  - 貼裝: 0.205
# 文本 7258 的代表性關鍵詞：
#  - ib660cx: 0.234
#  - n50s: 0.293
#  - p36: 0.271
#  - rplr: 0.345
#  - sb21d13551: 0.390
#  - short: 0.246
#  - xu1: 0.348
#  - 短路: 0.226
#  - 腳座: 0.331
# 文本 7259 的代表性關鍵詞：
#  - p2aa: 0.285
#  - 機臺: 0.215
#  - 破損: 0.607
#  - 電感: 0.313
# 文本 7260 的代表性關鍵詞：
#  - 散熱片: 0.494
#  - 混料: 0.442
#  - 線長: 0.462
# 文本 7261 的代表性關鍵詞：
#  - dimm: 0.237
#  - tray: 0.525
# 文本 7262 的代表性關鍵詞：
#  - pn: 0.220
#  - t00: 0.315
#  - 錫球: 0.631
# 文本 7263 的代表性關鍵詞：
#  - pcb: 0.321
#  - 背板: 0.837
# 文本 7264 的代表性關鍵詞：
#  - p36: 0.385
#  - pin: 0.499
#  - 棧板: 0.290
#  - 產品: 0.225
# 文本 7265 的代表性關鍵詞：
#  - ab: 0.205
#  - dimm: 0.272
#  - pvrxf: 0.212
#  - 異常: 0.203
#  - 短路: 0.326
# 文本 7266 的代表性關鍵詞：
#  - test: 1.000
# 文本 7267 的代表性關鍵詞：
#  - n42733: 0.327
#  - p31: 0.215
#  - rpos23: 0.323
#  - tnv: 0.323
#  - 掉落: 0.249
#  - 撞件: 0.350
#  - 零件: 0.253
#  - 電容: 0.292
# 文本 7268 的代表性關鍵詞：
#  - 系統: 1.000
# 文本 7269 的代表性關鍵詞：
#  - lm: 0.362
#  - ms: 0.204
#  - prr48: 0.205
#  - 溫度: 0.220
# 文本 7270 的代表性關鍵詞：
#  - pca: 0.327
#  - 回焊爐: 0.267
#  - 板邊: 0.356
#  - 殘膠: 0.654
# 文本 7271 的代表性關鍵詞：
#  - 系統: 1.000
# 文本 7272 的代表性關鍵詞：
#  - smt: 0.411
#  - 回焊爐: 0.454
#  - 塑膠: 0.280
#  - 微鏡: 0.278
#  - 破損: 0.469
#  - 零件: 0.316
# 文本 7273 的代表性關鍵詞：
#  - dp1: 0.408
#  - dp3: 0.302
#  - freeport: 0.229
#  - lm: 0.200
#  - nf: 0.416
# 文本 7274 的代表性關鍵詞：
#  - aoi: 0.378
#  - p28: 0.265
#  - pin: 0.335
#  - sff3: 0.201
#  - 大圖: 0.314
#  - 機臺: 0.295
# 文本 7275 的代表性關鍵詞：
#  - fw8: 0.297
#  - glan: 0.281
#  - hvar: 0.265
#  - pcb: 0.301
#  - ref: 0.287
#  - 殘留: 0.200
#  - 殘錫: 0.423
#  - 載具: 0.224
#  - 隱患: 0.254
# 文本 7276 的代表性關鍵詞：
#  - input: 0.283
#  - p36: 0.204
#  - rplr: 0.259
#  - ytm400: 0.267
#  - 光板: 0.245
# 文本 7277 的代表性關鍵詞：
#  - r93r: 0.286
#  - sigsaly: 0.302
#  - xe: 0.269
#  - 異常: 0.204
#  - 缺件: 0.563
#  - 貼片: 0.229
# 文本 7278 的代表性關鍵詞：
#  - y7v6m: 0.215
#  - 剪腳: 0.263
#  - 引腳: 0.354
#  - 插件機: 0.344
#  - 腳長: 0.453
# 文本 7279 的代表性關鍵詞：
#  - ff: 0.281
#  - ff2: 0.722
#  - ng: 0.365
#  - 空焊: 0.210
# 文本 7280 的代表性關鍵詞：
#  - pin: 0.397
#  - s0: 0.305
#  - vgt: 0.412
#  - xu1: 0.629
# 文本 7281 的代表性關鍵詞：
#  - ict: 0.256
#  - n18252: 0.259
#  - scrabbler: 0.265
#  - 外殼: 0.341
#  - 變形: 0.471
# 文本 7282 的代表性關鍵詞：
#  - tray: 0.519
#  - 包裝: 0.365
#  - 破損: 0.313
# 文本 7283 的代表性關鍵詞：
#  - pin4: 0.426
#  - pq4802: 0.825
# 文本 7284 的代表性關鍵詞：
#  - act: 0.207
#  - audio: 0.276
#  - hi: 0.207
#  - lm: 0.401
#  - lo: 0.207
#  - msr: 0.207
#  - name: 0.207
#  - rplr: 0.226
#  - std: 0.207
#  - step: 0.211
#  - test: 0.256
#  - ytm400: 0.234
# 文本 7285 的代表性關鍵詞：
#  - maver: 0.375
#  - p32: 0.226
#  - 品質: 0.218
#  - 殘錫: 0.516
#  - 隱患: 0.310
#  - 點位: 0.252
# 文本 7286 的代表性關鍵詞：
#  - dominor: 0.213
#  - mylar: 0.482
#  - n18256: 0.215
#  - p1: 0.443
#  - p34b: 0.201
#  - 漏貼: 0.482
#  - 粘貼: 0.251
# 文本 7287 的代表性關鍵詞：
#  - bastion: 0.433
#  - d14: 0.418
#  - p26: 0.271
#  - 引腳: 0.305
#  - 機打: 0.334
#  - 目視: 0.223
# 文本 7288 的代表性關鍵詞：
#  - mb: 0.309
#  - p39b: 0.491
#  - 撞件: 0.367
#  - 濾波: 0.310
#  - 規範性: 0.309
#  - 電容: 0.307
# 文本 7289 的代表性關鍵詞：
#  - snow: 0.373
#  - 偏位: 0.375
#  - 座標: 0.430
#  - 識別: 0.329
# 文本 7290 的代表性關鍵詞：
#  - feeder: 0.222
#  - m81628: 0.242
#  - oolo: 0.244
#  - p34: 0.223
#  - 偏位: 0.294
#  - 吸料位置: 0.480
#  - 高四: 0.264
# 文本 7291 的代表性關鍵詞：
#  - test: 1.000
# 文本 7292 的代表性關鍵詞：
#  - cpu: 0.211
#  - cxr46: 0.372
#  - d13: 0.201
#  - low: 0.321
#  - mlk: 0.317
#  - p28: 0.279
#  - sff: 0.208
#  - short: 0.492
#  - ven: 0.280
# 文本 7293 的代表性關鍵詞：
#  - dominor: 0.282
#  - n18256: 0.285
#  - p34b: 0.266
#  - 全圖: 0.285
#  - 撞件: 0.346
#  - 良品: 0.266
#  - 零件: 0.251
# 文本 7294 的代表性關鍵詞：
#  - p39b: 0.261
#  - 上料: 0.266
#  - 上料員: 0.290
#  - 實物: 0.311
#  - 背板: 0.555
#  - 重影: 0.206
# 文本 7295 的代表性關鍵詞：
#  - cpu: 0.222
#  - galior: 0.394
#  - n27946: 0.393
#  - p37: 0.303
#  - short: 0.518
#  - 短路: 0.238
#  - 腳座: 0.349
# 文本 7296 的代表性關鍵詞：
#  - mylar: 0.688
#  - p152: 0.516
#  - 目檢: 0.229
# 文本 7297 的代表性關鍵詞：
#  - aoi: 0.265
#  - galior: 0.250
#  - hdmi: 0.264
#  - n27946: 0.249
#  - p37b: 0.223
#  - 全圖: 0.257
#  - 彈片: 0.538
#  - 良品: 0.240
#  - 變形: 0.364
# 文本 7298 的代表性關鍵詞：
#  - f284y: 0.206
#  - sff3: 0.213
#  - 電阻: 0.462
# 文本 7299 的代表性關鍵詞：
#  - ic: 0.215
#  - p36: 0.297
#  - touch: 0.353
#  - up: 0.348
#  - usb: 0.540
#  - vga: 0.476
# 文本 7300 的代表性關鍵詞：
#  - lm: 0.258
#  - pn: 0.266
#  - 體值: 0.512
# 文本 7301 的代表性關鍵詞：
#  - kyoto: 0.245
#  - mlk2: 0.342
#  - p2ab: 0.238
#  - rn24d: 0.361
#  - rpl: 0.273
#  - sata: 0.344
#  - touch: 0.286
#  - up: 0.283
#  - 折角: 0.382
# 文本 7302 的代表性關鍵詞：
#  - fw8: 0.377
#  - glan: 0.358
#  - hvar: 0.337
#  - p25: 0.265
#  - ref: 0.365
# 文本 7303 的代表性關鍵詞：
#  - test: 1.000
# 文本 7304 的代表性關鍵詞：
#  - ff1: 0.419
#  - ng: 0.214
#  - pin: 0.265
#  - 主板: 0.220
#  - 機臺: 0.311
# 文本 7305 的代表性關鍵詞：
#  - n18252: 0.208
#  - scrabbler: 0.213
#  - 螺絲: 0.785
#  - 鐵件: 0.250
# 文本 7306 的代表性關鍵詞：
#  - p20a: 0.450
#  - pin: 0.245
#  - typec2: 0.216
#  - 爐前: 0.207
# 文本 7307 的代表性關鍵詞：
#  - dimm: 0.274
# 文本 7308 的代表性關鍵詞：
#  - pq5001: 0.804
#  - pq5002: 0.218
#  - 殘留: 0.245
#  - 零件: 0.220
#  - 電阻: 0.265
# 文本 7309 的代表性關鍵詞：
#  - d13: 0.223
#  - dolphin: 0.344
#  - f284y: 0.452
#  - mlk2: 0.426
#  - p28a: 0.433
#  - rpl: 0.341
#  - sff: 0.231
# 文本 7310 的代表性關鍵詞：
#  - n18252: 0.238
#  - scrabbler: 0.244
#  - 微鏡: 0.236
#  - 掉落: 0.264
#  - 油污: 0.395
#  - 空焊: 0.342
#  - 貼裝: 0.238
#  - 電阻: 0.243
#  - 高二: 0.289
# 文本 7311 的代表性關鍵詞：
#  - fw8: 0.232
#  - glan: 0.220
#  - hvar: 0.207
#  - lm: 0.337
#  - ref: 0.225
#  - 空焊: 0.238
#  - 貼裝坐標: 0.326
# 文本 7312 的代表性關鍵詞：
#  - d14: 0.431
#  - fuconn: 0.446
#  - p22: 0.366
#  - sata: 0.409
# 文本 7313 的代表性關鍵詞：
#  - d14: 0.296
#  - p25: 0.214
#  - 不良板: 0.305
#  - 信號: 0.241
#  - 異常: 0.305
#  - 系統: 0.262
#  - 開機: 0.245
#  - 電壓: 0.203
#  - 電量: 0.282
# 文本 7314 的代表性關鍵詞：
# 文本 7315 的代表性關鍵詞：
#  - cpu1: 0.408
#  - d12: 0.225
#  - kyoto: 0.270
#  - p2aa: 0.270
#  - r93r: 0.386
#  - sff: 0.204
#  - short: 0.241
#  - sigsaly: 0.408
#  - xe: 0.364
# 文本 7316 的代表性關鍵詞：
#  - option1: 0.405
#  - p26: 0.240
#  - pin: 0.399
#  - 端子: 0.202
# 文本 7317 的代表性關鍵詞：
#  - lm: 0.282
#  - nf: 0.585
# 文本 7318 的代表性關鍵詞：
#  - 油污: 0.817
# 文本 7319 的代表性關鍵詞：
#  - galior: 0.259
#  - mj39: 0.301
#  - n27946: 0.259
#  - p37b: 0.232
#  - 主板: 0.304
#  - 陰影: 0.303
#  - 鼓包: 0.332
# 文本 7320 的代表性關鍵詞：
#  - dominor: 0.245
#  - n18256: 0.248
#  - p34: 0.365
#  - 殘錫: 0.577
#  - 錫球: 0.291
# 文本 7321 的代表性關鍵詞：
#  - dimm: 0.291
#  - dimm2: 0.579
#  - test: 0.201
#  - 週期: 0.205
#  - 電壓: 0.290
# 文本 7322 的代表性關鍵詞：
#  - cxr46: 0.313
#  - feeder: 0.237
#  - ic: 0.329
#  - low: 0.270
#  - mlk: 0.266
#  - ven: 0.235
#  - 反白: 0.290
#  - 高一: 0.267
# 文本 7323 的代表性關鍵詞：
#  - 系統: 1.000
# 文本 7324 的代表性關鍵詞：
#  - n50s: 0.266
#  - p38a: 0.266
#  - 引腳: 0.270
#  - 料盤: 0.361
#  - 焊點: 0.247
#  - 邊緣: 0.333
# 文本 7325 的代表性關鍵詞：
#  - n26178: 0.229
#  - nebula: 0.206
#  - pan: 0.236
#  - 殘錫: 0.347
#  - 螺絲孔: 0.701
# 文本 7326 的代表性關鍵詞：
#  - 燒錄: 0.485
# 文本 7327 的代表性關鍵詞：
#  - j41: 0.774
#  - 焊點: 0.241
# 文本 7328 的代表性關鍵詞：
#  - fio: 0.203
#  - fuconn: 0.503
#  - 差異: 0.251
# 文本 7329 的代表性關鍵詞：
#  - ff1: 0.626
#  - ms: 0.258
#  - ng: 0.320
#  - p2ab: 0.201
#  - rota: 0.225
#  - rpl: 0.230
#  - 空焊: 0.323

# %%
df['extracted_keywords'] = filtered_results

# %% [markdown]
# ## 輸出結果

# %%
def clean_tfidf_keywords(keyword_string):
    # 分隔關鍵詞，提取括號前的部分
    keywords = [item.split(' (')[0] for item in keyword_string.split(',') if item.strip()]
    # 使用空格拼接關鍵詞
    return ' '.join(keywords)


df['tfidf_keywords'] = df['extracted_keywords'].apply(clean_tfidf_keywords)

# %%
df[df['bill_no'] == 'PDPC20230707004']
# Out:
#               bill_no group_line manufacture_time  \
# 4038  PDPC20230707004        P21         2023/7/7
#
#                                          exception_desc defects_name  \
# 4038  P21B線在生產UNELLA-ALT（L85069-002）機種時，SMT維修發現KL39反...         反白缺件
#
#                                              reason_fix  \
# 4038  1.確認不良為KL39反白缺件不良；_x000D_\n2.查詢不良路由時間為7/7 07:3...
#
#                               qc_suggestion  \
# 4038  更換Feeder後，跟進2H(7/7 9:00-11:00)無相同不良產出
#
#                                                  corpus  \
# 4038  1.確認不良為KL39反白缺件不良； 2.查詢不良路由時間為7/7 07:37-08:32產...
#
#                                                 cleaned  \
# 4038  1   KL39 反白 缺件   2   路由 時間   7           3   高...
#
#                                      extracted_keywords  \
# 4038  alt (0.27), feeder (0.39), p21b (0.28), 反白 (0....
#
#                            tfidf_keywords
# 4038  alt  feeder  p21b  反白  缺件  貼裝坐標  高三

# %%
df.loc[107, 'cleaned']

df.loc[107, 'extracted_keywords']
# Out:
# 'd08 (0.24), x0y8 (0.62), 吸嘴 (0.40), 殘錫 (0.21), 缺件 (0.37), 電阻 (0.22)'

# %%
# 將所有單詞收集到一個列表中，排除空字串，並去重
unique_words = set(
    word
    for keywords in df['tfidf_keywords']
    if isinstance(keywords, str)  # 確保是字串
    for word in keywords.split()  # 用空白分割
)

# 將結果轉回有序列表（可選）
unique_words = sorted(unique_words)

print(unique_words)
# Out:
# ['0201電容', '0402電容', 'a1', 'a6', 'a8', 'a9', 'ab', 'act', 'adl', 'agp', 'ah00', 'ai', 'aj76', 'aj78', 'akali', 'akalir', 'alexandria', 'alt', 'alw', 'amd', 'aoi', 'aos', 'au14', 'aud', 'audio', 'audio1', 'aux', 'b1', 'bastion', 'bat', 'bb4', 'bent', 'bga', 'bios', 'blizzard', 'bohemia', 'bom', 'bti', 'buffalo', 'c1', 'c7', 'ca', 'card', 'card1', 'cersei', 'cezanne', 'cn1', 'con', 'controller', 'cpu', 'cpu0', 'cpu1', 'cr10', 'cr14', 'cr15', 'cres', 'crf7h', 'cxr46', 'd04', 'd05', 'd07', 'd08', 'd09', 'd10', 'd10a', 'd10b', 'd11', 'd12', 'd13', 'd14', 'd2502', 'dali', 'dc48c', 'dell', 'dev', 'dimm', 'dimm1', 'dimm2', 'dimm3', 'dimm4', 'dmyn9', 'dolphin', 'domino', 'dominor', 'dp1', 'dp3', 'dp浮高', 'drive', 'driver', 'dsw', 'dual', 'dy62r', 'e3', 'e49', 'ec', 'ec1', 'ee', 'ej31', 'eldorado', 'elite', 'er', 'esd', 'exp', 'f1', 'f1hc1', 'f209', 'f284y', 'f4y1m', 'fa', 'failed', 'faillocation', 'fan', 'fbt', 'feeder', 'ff', 'ff1', 'ff2', 'ff3', 'ff4', 'fg47g', 'final', 'fio', 'fit', 'freeport', 'front', 'frost', 'fuconn', 'fw', 'fw8', 'fxd80', 'g9', 'galio', 'galior', 'gcy4m', 'glacier', 'glan', 'gnd', 'gnvhc', 'groot3', 'grs', 'hd', 'hdmi', 'hh', 'hi', 'high', 'hled1', 'hold', 'hp', 'hrfmr', 'hsb', 'hsbp', 'hu', 'hvar', 'ib660cx', 'ic', 'ict', 'ids', 'in', 'input', 'int', 'integrated', 'intel', 'ipqc', 'j10', 'j1c3p', 'j2', 'j31', 'j39', 'j40', 'j41', 'j43', 'j46', 'j54d', 'j64', 'j73', 'j74', 'j76', 'j8', 'j81', 'j90', 'j91', 'j94', 'jamie', 'jf43', 'joffrey', 'jonhon', 'juki插件機', 'jwjy', 'k00', 'k1d6x', 'k5c', 'kent5', 'kent6', 'kg', 'kj166', 'kombucha', 'kyoto', 'l09623', 'l75370', 'l76450', 'l76451', 'l76453', 'l77195', 'label', 'lan', 'lj2', 'lm', 'lo', 'loc', 'lot', 'lotes', 'low', 'lpt1', 'lvds', 'm09983', 'm10197', 'm10314', 'm10315', 'm2', 'm44945', 'm450c', 'm45442', 'm81542', 'm81592', 'm81600', 'm81602', 'm81626', 'm81628', 'm86349', 'm86365', 'm87866', 'm90646', 'm98850', 'm99498', 'mac', 'matira', 'matira35', 'matira5', 'maver', 'mb', 'mfg', 'mfr', 'mi', 'min', 'mj39', 'mlk', 'mlk2', 'mosfet', 'ms', 'msr', 'mtp', 'mtx', 'mylar', 'n00', 'n0992', 'n10297', 'n10298', 'n18252', 'n18256', 'n18258', 'n21152', 'n25948', 'n25951', 'n25955', 'n26178', 'n26799', 'n27009', 'n27946', 'n42733', 'n50s', 'name', 'nb168', 'ncp302155hmntwg', 'nd', 'nebula', 'nf', 'ng', 'nile', 'npi', 'nut1', 'nut2', 'ohm', 'on', 'oolo', 'oolong', 'open', 'operation', 'operationr', 'option1', 'option2', 'p0', 'p00', 'p1', 'p152', 'p2', 'p20a', 'p20b', 'p21', 'p21a', 'p21b', 'p22', 'p22b', 'p24', 'p25', 'p26', 'p27', 'p28', 'p28a', 'p28b', 'p29b', 'p2aa', 'p2ab', 'p2b', 'p2h', 'p3', 'p30a', 'p31', 'p31a', 'p31b', 'p32', 'p32a', 'p32b', 'p33a', 'p33b', 'p34', 'p34a', 'p34b', 'p35', 'p35a', 'p35b', 'p36', 'p36a', 'p36b', 'p37', 'p37a', 'p37b', 'p38', 'p38a', 'p38ab', 'p38b', 'p39a', 'p39b', 'p3a', 'p3c', 'p3d', 'p3f', 'p6', 'p60', 'p6y94', 'p72', 'p73', 'p77', 'p8', 'pa', 'pan', 'pca', 'pcb', 'pce297', 'pch', 'pch1', 'pe', 'pfgw', 'pike', 'pin', 'pin1', 'pin4', 'pjdgf', 'pl935', 'plymouth', 'pmepl0', 'pmnjk0', 'pn', 'post', 'power', 'ppid', 'pq', 'pq4701', 'pq4717', 'pq4802', 'pq5001', 'pq5002', 'pq650', 'pqe', 'pqr', 'prr48', 'ps', 'pu100', 'pu210', 'pu220', 'pu230', 'pu280', 'pu4601', 'pu4703', 'pu4803', 'pu5401', 'pu900', 'pvrxf', 'pwm', 'pwr', 'qe', 'qfp', 'qtm460c', 'r1', 'r6pct', 'r93r', 'ray', 'rd', 're', 'ref', 'refresh', 'reno', 'reno2', 'renor', 'renor2', 'repair', 'rf96m', 'rn24d', 'rota', 'rota2', 'rpl', 'rplr', 'rpos23', 'rt', 's0', 's31', 's33', 's34', 'salween', 'sata', 'sb20n61335', 'sb20n61336', 'sb20n61337', 'sb20n61545', 'sb20n61553', 'sb20t22662', 'sb20t22670', 'sb21d13154', 'sb21d13158', 'sb21d13551', 'sc15', 'scrabble', 'scrabbler', 'sd', 'sfc', 'sff', 'sff3', 'short', 'side', 'sierra', 'sigsaly', 'slot1', 'slot3', 'slot4', 'slot5', 'smt', 'snow', 'socket', 'sop', 'sorting', 'sparrow', 'speedtech', 'spi', 'ss', 'ssd', 'sss', 'std', 'step', 'supplier', 'sw', 'sw1', 'sw2', 't00', 'tc', 'team', 'test', 'tmp', 'tnv', 'touch', 'tracer', 't ...

# %%
df[['corpus','tfidf_keywords']].head(20)
# Out:
#                                                corpus  \
# 0   1.現場確認為電感偏位不良，3顆用量，3個位置均有不良產出； 2.查詢不良板路由時間：1/7...
# 1     P31線生產Trinidad，ICT直通率35%左右，嚴重影響生產效率，請幫忙協助解決，謝謝！
# 2   跟進狀況： 1>Lenovo WS機種，SMT貼裝0402電容，反面板邊位置； 2>確認不良...
# 3   OBE抽檢P37B TYWIN（L76450-002）產品，發現MR206&MR206零件燒...
# 4   1.顯微鏡下觀察，不良板功能Pin根部少錫不良（單個功能Pin腳焊盤中間存在"斷層"現象，錫...
# 5   P38線生產IB460CX-M430C-38S，FT測試發現不開機 送FT維修分析燒板 請協...
# 6   跟進狀況： 1、確認不良板外觀PCE230(820uF 2.5V電容)正面浮高,反面腳未出,...
# 7   跟進狀況 1>PTH機打電容，目視零件單邊腳未剪斷（有剪切痕跡）； 2>神目無法Cover此...
# 8   跟進狀況 1>確認Q45位置三極管不貼件，目視殘10PIN QFN反白，確認AOI無法Cov...
# 9   1>確認DIMM2不開機； 2>直接DIMM2量測到DIMM2-148對地無阻值，DIMM2...
# 10  跟進狀況： 1>確認不良正面板邊線路多處刮傷，反面板邊殘黑色異物； 2>查PTH神目記錄無刮...
# 11  1.確認不良為M.2 PCIe.SSD-2短路； 2.查詢不良板印刷時間為06：50—07：...
# 12  D05在生產Maitira 7幾種60K5C時，在壓件核打螺絲工站發現壓件物料(34043Y...
# 13  1,查看不良板，確認M.2 SSD0/SSD1 跨PIN,跨PIN現象 2,SMT使用340...
# 14  跟進狀況 1>SMT貼裝M.2硬盤接口，目視零件頂部膠紙下缺損； 2>顯微鏡確認排除撞件，屬...
# 15  1.現場確認為PC603，PC666 1206電容立碑不良； 2.現場確認印刷，貼裝無異常；...
# 16  1.現場確認為PC295 電容偏位不良； 2.查詢不良板生產時間，為1/15 14:00-1...
# 17  跟進狀況 1>目視多根pin上翹； 2>路由ICT後滯留9H，FT測試前有保護蓋，FT後路由...
# 18  1.現場確認為視頻接口折腳不良； 2.視頻接口有和PCB光板適配,發現pin腳有靠近孔壁現象...
# 19  1不良板查詢路由無異常 2目檢電容PCE216鼓起燒壞 3量測PCE216電容本體無異常 4...
#
#                                  tfidf_keywords
# 0                                        偏位  電感
# 1                     p31  trinidad  效率  直通  重影
# 2            mac  sb20t22670  volga  工具  撞件  端板
# 3             l76450  p37b  ppid  tywin  產品  零件
# 4                               spi  刮刀  鋼網  錫量
# 5                                   p38  燒板  維修
# 6   juki插件機  m10197  p31a  trinidad  壓痕  表面  電容
# 7             buffalo  d08  d11  剪腳  機打  腳長  自動
# 8                      m10197  trinidad  反白  殘件
# 9                                dimm2  ohm  阻值
# 10  ict  kent5  m98850  pca  上線  卡板  板邊  線路  軌道
# 11                            d07  d10  ssd  短路
# 12                         d05  k5c  上線  壓件  螺絲
# 13                       pin  rt  smt  x0y8  結構
# 14             j39  jamie  l76451  p35b  微鏡  膠紙
# 15                       p3d  tywin  條件  雙面  電容
# 16                   final  vi  偏位  腳座  貼裝頭  電容
# 17               cpu  p34b  pin  堆板  幹部  背板  螺絲
# 18                                  pin  rt  折角
# 19                                 p34b  異常  電容

# %%
df.to_excel('PDCS_TFIDF.xlsx', index=False)

# %% [markdown]
# ## Apriori

# %%
import pandas as pd


df = pd.read_excel('PDCS_TFIDF.xlsx')


df['defects_name'] = df['defects_name'].fillna('')
df_tmp = df[df['defects_name'].str.contains('缺件')].reset_index(drop=True).copy()

# %%
df_tmp[df_tmp['bill_no'] == 'PDPC20230707004']
# Out:
#              bill_no group_line manufacture_time  \
# 117  PDPC20230707004        P21         2023/7/7
#
#                                         exception_desc defects_name  \
# 117  P21B線在生產UNELLA-ALT（L85069-002）機種時，SMT維修發現KL39反...         反白缺件
#
#                                             reason_fix  \
# 117  1.確認不良為KL39反白缺件不良；_x000D_\n2.查詢不良路由時間為7/7 07:3...
#
#                              qc_suggestion  \
# 117  更換Feeder後，跟進2H(7/7 9:00-11:00)無相同不良產出
#
#                                                 corpus  \
# 117  1.確認不良為KL39反白缺件不良； 2.查詢不良路由時間為7/7 07:37-08:32產...
#
#                                                cleaned  \
# 117  1   KL39 反白 缺件   2   路由 時間   7           3   高...
#
#                                     extracted_keywords  \
# 117  alt (0.27), feeder (0.39), p21b (0.28), 反白 (0....
#
#                           tfidf_keywords
# 117  alt  feeder  p21b  反白  缺件  貼裝坐標  高三

# %%
# Step 1: 過濾掉空字串
df_tmp = df[df['tfidf_keywords'].str.strip() != ''].copy()

# Step 2: 將每個非空字串以空白分割，轉換成詞列表
df_tmp['tfidf_keywords'] = df_tmp['tfidf_keywords'].fillna('')
df_tmp['tfidf_keywords'] = df_tmp['tfidf_keywords'].apply(lambda x: x.split())


transactions = df_tmp['tfidf_keywords'].tolist()
transactions = [t for t in transactions if t]

# %%
print(len(transactions))
transactions 

#相機
# Out:
# 7296
# [['偏位', '電感'],
#  ['p31', 'trinidad', '效率', '直通', '重影'],
#  ['mac', 'sb20t22670', 'volga', '工具', '撞件', '端板'],
#  ['l76450', 'p37b', 'ppid', 'tywin', '產品', '零件'],
#  ['spi', '刮刀', '鋼網', '錫量'],
#  ['p38', '燒板', '維修'],
#  ['juki插件機', 'm10197', 'p31a', 'trinidad', '壓痕', '表面', '電容'],
#  ['buffalo', 'd08', 'd11', '剪腳', '機打', '腳長', '自動'],
#  ['m10197', 'trinidad', '反白', '殘件'],
#  ['dimm2', 'ohm', '阻值'],
#  ['ict', 'kent5', 'm98850', 'pca', '上線', '卡板', '板邊', '線路', '軌道'],
#  ['d07', 'd10', 'ssd', '短路'],
#  ['d05', 'k5c', '上線', '壓件', '螺絲'],
#  ['pin', 'rt', 'smt', 'x0y8', '結構'],
#  ['j39', 'jamie', 'l76451', 'p35b', '微鏡', '膠紙'],
#  ['p3d', 'tywin', '條件', '雙面', '電容'],
#  ['final', 'vi', '偏位', '腳座', '貼裝頭', '電容'],
#  ['cpu', 'p34b', 'pin', '堆板', '幹部', '背板', '螺絲'],
#  ['pin', 'rt', '折角'],
#  ['p34b', '異常', '電容'],
#  ['d05', 'dimm', 'dimm1', 'jwjy', '技能', '插件機', '數量', '目檢'],
#  ['孔徑', '直徑'],
#  ['m09983', 'pike', 's31', '偏位', '電感'],
#  ['hu', 'pe', '板子', '花板', '設計', '變形', '貼片機'],
#  ['aoi', 'spi', '偏位', '錫膏印刷', '錫量'],
#  ['p34a', '幹部', '技能', '撞件', '散熱片', '機台', '濾波'],
#  ['audio', 'd07', 'repair', '處理'],
#  ['ng', 'sff', '偏位', '更換', '設備異常', '電容'],
#  ['0402電容', 'refresh', 'salween', 'sb20t22662', '微鏡', '貼裝', '零件'],
#  ['j41', 'p31', 'pike', '品質', '效率', '重影'],
#  ['aoi', '偏位', '偶發性', '吸料', '濾波', '電容', '高三'],
#  ['d05', 'p1', 'sfc', '目檢'],
#  ['j94', 'tywin', '聯基', '變形'],
#  ['hdmi', 'kent5', 'm98850', 'p3a', 'power', '撞件', '表量'],
#  ['e49', 'm81542', 'p37a', 'pin', 'reno2', '短路'],
#  ['cr15', '板子'],
#  ['0402電容', 'aoi', 'm09983', 'pike', 'smt', '偏出', '貼裝'],
#  ['m09983', 'p31a', 'pike', '產品'],
#  ['d10b', 'repair', 'type', 'typec1', '刮刀'],
#  ['ec1', 'pin', '偏位', '引腳', '識別', '貼片機'],
#  ['d08', 'd10b', 'pin', 'wlan', '機臺', '異常', '週期'],
#  ['con', 'uf', '原物料', '電容'],
#  ['p34a', 'smt', '微鏡', '板作業', '設備貼裝', '貼片', '雙面', '電阻', '高一'],
#  ['d05', 'dimm', 'dimm1', 'k5c'],
#  ['bent', 'cpu', 'd10a', 'pin', '腳座'],
#  ['貼裝參數'],
#  ['d04', 'm81592', 'scrabble', '板邊', '機台'],
#  ['d04', 'hu', 'pin', '板邊'],
#  ['u1', '壓件', '貼裝頭', '高一'],
#  ['c1', '阻值', '體值'],
#  ['固定', '料盤', '電池'],
#  ['con', 'pn', '引腳', '插件機', '電容'],
#  ['d04', 'npi', '螺絲', '變形', '鐵件'],
#  ['d09', 'd10', 'dy62r', 'feeder', 'repair', '反白'],
#  ['kent5', 'm98850', 'p3a', '上料', '上料員', '品質', '背板', '隱患'],
#  ['kent5', 'm98850', '引腳', '插件機', '松下', '機打', '腳長', '電容'],
#  ['fbt', 'p32b', 'refresh', 'salween', 'sb20t22662', 'smt', '機台', '貼裝', '電容'],
#  ['d04', 'd09', 'm81592', '插件機'],
#  ['d10b', 'repair', 'smt', '偏位'],
#  ['d10b', 'repair', '偏位', '吸料位置', '跑偏'],
#  ['d10a', 'repair', 'usb3s3', '空焊', '處理'],
#  ['設計', '貼裝'],
#  ['ff', 'fw', 'hdmi', '版本'],
#  ['剪腳', '插件機'],
#  ['d10a', '對板', '端板', '網絡', '零件'],
#  ['u4003'],
#  ['j41', 'joffrey', 'l76453', 'p35b', '引腳', '焊點', '維修'],
#  ['d04', 'd09', 'j94', '半成品', '變形'],
#  ['s34', '吸料位置', '設備異常', '電感'],
#  ['kent5', 'm98850', '引腳', '機打', '漏點', '焊點', '雙面', '電容'],
#  ['oolong', 'xu1', '刮刀', '錫膏'],
#  ['d05', 'k5c', '印刷機', '更換', '溫度', '錫膏'],
#  ['cpu', 'd07', '偏位', '吸料位置', '腳座', '跑偏', '電容', '高五'],
#  ['cpu', 'm81542', 'ray', 'reno2', 'xu1', '腳座', '錫球'],
#  ['fw', 'u7', '版本'],
#  ['dimm1', 'joffrey', 'l76453', 'pin'],
#  ['cpu', 'hu', '撞件', '螺絲'],
#  ['cpu', 'p38', 'pin', '腳座'],
#  ['m2', 'm81542', 'mj39', 'reno2'],
#  ['aj78', 'p3'],
#  ['cpu', 'p38a', 'pin', 'ppid', '產品'],
#  ['cpu', 'pin', '機臺', '腳座'],
#  ['fio', 'p3f', 'spi', 'v2', '生產'],
#  ['a6', 'aoi', 'm44945', '作業員', '對板', '電容'],
#  ['d10a', '偏位', '拖盤', '擦板', '時作業', '缺件', '高三'],
#  ['d05', 'matira5', '動作', '板邊', '連片'],
#  ['aoi', 'd09', 'dy62r', 'pin', 'wlan', '數量', '更換'],
#  ['d09', 'dy62r', 'pin', '數量', '更換', '消失', '焊點'],
#  ['fbt', 'mac', 'pin', '塑膠', '排針', '探針', '板角', '破損', '零件'],
#  ['aud', 'j39', 'joffrey', 'l76453', 'p35', '空焊'],
#  ['pin', '機臺'],
#  ['fbt', 'm10314', 'p33b', 'sierra', '插拔'],
#  ['cpu', 'l76450', 'p37a', 'socket', 'tywin', 'uf', '偏位', '濾波'],
#  ['d05', 'pin', 'sorting', '上料', '上料員'],
#  ['cpu0', 'driver', 'joffrey', 'p35', 'pn', 'pu210', 'short', '電壓'],
#  ['j41', '空焊'],
#  ['m10197', 'p31a', 'usb', '外殼', '板角', '破損', '網絡', '零件', '電感'],
#  ['k5c', '偏位', '刮刀', '單片', '電感'],
#  ['aoi', '偏位', '濾波', '電容'],
#  ['d04', 'j76', 'repair', '泛一', '貼裝'],
#  ['aoi', 'd08', 'ict', 'repair', '偏位', '吸料位置', '跑偏', '高一'],
#  ['cpu1', 'eldorado', 'pin', '異常', '程度', '電壓', '電量'],
#  ['hu', 'p31', 'pe', '散熱片', '模組', '機台', '生產品質', '重影'],
#  ['aoi', 'kent6', 'l75370', 'p3a', '不良板'],
#  ['d04', '短路', '錫膏', '鏈速'],
#  ['con', 'd10b', '插件機', '電容'],
#  ['reno2'],
#  ['d08', 'x0y8', '吸嘴', '殘錫', '缺件', '電阻'],
#  ['d10a', 'widowmaker', '插件機', '電容'],
#  ['d09', 'dy62r', 'sorting', 'usb', '原物料', '變形'],
#  ['cpu', 'ict'],
#  ['pin', 'wlan', '機臺'],
#  ['type', '識別'],
#  ['堆板', '投板'],
#  ['fbt', 'm10197', 'p31a', 'trinidad', '零件'],
#  ['cres', 'd04', '撞件'],
#  ['s34', '偏位', '目檢'],
#  ['j8', 'type'],
#  ['aud', 'nut2', 'p3d', 'tywin', '吸嘴', '螺柱'],
#  ['p3a', '品質', '背板', '隱患'],
#  ['j31', 'juki插件機', 'l76450', 'pin', 'tywin', '折腳'],
#  ['j39', 'j40', 'trinidad'],
#  ['p6', 'pcb', '排針', '白色', '載具'],
#  ['aud', 'nut2', '偏位', '目檢'],
#  ['ict', 'm81592', 'scrabble', 'xu1'],
#  ['m2', 'm81542', 'mj39', 'reno2', '塑膠', '時作業', '破損'],
#  ['aoi', 'm81542', 'p37a', 'reno2', 'uf', '電容'],
#  ['d12', 'dimm2', 'mtx', 'n0992', 'rota'],
#  ['d08', 'd11', 'freeport', 'x0y8', '上料', '上料員', '泛用機'],
#  ['d07', 'usb', '插件機', '目檢'],
#  ['aoi', 'm81600', 's34', '撞件', '網絡', '電容'],
#  ['s34', '電容'],
#  ['buffalo', 'x0y8', '腳座', '零件', '電池'],
#  ['彈片', '池座', '電池'],
#  ['aoi', 'int', 'sfc', 'x0y8', '全圖', '堆板', '破損'],
#  ['識別'],
#  ['塑膠', '插卡', '破損', '零件'],
#  ['工具', '空焊', '變形', '載具'],
#  ['p152', 'pin', '膠紙'],
#  ['aoi', 'd10a', 'feeder', '反白', '技能', '時點'],
#  ['dali', 'dimm', 'fbt', 'p34b', '投板', '貼裝', '電容'],
#  ['dali', 'hh', 'mfr', 'p34a', 'pca', '漏銅'],
#  ['smt', '殘件', '設備貼裝', '電阻'],
#  ['kent6', 'l75370', '偏位', '爐前', '零件'],
#  ['eldorado', 'ict', 'p32', 'v2'],
#  ['d05', 'dell', 'k5c', '噴霧', '排針', '流量', '零件'],
#  ['cpu', 'm81542', 'reno2'],
#  ['ids', 'p34a', '偏位'],
#  ['p38', 'pu100', '偏位', '貼裝頭'],
#  ['p72', '殘件'],
#  ['d09', 'd10', 'dy62r', 'sff', '破損'],
#  ['0402電容', 'j91', 'pin', 'usb'],
#  ['p34', 'team', 'type', '重影'],
#  ['dimm', '短路', '錫膏'],
#  ['a8', 'm86365', 'p36b', '包裝', '彈片', '變形'],
#  ['fio', 'j90', 'p3f', 'usb', '焊點'],
#  ['d10a', '目檢', '螺絲'],
#  ['刮刀'],
#  ['hu', 'ng', 'pe', '破損', '電感'],
#  ['0402電容', 'fbt', 'm81542', 'p33a', 'reno2', 'smt', '插件機', '板作業', '自動'],
#  ['lot', 'supplier', 'usb', '電壓'],
#  ['d10b', 'd11', 'option2', 'pin', '固定', '空焊'],
#  ['d07', 'd10', 'dimm', 'dimm1', '引腳', '焊點', '目視'],
#  ['cpu', 'mac', 'pin'],
#  ['dimm', 'dimm4', '插件機', '異常'],
#  ['p33b', '塑膠', '破損', '零件'],
#  ['d10a', 'dimm1', 'tray', '異常'],
#  ['d07', 'wlan', '堆板', '插拔', '處理'],
#  ['feeder', 'p36', '供料不穩', '電感'],
#  ['保養', '螺絲孔', '錫珠'],
#  ['p3a', 'usb', '彈片', '投板', '舌片', '變形'],
#  ['kent5', 'p3a', '原物料', '品質', '板子', '機打', '異常', '隱患', '電容'],
#  ['插件機', '機打', '設計', '電容'],
#  ['d08', 'dy62r', '保養', '缺件'],
#  ['type', '漏點'],
#  ['d10', 'd10a', '散熱片', '膠紙'],
#  ['0402電容', 'sb20n61337', 'smt', '維修'],
#  ['dy62r', '擦板', '皮帶', '缺件'],
#  ['d08', '機臺', '蓋子', '表面'],
#  ['vi', '偏位', '貼裝', '電阻'],
#  ['p3d', '上料員'],
#  ['fg47g', '螺絲', '鐵件'],
#  ['kj166', 'sd'],
#  ['intel', 'usb'],
#  ['d10a', 'pin', 'ssd', '機臺'],
#  ['e49', '吸料', '排針', '空間', '缺件', '進料'],
#  ['groot3', 'team', '偏位', '吸料位置', '料位跑偏', '高五'],
#  ['feeder', 'm10197', 's31', 'trinidad', 'y5', '供料不穩', '反白', '時點'],
#  ['fan', 'vendor'],
#  ['p3c', '不良板', '腳座', '花板', '軌道', '錫膏', '高一'],
#  ['m09983', 'pike', 's31', 'team', '偏位', '效率', '重影'],
#  ['r6pct', '漏貼'],
#  ['受力', '空焊', '電阻'],
#  ['料槽'],
#  ['d04', 'm81592', 'pin', 'repair', 'xu1', '幹部', '機臺', '異常', '腳座'],
#  ['p1', '壓塊', '機台', '間距'],
#  ['pin', 'short', 'vcore', '燒板', '空焊', '電壓'],
#  ['aj76', 'open', '線量'],
#  ['d07', 'pin', 'sff3', 'wlan', '撞件'],
#  ['d11', 'esd', 'pqe', 'u1', '燒錄'],
#  ['吸嘴', '板面', '電容'],
#  ['cr14', 'cr15', 'd09', '偏位', '時點', '設備貼裝'],
#  ['pin', 'pwr', 'sw', '撞件', '流水', '程式'],
#  ['j94', 'p3d', 'tywin', 'vi'],
#  ['ee', 'm09983', 'p31b', 'pike', 'vi', '電阻', '高一'],
#  ['料槽'],
#  ['ict', 'p33a', '板邊', '濾波', '背板', '電容'],
#  ['cpu', 'pin', 'xu1', '腳座'],
#  ['p33a', 'twr', 'uf', 'z2', '掉落', '插件機', '機打', '零件', '電容'],
#  ['cpu', 'd05', 'fan', 'jwjy', 'pin', '機臺', '端子'],
#  ['aoi', '檢測', '短路', '鋼網', '電容'],
#  ['aoi', 'd08', 'pin', 'ssd', '插卡', '插拔'],
#  ['aoi', 'nf', 'pcb', '容值', '機臺', '電容'],
#  ['d05', 'k5c', '螺絲', '鐵件'],
#  ['n0992', '吸嘴', '殘留', '缺件', '膠紙'],
#  ['controller', 'cpu', 'dsw', 'x0y8', '偏位', '圖片', '電流'],
#  ['label', '漏貼', '網絡'],
#  ['buffalo', 'd08', 'd11', 'rt', 'x0y8', '螺絲', '鐵件'],
#  ['dimm2', '投板', '撞件', '時作業', '殘留', '端板', '貼片', '軌道', '零件'],
#  ['cpu', 'ict', 'scrabble'],
#  ['groot3', 'm99498', 'p3c', 'pcb', '燒板'],
#  ['card1', 'sd', '變形'],
#  ['feeder', 'kent5', 'm98850', '保養', '偏位', '反白', '更換', '高四'],
#  ['type'],
#  ['d10a', 'dolphin', 'feeder', 'hd', '供料不穩', '缺件'],
#  ['m2', 'p38', 'sb20n61337', '空焊'],
#  ['d05', 'fio', 'matira35', 'sop', '爐前'],
#  ['m81542', 'reno2', 'vj69'],
#  ['a6', 'er', 'ic', 'm44945', 'p36a', '產品'],
#  ['con', 'd08', 'on', 'x0y8', '上料員', '封裝', '電容'],
#  ['s33', 'smt', 'twr', 'z2', '偏位'],
#  ['feeder', 'sb20n61335', '供料不穩', '反白'],
#  ['l76450', 'p37', 'pin', 'tywin', '排針'],
#  ['l76450', 'p1', 'p37a', 'tywin', '維修', '腳座', '電源'],
#  ['壓件', '電壓'],
#  ['dmyn9', 'sfc'],
#  ['aoi', 'd05', 'jwjy', '異常', '短路'],
#  ['d08', 'x0y8', '速度', '電感'],
#  ['buffalo', 'd09', 'd11', 'fxd80', 'up', 'usb3s3', '打膠', '紙板', '貼裝坐標'],
#  ['pcb', 'r6pct', '線路'],
#  ['d10a', 'r1', 'usb', '殘留', '鑷子'],
#  ['pn', 'u100'],
#  ['aud', 'cersei', 'hp', 'p34', '燒板'],
#  ['p3d', '不良板', '板面', '棧板'],
#  ['l77195', '偏位', '貼裝', '電容'],
#  ['nut1', 'sb20n61337', '吸料位置', '螺絲柱', '跑偏'],
#  ['d10a', 'mtx', 'r6pct', 'tracer', '偏位'],
#  ['bent', 'buffalo', 'cpu', 'd08', 'd11', 'pin', 'x0y8', '自動'],
#  ['sb20n61337', 'type'],
#  ['j41', 'joffrey', 'l76453', 'p35b', '焊點'],
#  ['aoi', 'd07', 'fio', 'matira35', 'pin', '棧板'],
#  ['bent', 'cpu', 'l77195', 'p34a', 'pin', '幹部', '技能', '時作業', '邊緣'],
#  ['ee', 'm450c', 'p38b', '偏位'],
#  ['d08', 'sfc', '電池'],
#  ['料帶', '更換', '異常'],
#  ['ec', 'ec1', '阻值', '電阻'],
#  ['引腳', '識別'],
#  ['m09983', 'p31b', 'pike', 'usb', '信號', '焊點', '維修', '零件'],
#  ['d09', 'fxd80', 'option1', 'option2', '空焊', '貼裝高度'],
#  ['ai', 'input', 'jamie', 'p35', '堆板', '維修'],
#  ['d10a', 'kyoto', '偏位', '貼裝'],
#  ['d05', 'matira', 'tvw7j', 'xl', '偏位'],
#  ['cersei', 'p34b', 'pch', '撞件', '散熱片', '時作業', '零件'],
#  ['j76', 's31', 'team', '跑偏'],
#  ['ict', 'mj39', '不良板', '撞件', '時作業', '泡棉', '流線', '濾波', '轉板', '零件', '電容'],
#  ['0402電容', 'p38b', 'sb20n61337', '偏位', '吸嘴'],
#  ['cpu', 'driver', 'dsw', 'pin1', 'pin4', 's0', '信號'],
#  ['b1', 'f1hc1', '空焊'],
#  ['f1', 'usb', '彈片', '插拔'],
#  ['feeder', 'p32', 'sb20t22662', '供料不穩', '偏位', '電阻'],
#  ['d09', 'post', 'ssd'],
#  ['m99498', '板邊', '機台', '殘留', '毛刺'],
#  ['d10b', 'n0992', 'open', 'pcb', 'pq', '漏銅', '覆蓋'],
#  ['nile', 'p32b', '產品', '螺絲孔'],
#  ['buffalo', 'd11', '偏位', '電感'],
#  ['jamie', 'p35', 'post', '吸料位置'],
#  ['p38', 'sb20n61335', 'type', '貼裝坐標'],
#  ['d08', 'ee', 'x0y8', '焊點', '螺柱', '螺絲柱', '設備貼裝'],
#  ['power', 'sb20t22670', 'volga', '技能', '效應', '目檢', '空焊', '腳空', '載具', '陰影'],
#  ['hd', 'pin', 'ssd', 'troy', '整體', '機臺', '程度'],
#  ['d10a', 'd12', 'f1hc1', 'kyoto', '外力', '掉落'],
#  ['j39', 'pike', 'v2'],
#  ['m81542', 'reno2', 's34', 'usb', '泛三'],
#  ['0402電容', 'd07', 'kyoto', '偏位', '反白', '吸嘴', '目檢'],
#  ['板邊', '爐前', '空焊'],
#  ['pcb', '撞件'],
#  ['固定', '空焊'],
#  ['偏位', '短路', '鑷子'],
#  ['feeder', 's31', '供料不穩', '偏位', '高四'],
#  ['s31', '偏位', '泛二', '爐前', '零件'],
#  ['m81542', 'reno2', '偏位'],
#  ['xc300', '撞件', '目檢'],
#  ['d09', 'd11', 'fxd80', '偏位', '貼裝高度'],
#  ['jamie', 'p35b', '撞件', '板邊', '維修', '貼片', '零件', '電容'],
#  ['j39', 's31', 'ssd', 'team', '空焊', '貼裝壓力'],
#  ['mb', '偏位', '泛一', '程式', '花板', '貼裝', '貼裝頭'],
#  ['p32', 'sb20t22662', 'smt', '偏位', '目檢', '處理'],
#  ['dc48c', 'ec1', 'qfp'],
#  ['卡板', '回焊爐', '板子', '爐前', '線體', '軌道'],
#  ['m86349', 'p3d', 'reno', '電感'],
#  ['fbt', 'j8', 'p3d', 'type', 'x3', '上線'],
#  ['aoi', 'd08', 'pin', 'x0y8', '折腳', '板邊', '機打'],
#  ['pu900', '偏位'],
#  ['f209', 'j94', 's33', 'twr', 'z2', '同廠', '泛用機', '週期'],
#  ['aoi', 'd09', 'fxd80', 'r1', '折腳', '機打', '程式'],
#  ['smt', '偶發性', '異常', '目檢', '貼裝', '雙面', '電容'],
#  ['xc300', '干涉', '殘錫', '網卡', '錫膏'],
#  ['錯料'],
#  ['cpu', 'd10b', 'fan', 'n0992', '原物料', '髒污', '高工'],
#  ['目檢', '腳長'],
#  ['空焊'],
#  ['a8', 'er', 'feeder', 'm86365', '反白'],
#  ['d10b', 'r6pct', 'tracer', '板作業'],
#  ['d07', 'd12', 'kyoto', '偏位', '設備貼裝', '貼裝坐標'],
#  ['ict', 'm81628', 'oolo', 'p33a', '撞件', '貼片', '零件', '電阻'],
#  ['dy62r', '殘膠', '膠紙', '螺柱', '螺絲柱'],
#  ['spi', '偏位', '板子', '程式'],
#  ['ib660cx', 'n50s', 'pa', 'pin', 'pin1', 'sb20n61335', 'socket'],
#  ['fio', 'matira35', '散料', '料盤'],
#  ['nb168', '插件機', '電容'],
#  ['pn', '容值', '阻值'],
#  ['d11', 'smt', '產品'],
#  ['d04', 'slot1', '空焊'],
#  ['fg47g', 'nf', '程式', '錯料'],
#  ['j73', 'kent6', 'l75370'],
#  ['fbt', 'hdmi', '刮刀', '壓力', '短路'],
#  ['ib660cx', 'ic', 'p38a', 'pa', 'ppid', 'sb20n61337', '產品'],
#  ['aj78', 'groot3', 'm99498', '電容'],
#  ['dimm', 'dimm1', 'n50s', 'p38b', 'sb20n61335', '單根', '折腳'],
#  ['j41', 'u100', '鋼網'],
#  ['ib660cx', 'j41', 'p38', 'sb20n61336', 'ytm400'],
#  ['u100'],
#  ['domino', 'feeder', 'm81600', 's33', '偏位', '花板'],
#  ['a6', 'feeder', 'ic', 'm44945', '供料不穩', '偏位', '貼裝', '高四'],
#  ['sb20n61337', '外力', '板作業', '電容'],
#  ['j43', 's31', '爐前'],
#  ['d09', 'd11', 'fxd80', 'option1', 'rt', '空焊'],
#  ['aoi', '偏位', '偏出', '技能', '整體', '目檢', '識別'],
#  ['mb', 'p33a', '不良板', '撞件', '濾波', '電容'],
#  ['cpu1', 'd07', '偏位', '固定', '掉落', '相機', '零件'],
#  ['d09', 'fxd80', '大圖', '鐵件'],
#  ['條件', '雙面', '電容'],
#  ['塑膠', '外殼', '裂痕', '零件', '電感'],
#  ['s33', '板子'],
#  ['aoi', 'smt', '不良板', '信號', '半成品'],
#  ['joffrey', 'l76453', 'p2', 'pin', 'sorting', '白色', '電源'],
#  ['a8', 'er', 'feeder', 'usb', '吸料位置', '貼裝', '進料'],
#  ['容值', '流線', '電容'],
#  ['ib660cx', 'ic', 'p38a', 'pa', 'sb20n61337', 'xc300', '撞件'],
#  ['adl', 'd10b', 'mtx', 'r6pct', 'tracer', '擦板', '缺件', '載具'],
#  ['燒錄', '網絡'],
#  ['0402電容', 'a8', 'm86365', '機臺'],
#  ['mosfet', 'supplier', '內存', '短路', '電壓'],
#  ['s33', '偏位', '泛一', '貼裝頭'],
#  ['p3f', '主板', '撞件', '板邊', '泡棉'],
#  ['l77195', 'tywin', 'y5', '反白'],
#  ['aoi', 'f1hc1', '偏位', '全圖', '貼裝'],
#  ['d07', 'dc48c', 'ee', '不良板', '端板'],
#  ['0402電容', 'input', 'jamie', 'l76451', 'p35', '偏出', '堆板', '投板', '零件'],
#  ['m2', 'matira', 'u1', '生產', '短路', '空焊'],
#  ['alw', 'short', '壓件', '燒板', '電壓'],
#  ['pcb', 'smt', '空焊', '貼裝', '雙面'],
#  ['d08', 'd10', 'dp1', 'mlk', 'sff'],
#  ['m2', 'matira', 'u1', '生產', '短路', '空焊'],
#  ['機臺'],
#  ['d05', '擦板', '螺絲', '螺絲孔', '鋼板'],
#  ['cpu', 'driver', 'mosfet', 'on', 'pin1', 'pin4', 'side'],
#  ['ict', 'j91', 'kent6', 'l75370', '撞件', '板角', '自動化', '零件'],
#  ['d07', 'dc48c', 'ppid'],
#  ['eldorado', 'm10315', 'pq650', '反白', '識別'],
#  ['aud', 'j39', 'p35'],
#  ['d07', 'front', 'tc', 'touch', 'up', '異常'],
#  ['cersei', 'ee', 'p34b', '偶發性', '微鏡', '電容'],
#  ['au14', 'l75370', '偏位', '短路'],
#  ['d08', '流線', '螺絲孔'],
#  ['d10a', 'pwr', 'sw1', 'wxmx', '塑膠', '破損'],
#  ['jonhon', 'p3', 'sop', '極性'],
#  ['0402電容', 'a6', 'er', 'm44945', 'p36b', '偏位', '偏出', '機臺', '線路', '貼裝', '高一'],
#  ['0402電容', 'sorting', '堆板', '掉落', '撞件'],
#  ['pn', 'short', 'vccia1', 'vin', '不良板', '電壓'],
#  ['au14', 'kent6', 'l75370', '偏位'],
#  ['feeder', 'vi', '供料不穩', '電容'],
#  ['l76450', 'tywin', '焊點'],
#  ['dc48c', 'ec1', 'qfp'],
#  ['feeder', 'n50s', 'p38', 'p38a', 'pa', 'sb20n61335', '供料不穩', '反白'],
#  ['j8', 'm86349', 'pin', 'reno', '光板', '固定'],
#  ['dimm', 'dimm4', 'jamie', 'p35b', '單根', '折腳', '焊點'],
#  ['cersei', 'p34a', '回焊爐', '濾波', '網絡', '腳座', '設備貼裝', '電容'],
#  ['kombucha', 'm81626', 'p33a', '堆板', '板子'],
#  ['d10a', 'd12', '品質', '處理', '螺絲', '隱患'],
#  ['d10b', '偶發性', '插件機', '異常', '電容'],
#  ['aoi', 'ppid', '不良板', '流線'],
#  ['cpu', 'p36', '單位'],
#  ['d08', 'd10', 'wlan', '偏位', '吸嘴', '貼片機'],
#  ['bohemia', 's31', 'team', '偏位', '印刷機', '直通', '隱患'],
#  ['bohemia', 'dimm', 's31', 'team', '空焊', '隱患'],
#  ['agp', 'sop', '效應'],
#  ['cpu', 'p37a', 'pin', 'sb20n61337', 'socket', '背板', '螺絲'],
#  ['d07', 'd11', 'repair', '保養', '偏位', '回焊爐', '結構', '週期', '電感'],
#  ['aj76', 'm86349', 'p3d', '品質', '效率'],
#  ['cpu', 'p31b', 'pin', '時作業'],
#  ['cpu', 'fbt', 'ib660cx', 'ic', 'pa', 'pin', '幹部'],
#  ['p8', '破損', '自動'],
#  ['dali', 'dimm2', '泛用機'],
#  ['d08', 'hp', 'pcb', 'supplier', '漏銅', '線路', '表面', '覆蓋'],
#  ['rpl', '偏位', '整體', '設備貼裝'],
#  ['m86349', 'p3d', 'reno', '撞件', '板作業'],
#  ['rpl', '反白', '設備貼裝'],
#  ['ec1', 'tray', '空焊'],
#  ['j90', 'j91', '功能pin', '原物料'],
#  ['d10a', 'pcb', 'wxmx', '包裝', '板子', '目檢', '維修'],
#  ['p00', 'sw2', 'vendor'],
#  ['card', 'd11', 'd12', 'dolphin', 'sd', '空焊'],
#  ['l77195', 'p34b', '偶發性', '容值', '撞件', '電容'],
#  ['feeder', 'intel', 'mb', '反白', '晶振'],
#  ['bent', 'cpu', 'd10b', 'pin', 'r6pct', '單根', '背板'],
#  ['m98850', 'usb', '定位腳', '料帶'],
#  ['front', 'tc', '短路', '錫膏', '零件'],
#  ['d05', 'k5c', '回焊爐', '殘留', '濾波', '缺件', '腳座', '設備貼裝', '零件', '電容'],
#  ['feeder', 'm450c', 'p38', '反白'],
#  ['pcb', 'sw'],
#  ['cpu', 'driver', 'dsw', 'ic', 'on'],
#  ['card', 'dolphin', 'sd', '爐前'],
#  ['d08', '安裝', '機臺', '異常', '電池'],
#  ['p3c', '燒板'],
#  ['dmyn9', 'npi', 'pin', 'pwr'],
#  ['s33', 'usb', '設備異常', '貼裝坐標'],
#  ['esd', 'ic', 'kent6', 'l75370', 'pin', '殘件'],
#  ['usb', '破損', '舌片'],
#  ['d07', 'pq5001', 'pq5002', 'qe', 'sff3', '爐溫'],
#  ['a8', 'm86365', '鋼網', '錫膏'],
#  ['usb', '舌片'],
#  ['u1', '偏位', '拖盤'],
#  ['d08', 'pin', 'x0y8', '不良板', '更換', '機臺'],
#  ['j90', 'j91', 'kent6', '空焊'],
#  ['ids', 'l09623', 'nut1', 'nut2', 'p32', 'team', 'trinidad', '螺絲'],
#  ['ib660cx', 'm450c', 'p38', 'vb'],
#  ['m09983', 'p31a', 'pike', '焊劑', '空焊', '載具'],
#  ['dimm', 'kent6', 'l75370', 'pan', 'pcb', '清洗', '焊劑'],
#  ['0402電容', 'l76450', 'tywin', '偏位', '貼裝'],
#  ['pqe', '錯料'],
#  ['aj76', 'kent5', 'm98850', 'p37b', 'pca', '焊劑'],
#  ['d10b', 'grs', 'lotes', 'widowmaker', '效率', '背板', '良率', '螺紋', '鐵件', '響產線'],
#  ['d05', 'juki插件機', 'tvw7j', '不良板', '電容'],
#  ['joffrey', 'l76453', 'pin', 'wlan', '單根', '機臺', '金手指'],
#  ['d09', '上料員', '包裝', '白色', '電源', '髒污'],
#  ['d05', 'jwjy', '塑膠', '板子', '機臺', '破損', '蓋子', '表面'],
#  ['d05', 'jwjy', 'repair', 'smt', '偏位'],
#  ['d09', 'sb20n61337', '外力', '引腳', '板子', '變形', '電容'],
#  ['d05', 'jwjy', 'repair', '偏位', '爐前', '短路', '貼裝'],
#  ['aoi', 'd09', 'pch', 'u4', '撞件', '電容'],
#  ['m2', 'p38', 'sb20n61337', '空焊', '處理'],
#  ['cersei', 'p72', 's31', 'team'],
#  ['p38', '空焊'],
#  ['塑膠', '引腳', '空焊', '鑷子', '零件'],
#  ['cersei', 'j39', 'j40', 'post', '零件'],
#  ['d10a', 'fan', 'pin', 'wxmx', '微鏡', '排針', '機台', '異常', '白色'],
#  ['dimm', 'dimm1', 'p32a', 'sb20t22670', 'volga', '板子', '焊點', '點位'],
#  ['lpt1', 'm450c', 'p38', 'sb20n61553', 'vb', '偏位', '設備異常'],
#  ['qfp', 'spi', '刮刀', '殘留', '短路', '鋼網', '錫膏'],
#  ['封裝'],
#  ['type', '受力', '外殼', '撞件', '距離', '電容'],
#  ['p3c', '品質', '效率', '良率', '重影', '隱患', '電容', '響產線'],
#  ['hu', 'p31a', 'pe', '撞件', '泡棉', '雙面'],
#  ['aj78', 'm99498', '高工'],
#  ['feeder', 'g9', 'm81626', 's33', 'twr', 'z2', '供料不穩', '電阻'],
#  ['speedtech', 'type'],
#  ['m09983', 'p31a', 'pike', 'ppid', '產品'],
#  ['m09983', 'p31a', 'pike', '撞件', '板作業', '貼片'],
#  ['vu67', '錫溫'],
#  ['bga', 'kent5', 'p3a', 'u4', '短路'],
#  ['d10b', 'kg', 'tracer', '壓力', '短路'],
#  ['d13', 'ic', 'low', 'ppid', 'sff', 'ven'],
#  ['d07', 'dolphin', 'hd', 'hrfmr', '空焊', '貼裝'],
#  ['pin', 'wlan', '機臺'],
#  ['d09', 'sb20n61337', 'u100'],
#  ['d04', 'ict', 'sb20n61336', 'vga', 'ytm400', '撞件', '線路'],
#  ['groot3', 'm99498', 'p3c', 'pin', '溫度', '短路', '錫珠'],
#  ['p31b', 'sierra', '目檢', '電容'],
#  ['aoi', 'cpu1', 'd05', 'matira5', 'vcore', '濾波', '異常', '網絡', '背板', '電容'],
#  ['npi', '包裝', '漏貼'],
#  ['l77195', 's34', '條件', '雙面', '電容'],
#  ['ids', 'nut1', 'nut2', 'trinidad', '螺絲柱'],
#  ['d09', 'fxd80', '殘錫', '維修'],
#  ['ids', 'l09623', 'trinidad', '不良板', '偏位', '設備異常'],
#  ['audio', 'd10b', '微鏡', '焊點', '空焊', '點位'],
#  ['料帶', '缺件', '貼片機'],
#  ['pin', 'winters', '排針'],
#  ['d08', 'hp', 'x0y8', '幹部', '時作業', '螺柱', '螺絲柱'],
#  ['ict', 'p34', '維修'],
#  ['a6', 'er', 'm44945', 'p36a', '松下', '殘件', '高二'],
#  ['d10a', 'f1hc1', 'repair', 'smt'],
#  ['hdmi', '同廠', '投板', '散料', '開線'],
#  ['d07', 'd11', 'sff', '系統'],
#  ['dimm4', 'pin', '維修'],
#  ['s33', '實物', '貼片機'],
#  ['fbt', 'xc300', '撞件', '開線'],
#  ['p3c', 'pcb', '毛刺', '漏銅', '螺絲', '週期'],
#  ['殘錫', '載具', '錫餅'],
#  ['p34', '主板', '燒板', '處理'],
#  ['cpu', 'm86349', 'p8', 'reno', '塑膠', '排針', '破損', '電源'],
#  ['m450c', 'p38', 'sb20n61553', 'vb', '空焊', '錫膏印刷'],
#  ['groot3', 'm99498', 'p2', 'p3c', '大圖', '時作業', '破損', '電源'],
#  ['d10b', 'd12', 'mtx', 'r6pct', '處理'],
#  ['supplier', '網卡', '網絡'],
#  ['j39', 'joffrey', 'p35', '空焊', '設備貼裝', '貼裝坐標'],
#  ['ib660cx', 'm450c', 'p38a', 'sb20n61553', 'vb', '空焊'],
#  ['d04', 'sc15', '撞件'],
#  ['d10a', 'f1hc1', '交叉', '錯位'],
#  ['d10b', 'repair', '吸嘴', '缺件', '螺絲柱'],
#  ['aj76', 'open', '線量'],
#  ['bent', 'cpu', 'd09', 'final', 'pin', 'vi'],
#  ['p37a', 'p3a', 'sb20n61337', '干涉', '板作業', '機台', '貼裝', '開線', '雙面', '零件'],
#  ['pcb', '偏位', '空焊', '雙面'],
#  ['p38a', 'spi', 'u4', '偏位', '鋼網'],
#  ['m450c', 'p38', 'sb20n61553', 'vb', '空焊', '錫膏印刷'],
#  ['hd', 'hrfmr', '濾波', '空焊', '電容'],
#  ['groot3', 'm99498', 'p3c'],
#  ['aoi', 'd08', '不良板', '偏位', '缺件', '設備異常'],
#  ['hsbp', 'matira5', 'smt', '排針'],
#  ['ict', 'p31', 'sierra', 'v2'],
#  ['fio', 'v2', '短路', '鐵殼'],
#  ['cersei', 'j94', 's33', '光板', '爐前', '程度', '聯基', '貼裝壓力'],
#  ['lot', 'usb', '外殼', '變形'],
#  ['dimm', 'p34b', '干涉', '撞件', '板作業', '機台', '貼片', '雙面'],
#  ['l09623', 'p31', '燒板'],
#  ['j39', 'pike', 'v2', '空焊'],
#  ['m09983', 'pike', 's31', 'v2', '保養', '偏位', '花板', '高一'],
#  ['m09983', 'uf', 'v2', '機打', '電容'],
#  ['d09', 'd10', 'dy62r', '夾邊', '時點', '花板', '軌道'],
#  ['matira5', 'slot1', '技能', '方案'],
#  ['d08', 'dy62r', 'ss', 'usb', '外殼', '變形'],
#  ['d08', 'd10', 'dy62r', '不良板', '空焊', '進料'],
#  ['a6', 'er', 'm44945', 'p36b', '對板', '濾波', '背板', '貼裝', '雙面', '電容'],
#  ['hsbp', 'matira5', 'smt', '排針'],
#  ['a6', 'er', 'ic', 'm44945', 'p36a', '空焊'],
#  ['a6', 'er', 'ic', 'm44945', 'p36a', '產品'],
#  ['groot3', 'm99498', '端子'],
#  ['p36', '燒板', '短路'],
#  ['hdmi', 'pin', '插件機'],
#  ['p32', 'twr', 'z2', '吸嘴', '殘錫', '電感'],
#  ['j90', 'j91', 'p3c'],
#  ['混料'],
#  ['card', 'ict', 'p3f', 'usb', '不良板'],
#  ['j90', 'j91', 'usb', '空焊'],
#  ['domino', 'm81600', '偏位', '間距'],
#  ['偏位', '設計', '間隙', '電感'],
#  ['d08', 'd10', 'ict', 'sff', '空焊'],
#  ['d10b', 'ict', 'r6pct', 'tracer', '撞件', '路由'],
#  ['d10a', 'dp1', 'pcb', '短路', '間隙'],
#  ['m10314', 'p31a', 'sierra', 'v2', '撞件', '時作業', '目檢', '貼片', '電感'],
#  ['爐前'],
#  ['d05', 'p1', 'sata', 'slot1', '噴霧', '清洗', '焊劑'],
#  ['bent', 'cpu', 'pin', 'sfc', '單根', '邊緣'],
#  ['m81592', 'scrabble', '偏位', '墊片'],
#  ['0402電容', 'feeder', 'pa', 'sb20n61336', 'ytm400'],
#  ['pu900', '偏位'],
#  ['m86349', 'reno', '撞件', '板作業', '流線', '目檢', '維修'],
#  ['cpu', 'fbt', 'p31', 'pin', 'sierra', 'v2'],
#  ['d05', 'front', 'tc', 'touch', 'up', 'usb'],
#  ['pin', 'ssd'],
#  ['d05', 'fio', 'matira35', '偏位', '機台'],
#  ['kent6', 'l75370', 'p37a', 'smt', '偏位', '空焊', '設備貼裝'],
#  ['j91', '膠紙', '鋼板'],
#  ['groot3', 'm99498', 'p3c', 'vendor', '燒板'],
#  ['cersei', 'p33a', 'pin', '排針', '軌道', '零件'],
#  ['cpu', 'm81542', 'reno2', '螺絲'],
#  ['pin', '單根', '工具', '目視'],
#  ['m81592', 'pcb', 'scrabble', '板子', '白色'],
#  ['cpu', '異常', '短路'],
#  ['n0992', '固定', '技能', '螺絲', '螺絲柱'],
#  ['hsb', '板子'],
#  ['缺件', '設備異常', '貼裝坐標'],
#  ['d07', 'hrfmr', 'ict', 'repair'],
#  ['kent5', 'spi', '目檢'],
#  ['kent5', 'p3a', 'smt', '維修'],
#  ['d05', 'fio', 'matira35', 'pwr', 'sop', '爐前'],
#  ['aoi', 'd10b', 'dimm', 'spi'],
#  ['d10b', 'd12', 'mtx', 'r6pct', '效率', '良率', '重影', '響產線'],
#  ['d10b', 'd12', 'mtx', 'r6pct', '處理'],
#  ['nf', 'pn', '容值'],
#  ['hsb', 'pcb', 'pq', 'qe', 'r6pct', 'sop', '目檢'],
#  ['實物'],
#  ['dimm2', '作業員', '目檢', '耳朵'],
#  ['aoi', 'feeder', 'ic', 'p3d', 'reno', '反白'],
#  ['groot3', 'p3c', 'x3', '表量', '貼裝壓力', '鋼網', '錫量'],
#  ['d08', 'groot3', 'repair', 'smt', '偏位', '短路'],
#  ['j90', 'p31b', 'usb', 'vendor', '交叉', '速度'],
#  ['card1', 'sd'],
#  ['d09', 'feeder', 'fxd80', '不良板', '更換', '設備異常'],
#  ['ee', 'p34b'],
#  ['d05', 'fio', 'matira35', 'pwr'],
#  ['d09', 'fxd80', '插件機', '插拔', '目檢'],
#  ['m44945', '偏位', '反白', '墊片', '貼裝高度'],
#  ['intel', 'lot', 'p00', 'p3f', '上料'],
#  ['intel', 'lot', 'p00', 'p3f', '上料'],
#  ['d07', 'd12', 'dolphin', 'spi', '品質', '微鏡', '鋼網', '電阻'],
#  ['lot', '處理', '錯料'],
#  ['pcb', 'qfp', '偏位', '刮刀', '良率', '變形'],
#  ['dimm', 'dimm3', 'tywin'],
#  ['d07', 'pq5001', 'pq5002'],
#  ['u5', '殘錫', '錫球', '零件'],
#  ['fbt', 'scrabble', 'spi', '座標', '空焊', '維修'],
#  ['0402電容', 'ib660cx', 'p38', 'pa', 'ytm400', '保養', '吸嘴', '殘錫'],
#  ['e49', 'kent5', 'm98850', 'p3a'],
#  ['in', 'input', 'p31b', 'sierra', '撞件'],
#  ['scrabble', 'xu1', '短路', '腳座', '鋼網'],
#  ['bent', 'cpu', 'groot3', 'm99498', 'pin', 'socket', '單根', '流水', '軌道'],
#  ['m81592', 'scrabble', 'team', 'type', '上料員', '貼片機', '重影'],
#  ['d10a', 'wxmx', '反白', '異常', '螺柱', '設備貼裝'],
#  ['kent5', 'm98850', '偏位', '識別', '電感'],
#  ['包裝', '撞件', '目檢'],
#  ['dell', 'p3d', 'reno2', '實物'],
#  ['juki插件機', 'm09983', 'p31b', 'pike', 'uf', '吸嘴', '干涉', '插件機', '零件', '電容'],
#  ['buffalo', 'd09', 'd11', 'x0y8', '泛三', '貼裝坐標', '跑偏'],
#  ['0402電容', 'pa', 'sb20n61337', '偏位', '異常', '貼裝頭', '高二'],
#  ['d07', '溫度'],
#  ['cpu', 'groot3', 'm99498', 'p3c', 'ray', 'xu1', '腳座'],
#  ['g9', 'ict', 'm81626', 'p33b', 'twr', 'xmm2', 'z2', '撞件', '板作業', '貼片', '電容'],
#  ['dimm1', 'groot3', 'm99498', 'sfc', '主板', '偏位', '維修', '線長', '良品'],
#  ['fio', 'p3f', 'v2', '刮刀', '單片'],
#  ['d09', 'fxd80', 'ict', '零件', '電容'],
#  ['殘件'],
#  ['aoi', 'feeder', 'm86349', 'p3d', 'reno', '供料不穩', '反白'],
#  ['j43', 'p31', 'pike', 'smt', '空焊'],
#  ['m81592', 'scrabble', '偏位', '貼裝坐標', '跑偏'],
#  ['d10a', 'f1hc1', 'option2', '貼裝坐標', '跑偏'],
#  ['eldorado', 'ict', 'm10315', 'p33a', 'v2', '目檢', '電容'],
#  ['d05', '偏位', '吸料位置', '跑偏'],
#  ['j8', 's34', 'type', '固定', '板子'],
#  ['d10b', 'd12', 'mtx', 'usb', 'widowmaker', '上料', '品質', '變形', '重影'],
#  ['aoi', 'sb20n61336', 'ytm400', '技能', '撞件'],
#  ['ib660cx', 'p38'],
#  ['fbt', 'p34a', 'vi', '缺件', '零件'],
#  ['fio', 'p3f', 'v2', '外殼'],
#  ['d12', 'fg47g', 'kyoto', 'mtp', '偏位', '偏出', '解焊'],
#  ['ee', 'm450c', 'p38a', 'sb20n61553', 'vb', '殘錫'],
#  ['aj78', 'kent5', 'm98850', '目檢', '路由'],
#  ['dy62r', 'grs', 'lot', 'lotes', 'pin'],
#  ['j39', 'm09983', 'pike', 's31', 'v2', '貼裝坐標'],
#  ['kent6', 'l75370', 'p37b', '受力', '撞件'],
#  ['ee', 'p32b', '目檢'],
#  ['domino', 'm81600', 'p33b', '撞件', '板作業', '零件', '電容'],
#  ['j39', 'm09983', 'pike', 'post', 's31', 'team', '空焊'],
#  ['j90', 'usb', '彈片', '機臺', '舌片'],
#  ['open', 'pcb', '卡板', '漏銅'],
#  ['d10b', 'n0992', 'rota', '不良板', '光板', '干涉', '微鏡', '設備貼裝'],
#  ['0402電容', 'ib660cx', 'n50s', 'pa', 'sb20n61335', '干涉', '程式', '貼裝'],
#  ['groot3', 'm99498', 'smt', '偏位', '電感'],
#  ['電感'],
#  ['sb20n61335', 'xc300'],
#  ['d11', 'feeder', 'l76450', 'tywin', '供料不穩', '高三'],
#  ['偏位', '目檢', '缺件'],
#  ['fbt', 'ib660cx', 'n50s', 'p38', 'pa', '偏位', '空焊', '電容'],
#  ['amd', 'd10b', '背板', '良率'],
#  ['d05', 'feeder', 'repair', '吸料位置', '缺件', '進料', '高四'],
#  ['m09983', 'pike', 'smt', '空焊'],
#  ['m09983', 'pike', 'spi', '空焊', '鋼網'],
#  ['npi', 'sparrow', '撞件', '目檢', '端板'],
#  ['lj2', '網絡'],
#  ['j41', 'p32a', 'pin'],
#  ['dp1', 'fxd80'],
#  ['nf', 'p3f', '錯料'],
#  ['p38', 'sb20n61336', '品質', '處理', '隱患'],
#  ['p2', '塑膠', '白色', '破損', '電源'],
#  ['d08', '破損', '零件'],
#  ['p36', '板子', '燒板'],
#  ['aud', 'jamie', 'l76451', 'p35', 'team', '偏位'],
#  ['fit', 'socket', '拖盤', '替代料', '鋼網'],
#  ['grs', 'lotes', 'sb20n61335', '固定', '隱患'],
#  ['d11', 'repair', 'sd', '板邊'],
#  ['d10b', 'lot', 'mtx', '壓痕', '效率', '背板', '良率', '重影', '鐵件', '響產線'],
#  ['cpu', 'ict', 'scrabble'],
#  ['groot3', 'ict', 'm99498', 'p3c', 'pin', '不良板', '插拔', '端子'],
#  ['a6', 'm44945', 'p36b', '外力', '安裝', '撞件'],
#  ['d08', 'groot3', 'm99498', 'pu900', '品質', '重影'],
#  ['aoi', 'm98850', '偏出', '堆板', '投板', '撞件', '規範性', '電容'],
#  ['j39', 'm81628', 'oolo', '吸料位置'],
#  ['ib660cx', 'sb20n61337', '錫球'],
#  ['ib660cx', 'p38a', 'pa', 'sb20n61337'],
#  ['ng', 's31', '保養', '偏位', '殘留', '高三'],
#  ['m81628', 'oolo', 'p33b', 'pcb', '外力', '板作業', '板邊', '破損'],
#  ['fio', 'p3f', 'z2', '生產'],
#  ['aud', 'joffrey', 'l76453', 'p35'],
#  ['p72', '爐前', '零件'],
#  ['p38', 'sb20n61335', 'xc300', '雙面', '零件'],
#  ['feeder', 'm09983', 'pike', 's31', '供料不穩', '反白'],
#  ['d10b', 'd12', 'mtx', 'r6pct', 'tracer', '品質', '處理', '重影'],
#  ['repair'],
#  ['kent6', 'l75370', 'p37a', '堆板', '撞件', '變形'],
#  ['p34', '空焊'],
#  ['d05', '偏位', '有所', '爐溫', '貼裝', '鋼網', '電感'],
#  ['j39', 'joffrey', 'p35', '功能pin', '空焊', '識別'],
#  ['c1', 'd10b', 'fio', 'typec1', 'usb'],
#  ['j46', 'm81592', 'ssd', '泛一', '空焊', '貼裝'],
#  ['p33a', 'p60'],
#  ['sb20n61337', '偏位', '吸嘴', '料帶', '泛一', '貼裝'],
#  ['groot3', 'm99498', 'p3c', '上料', '上料員', '混料'],
#  ['pcb'],
#  ['aud', 'p35', '燒板'],
#  ['d10b', '壓痕', '背板', '良率', '處理', '鐵件'],
#  ['塑膠', '排針', '殘膠'],
#  ['joffrey', 'l76453', '偏位', '偏出', '網絡', '貼裝', '間隙', '電容'],
#  ['d10a', 'd11', 'feeder', '供料不穩', '反白'],
#  ['aj76', '固定', '外殼', '變形'],
#  ['p32b', '排針', '目檢'],
#  ['e49', '差異', '幹部', '異常'],
#  ['d07', 'f1hc1', '空焊'],
#  ['kombucha', 'p33a', '撞件', '支架', '電容'],
#  ['buffalo', 'd07', 'd11', 'pin', 'rt', 'usb3s3'],
#  ['feeder', 'm09983', 's31', '供料不穩'],
#  ['a6', 'm44945', '對板', '濾波', '錫膏', '開線', '雙面'],
#  ['拖盤', '排針', '爐前'],
#  ['kent5', 'm98850', '不良板', '吸料', '吸料位置', '螺絲柱', '跑偏'],
#  ['usb3s3'],
#  ['bga', 'jamie', 'l76451', 'p35', '短路'],
#  ['j2', '打膠'],
#  ['d10', 'dy62r', '殘膠', '螺柱'],
#  ['j43', 'm09983', 's31', 'team'],
#  ['殘留', '載板', '錫餅'],
#  ['pn', 'uf', '容值', '電容'],
#  ['card', 'd07', 'hrfmr', 'sd', '處理'],
#  ['feeder', '反白', '更換', '週期'],
#  ['nut1', '料位跑偏', '泛二', '螺柱'],
#  ['m81542', 'reno2', 'x3', '保養', '偏位'],
#  ['nile', 'p32a', '受力', '撞件', '板作業', '維修', '線路', '貼片'],
#  ['mb', '偏位', '泛一', '空焊', '貼裝', '貼裝坐標'],
#  ['d05', 'ic', 'jwjy', '主板', '處理'],
#  ['sb20n61335', 'vi', '偏位', '零件', '電阻'],
#  ['cpu', 'f1hc1', 'pin', '投板', '自動化'],
#  ['kent6', 'l75370', '錯料', '阻值'],
#  ['d08', 'dimm', 'yp4hv', '殘留', '殘錫', '焊點', '載具'],
#  ['pin', 'short', 'vccgt', '偏位', '燒板', '靜態'],
#  ['cpu', 'ib660cx', 'ic', 'ict', 'p38', 'pa', '板子'],
#  ['mb', '刮刀', '短路'],
#  ['d07', 'dc48c', 'pcb'],
#  ['pcb', 'pin', 'usb', '固定'],
#  ['j90', 'j91', 'kent6', 'l75370', '爐前'],
#  ['p31', 'pike', '燒板'],
#  ['aj78', 'kent5', 'm98850', 'mfg', 'usb', '目檢', '規範性'],
#  ['d10a'],
#  ['kent5', 'm98850', 'p3a', 'u4', '不良板', '板照'],
#  ['d09', 'fxd80', 'usb3s3', '識別'],
#  ['m86349', 'reno', '刮刀', '更換', '短路', '鋼網', '錫膏印刷'],
#  ['groot3', 'p3c', '品質', '空焊', '載具', '陰影', '隱患'],
#  ['sierra', '螺絲柱', '風扇'],
#  ['dimm1', 'm09983', 'p31b', 'pike'],
#  ['m09983', 'pike', 's31', '偏位', '吸嘴', '貼裝', '速度', '電容'],
#  ['kent6', 'l75370', 'p37b', '螺絲孔'],
#  ['p34b', '包裝', '幹部', '撞件', '板子', '板邊'],
#  ['0201電容', 'ib660cx', 'n50s', 'pa', '偏位', '空焊'],
#  ['撞件', '板作業', '目檢'],
#  ['bga', 'pcb', 'u4', '泡棉', '破損'],
#  ['m45442', 'nebula'],
#  ['aud', 'l76450', 'tywin', '吸料位置', '缺件', '跑偏'],
#  ['ai', 'input', 'juki插件機', 'p32a', '表面', '電容'],
#  ['cpu', 'kent5', 'm98850', 'smt', '腳座', '電容'],
#  ['a8', 'm86365', '對板', '撞件', '濾波', '維修', '零件'],
#  ['燒板', '開機'],
#  ['0402電容', 'a8', 'bga', 'er', 'm86365', 'p36', 'p36a', '散熱片'],
#  ['intel', 's33', '偏位', '目檢', '空焊', '識別'],
#  ['con', 'in', 'm2', '插拔', '破損'],
#  ['dimm', 'label', 't00', '流水'],
#  ['引腳', '空焊'],
#  ['bom', 'elite', 'p38', 'sb20n61335', '容值', '更換', '消失', '電容'],
#  ['l76450', 'p37a', 'p77', 'tywin', '板作業', '板邊', '破損', '開線', '零件'],
#  ['kent5', 'm98850', 'x3', '偏位', '貼片機', '零件'],
#  ['d07', 'front', 'repair', 'tc', 'usb', '異常'],
#  ['aud', 'cersei', 'p34', '品質', '效率', '重影'],
#  ['hsbp', 'matira5', '固定'],
#  ['b1', 'f1hc1', '空焊'],
#  ['slot1', '清洗'],
#  ['差異', '載具'],
#  ['sb20n61335', 'vi', '偏位', '殘件'],
#  ['intel', 'mb', 's33', '反白', '差異', '晶振'],
#  ['intel', 'mb', 's33'],
#  ['d05', 'feeder', 'tvw7j', '供料不穩', '墊片', '高二'],
#  ['card', 'ict', 'p3f', 'short', 'usb'],
#  ['con', 'mb', 'p33a', 'pin', 'spi', '引腳', '排針'],
#  ['d07', 'f1hc1', 'ict', '空焊'],
#  ['galio', 'm90646', 'mj39', '料位跑偏'],
#  ['d10a', 'feeder', '供料不穩', '反白'],
#  ['drive', 'high', 'mosfet', 'side', 'vcore'],
#  ['intel', 'pch', 'u3', 'usb', 'vendor', '不良板', '異常'],
#  ['bent', 'pin', 'sb20t22670', 'socket', 'volga', '時作業'],
#  ['juki插件機', '松下', '機打', '空焊', '設計', '電容'],
#  ['全圖', '撞件'],
#  ['e49', 'm44945', 'p36', '品質', '效率', '重影'],
#  ['aud', 'cersei', 's34', '偏位', '貼裝', '貼裝坐標', '電感'],
#  ['feeder', 's33', '供料不穩', '偏位'],
#  ['kent5', 'p3a', 'sata', '工務'],
#  ['e49', '受力', '排針', '流向', '錫波'],
#  ['d07', 'hd', 'hold', '毛刺', '直通', '零件', '髒污'],
#  ['fbt', 'p38', 'pa', '泛一', '空焊', '貼裝坐標'],
#  ['aud', 'cpu', 'joffrey', 'p35', '板子'],
#  ['bga', 'd09', '散熱片', '規範性'],
#  ['matira', '鋼網', '電容'],
#  ['bom', 'p3d', 'pn', '更換'],
#  ['ff2', 'ng'],
#  ['j8', 'm86349', 'mfg', '技能', '機台'],
#  ['p3c', 'u4', '錫膏'],
#  ['p32b', 'sb20t22670', 'volga', '撞件', '時作業', '板邊', '零件'],
#  ['spi', '鋼網'],
#  ['d09', '剪腳', '干涉', '機打', '機臺', '腳長', '零件', '電容'],
#  ['撞件', '機臺', '濾波', '空間', '零件', '電容', '電源'],
#  ['groot3', 'm99498', 'pcb', '微鏡', '空焊', '腳座', '電容'],
#  ['bti', 'dimm', 'pcb', '單片', '折腳', '插件機', '生產品質'],
#  ['p32b', 'pin', 'refresh', '目視', '程度', '載具', '邊緣', '零件'],
#  ['l76450', 'tywin', '偏位', '吸嘴'],
#  ['feeder', 'j90', 'j91', 'kent6', 'l75370', '零件'],
#  ['j64', 'p31', 'spi', 'twr', 'z2', '泛二'],
#  ['hdmi', 'p3d', '焊點', '目視'],
#  ['0402電容', 'aud', 'l76453', '偏位', '貼裝坐標', '跑偏'],
#  ['buffalo', 'd11', 'dp1', 'mtp'],
#  ['d10b', 'type', 'typec1', '爐前', '載具'],
#  ['b1', '鋼網'],
#  ['alw', 'aud', 'joffrey', 'p35', 'pn', 'short', '燒板'],
#  ['domino', 'm81600', 'p33a', '撞件', '板作業', '貼片', '零件'],
#  ['不良率', '偏位', '單位', '目檢', '重影'],
#  ['ai', 'con', 'sorting', 'widowmaker', '引腳', '電容'],
#  ['cpu', 'p3d', 'ray', 'xu1', '腳座', '距離', '錫球'],
#  ['cpu', 'd05', '螺絲'],
#  ['0201電容', 'cersei', '偏位', '時點', '髒污', '高一'],
#  ['d05', 'matira5', 'ppid', '散熱片'],
#  ['散熱片', '膠紙'],
#  ['ict', 'm09983', 'p31', 'p31b', 'pike', '板邊', '零件'],
#  ['cpu', 'dsw', 'pn', 'pq4701', 'short', '主板', '電壓'],
#  ['d09', 'jonhon', 'pin', 'ssd', 'x0y8', '更換'],
#  ['固定', '空焊'],
#  ['usb', '彈片', '毛刺', '舌片', '變形'],
#  ['buffalo', 'd11', 'ps', 'sff', '吸嘴', '花板'],
#  ['p77', '機台', '破損'],
#  ['cn1', '維修'],
#  ['j64', 'j76', 'j81', 'j94'],
#  ['d10a', 'wxmx', '殘件', '設備貼裝'],
#  ['fxd80', 'rt', '板面', '機台', '殘錫', '線別'],
#  ['d10b', 'd12', 'mtx', 'r6pct', 'tracer', '處理'],
#  ['d09', 'dp1', 'fxd80'],
#  ['d07', 'front', 'tc', 'touch', 'up', 'usb'],
#  ['cpu', 'sb20n61337', '固定', '螺絲', '規範性'],
#  ['joffrey', 'p35a', '機打'],
#  ['m81592', 'p33a', 'scrabble', '撞件', '貼片'],
#  ['p31a', 'sierra', '產品', '異常'],
#  ['散熱片'],
#  ['bent', 'cpu', 'domino', 'm81600', 'p33a', 'pin', 'socket', '目檢', '邊緣'],
#  ['buffalo', 'd07', 'd11', 'rt', 'yp4hv', '偏位', '皮帶'],
#  ['d08', 'pin', 'wlan', '機臺'],
#  ['speedtech', '主板', '程度'],
#  ['aoi', 'card', 'sd', '目檢', '空焊', '缺件'],
#  ['bent', 'cpu', 'pin', '單根'],
#  ['j81', 'l77195', 's34', 'tywin'],
#  ['j39', 'scrabble', 'ssd', '泛一', '空焊', '貼裝', '貼裝壓力', '貼裝座標'],
#  ['d05', 'matira35', 'sd'],
#  ['bom', 'p3d', 'pn', '更換'],
#  ['bohemia', 'p31b', '撞件', '板邊', '貼片', '路由'],
#  ['groot3', 'm99498', 'p3c', '短路', '鋼板'],
#  ['短路', '線路', '電壓'],
#  ['d08', 'hsb', 'pcb', '微鏡', '漏銅', '線路'],
#  ['ict', 'p31', '燒板'],
#  ['sfc', 'vendor', '不良板', '消失', '異常', '開機', '電壓'],
#  ['j8'],
#  ['p32a', '安裝', '散熱片', '螺絲'],
#  ['cpu0', 'dimm3', 'dimm4', 'eldorado', 'p32', 'v2'],
#  ['d09', 'dimm1', 'm81592', 'scrabble', '產品', '破損', '處理'],
#  ['er', 'p36', 'sd', '助焊劑', '焊劑', '錫膏'],
#  ['sc15', '撞件', '目檢'],
#  ['dali', 'dimm', 's34', 'xmm1', '空焊', '貼裝'],
#  ['dp1', '泛三'],
#  ['燒板', '目檢', '短路'],
#  ['u5', 'u60', '空焊'],
#  ['eldorado', 'm10315', 'p33b', 'pca', 'v2', '漏銅', '線路'],
#  ['ej31', 'juki插件機', 'kent6', 'l75370', '壓件', '機臺'],
#  ['galio', 'm90646', 'p3d', '良率'],
#  ['pcb', '焊劑', '目檢', '處理', '螺絲孔'],
#  ['d10b', 'd12', 'mtx', 'pin', 'r6pct', 'tracer', '品質', '重影'],
#  ['j41', 'kombucha', 'p32', '燒板', '處理'],
#  ['cpu', 'dimm', 'pn', 'short', 'xu1', '毛刺', '點位'],
#  ['p27', '干涉', '模組', '變形', '電容'],
#  ['m81592', 'p32b', 'scrabble', '偏出', '擦板', '錫球'],
#  ['ps', '背板', '螺絲'],
#  ['adl', 'd10b', 'fan', 'mtx', 'nd', 'pin', 'r6pct', 'tracer', '外力'],
#  ['d07', 'd08', 'd10b', 'pin', 'wlan', '機臺'],
#  ['d08', 'pin', 'ssd', '機臺'],
#  ['kent5', 'p3a', '燒板'],
#  ['p34', 'tywin', '燒板'],
#  ['m2', 'matira', 'u1'],
#  ['d09', 'p38', 'sb20n61337', 'sw1', '不良板', '腳長', '軌道', '隱患'],
#  ['m81592', 'p32b', 'scrabble', '偏位', '偏出', '設備貼裝'],
#  ['d08', 'd12', 'mtx', 'r6pct'],
#  ['g9', 'j10', 'm81626', 'p32a', 'twr', 'z2', '變形'],
#  ['a6', 'er', 'ic', 'm44945', 'p36b', '電池'],
#  ['type', 'typec1', '貼裝壓力', '錫膏'],
#  ['ss', 'usb', '錯料'],
#  ['buffalo', 'd08', 'd11', 'gnvhc', 'mtp', '更換'],
#  ['l77195', '條件', '雙面', '電容'],
#  ['ib660cx', 'ic', 'p38', 'pa', 'sb20n61337', '偏位', '對板', '缺件'],
#  ['插件機', '松下', '機打', '電容'],
#  ['buffalo', 'card', 'gnvhc', 'sd', '空焊'],
#  ['dali', 'dimm', 's34', 'xmm1', '空焊'],
#  ['bent', 'cpu', 'pin'],
#  ['cpu', 'domino', 'm81600', 'socket', '偏位', '貼片', '電容', '高四'],
#  ['d05', 'jwjy', 'socket', '電容'],
#  ['scrabble', '泛一', '空焊', '識別'],
#  ['front', 'tc', 'usb'],
#  ['d09', 'e3', '缺件', '錯位'],
#  ['m90646', '偏位', '吸嘴', '機臺', '螺柱'],
#  ['p38', 'pa', 'pwr', 'sb20n61337', 'sw', '技能', '異常', '目檢', '空焊'],
#  ['aoi', 'd09', 'm81592', 'p32b', 'scrabble', '電容'],
#  ['cpu', 'd05', 'final', 'matira', 'tvw7j', 'vi', 'xl', '偏位', '電容', '響產線'],
#  ['a6', 'er', 'ic', 'p36', '錯料'],
#  ['bent', 'cpu', 'm09983', 'p31a', 'pike', 'pin', '單根'],
#  ['cersei', 'p33a', '工具', '撞件', '板作業', '背板', '路由', '零件'],
#  ['0402電容', '撞件', '板邊', '機台', '零件'],
#  ['d10b', 'lot', 'n0992', 'pin', 'ss', 'usb', '原物料', '聯基'],
#  ['uf', 'vendor', '容值', '更換', '電容'],
#  ['d10b', 'n0992', 'pin', 'wlan', '機臺', '網絡'],
#  ['j2', 'wlan', '不良板', '空焊'],
#  ['kent6', 'l75370', 'p3a', '偏位'],
#  ['d04', 'dmyn9', '包裝', '漏貼', '附件'],
#  ['sc15', '撞件'],
#  ['e3', 'ict', 'sb20n61337', '技能', '缺件', '藍色'],
#  ['sb20n61335', '堆板', '撞件', '電容'],
#  ['ee', 'l77195', 'p34b', 'socket', 'tywin', '貼片', '電容', '高四'],
#  ['ib660cx', 'p38b', 'pa', 'sb20n61337', '撞件', '目視', '電感'],
#  ['freeport', 'p36', '原物料', '聯基'],
#  ['p32', '上料員', '編帶', '電容'],
#  ['aoi', 'nile', '殘件', '電容'],
#  ['aoi', 'd05', 'p1', 'pin', 'spi', '偏位', '技能'],
#  ['p37b', 'sb20n61337', '偏位', '回焊爐', '貼裝', '雙面', '零件'],
#  ['sb20t22670', 'volga', '壓痕', '機臺', '破損', '零件'],
#  ['fio', 'p3f', 'u60', 'v2', '主板', '印刷機'],
#  ['殘錫', '螺絲孔'],
#  ['0402電容', 'm81628', 'oolong', 's33', '偏位', '吸嘴'],
#  ['d10a', 'ff2', 'ng'],
#  ['aoi', 'in', 'sfc', '全圖', '撞件', '電容'],
#  ['bent', 'cpu', 'm09983', 'p31a', 'pike', 'pin', 'socket', '單根'],
#  ['pn', '容值', '阻值'],
#  ['d09', 'fxd80', '偏位'],
#  ['d08', '品質', '焊點', '重影'],
#  ['bohemia', 'feeder', 's31', '供料不穩', '電感', '高四'],
#  ['pin', 'type', '寬度'],
#  ['bent', 'cpu', 'd04', 'm81592', 'repair', 'socket'],
#  ['bti', 'dimm', 'pcb', 'sierra', 'sop', '壓塊'],
#  ['aoi', 'qfp', 'sb20n61337', 'u100'],
#  ['bent', 'cpu', 'd10a', 'pin', 'r6pct', 'socket', '目檢', '路由'],
#  ['pin', 'spi', '清洗', '短路', '鋼網', '錫膏印刷'],
#  ['j90', 'p3f', '技能', '目檢', '設備異常'],
#  ['fio', 'p3f', '背板'],
#  ['cpu0', 'pu220', 'vcore', '錫珠'],
#  ['d07', 'fio', 'matira35', 'qfp', '印刷機', '板子'],
#  ['ib660cx', 'j2', 'pa'],
#  ['aoi', 'groot3', 'm99498', '偏位', '偏出', '干涉', '棧板', '異常', '程式', '貼裝'],
#  ['m09983', 'pike', 's31', '電感'],
#  ['ib660cx', 'ic', 'p38a', 'pa', 'sb20n61337', 'u100'],
#  ['p32a', 'salween', 'sb20t22662', '反白', '板面', '流線', '維修'],
#  ['d08', 'd09', '偏位', '偶發性', '貼裝', '軌道', '電感'],
#  ['aoi', 'd04', 'dimm', 'dimm2', 'pan', '雙面'],
#  ['ee', 'pa', 'sb20n61337', '缺件'],
#  ['d10b', 'rt', '時點', '皮帶', '高一'],
#  ['feeder', '供料不穩', '反白', '缺件'],
#  ['grs', 'lotes'],
#  ['ic', 'n50s', 'p38', 'pa', 'sb20n61335', '供料不穩', '備料', '反白', '異常'],
#  ['dp1', 'x0y8', '泛三'],
#  ['aoi', 'sb20n61335', '偏位', '偏出', '機臺', '程式'],
#  ['j39', 'p38', 'pa', 'post', 'sb20n61335', '吸料位置', '貼片'],
#  ['t00', '偏位', '電感'],
#  ['aud', 'p37', 'tywin', '主板'],
#  ['l77195', 's34', 'tywin'],
#  ['d08', 'fbt', 'option1', 'x0y8', '空焊'],
#  ['ng', '外力', '目檢', '零件'],
#  ['jamie', 'p35b', '撞件', '板作業', '破損', '背板', '零件'],
#  ['hled1', 'ict', 'supplier'],
#  ['amd', 'd10b', 'mfg', 'sorting', '電容'],
#  ['d04', 'pn', 'pq650', 'short'],
#  ['cpu', 'd10a', 'dimm1', 'supplier', '線路', '表量', '鐵件'],
#  ['dali', 'hdmi', 'ict'],
#  ['d10a', 'dc48c', 'dimm4', 'xu1', '空焊', '維修', '體值'],
#  ['lot', 'qe', 'usb', '聯基', '藍色', '誤料', '錯料'],
#  ['j90', 'j91', 'kent5', 'm98850', 'p3a', '功能pin', '空焊', '結構', '鋼板'],
#  ['cn1', 'matira'],
#  ['l77195', 's34', '條件', '雙面', '電容'],
#  ['藍色'],
#  ['d08', 'dy62r', 'fuconn', '定位腳', '零件', '電源'],
#  ['d05', 'k5c', 'matira', '偏位', '板子', '爐前', '零件'],
#  ['cpu', 'fbt', 'm81542', 'reno2', '螺絲'],
#  ['cpu', 'p33b', 'pin', 'socket', '時作業'],
#  ['花板'],
#  ['附件', '零件'],
#  ['m81592', 'pl935', 's33', 'scrabble', '偏位', '解焊'],
#  ['d07', 'd11', '保養', '吸嘴', '殘錫', '缺件'],
#  ['buffalo', 'd09', 'd11', 'type', '偏位', '吸料位置', '泛一', '跑偏'],
#  ['ee', 'p38a', 'socket', '偏出', '貼片', '電容', '高四'],
#  ['kent5', 'm98850', '不良板', '插件機', '流線'],
#  ['d10b', 'option1', 'pin', '供料不穩', '空焊'],
#  ['d07', 'ict', 'repair'],
#  ['sb20n61337', 'type', '程式', '貼片'],
#  ['bohemia', 'dimm', 's31', 'xmm2', '空焊', '貼片'],
#  ['d10', 'sff', 'smt', 'wlan', '偏位'],
#  ['kent6', 'l75370', 'p37a', 'uf', '濾波', '電容'],
#  ['ec', '信號', '燒板', '目檢'],
#  ...]

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules


# 將交易資料轉換為 one-hot 編碼的 DataFrame
te = TransactionEncoder()
te_array = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_array, columns=te.columns_)

# 使用 Apriori 找出高頻項目集
# min_support 可調整，例如設定為0.2，代表至少出現在 20% 交易中的項目組   0.004 = 421 至少 2 筆  0.00237=1
frequent_itemsets = apriori(df_encoded, min_support=0.0009, use_colnames=True)

print("高頻項目集 (Frequent Itemsets):")
frequent_itemsets
# Out:
# 高頻項目集 (Frequent Itemsets):
#        support                                           itemsets
# 0     0.005482                                           (0201電容)
# 1     0.015899                                           (0402電容)
# 2     0.003701                                               (a1)
# 3     0.006990                                               (a6)
# 4     0.003701                                               (a8)
# ...        ...                                                ...
# 5758  0.000959  (act, loc, dev, msr, a1, lm, std, lo, name, step)
# 5759  0.000959   (act, loc, msr, hi, a1, lm, std, lo, name, step)
# 5760  0.000959   (loc, dev, msr, hi, a1, lm, std, lo, name, step)
# 5761  0.001371  (act, loc, dev, msr, hi, lm, std, lo, name, step)
# 5762  0.000959  (act, loc, dev, msr, hi, a1, lm, std, lo, name...
#
# [5763 rows x 2 columns]

# %%
# 支持度 (support)

# 定義：高頻項目出現的比例。對於稀疏數據，設置較低的 support（如 0.01 至 0.05）更適合，以避免過高的門檻篩掉有意義的規則。
# 計算範例：支持度 0.01 表示項目需出現在至少 421 * 0.01 ≈ 4 筆交易中。

# 置信度 (confidence)

# 定義：當條件成立時，結果成立的概率。較低的 confidence（如 0.5 至 0.7）可生成更多規則，但可能包含較多低質量規則。
# 如果規則質量重要，可設置較高的 confidence（如 0.7 至 0.9）。

# %%
# 根據高頻項目集產生關聯規則
# metric 可以選 'confidence'、'lift'、'leverage'等，min_threshold 可依需要調整
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.007)

columns_to_round = [
    'antecedent support', 'consequent support', 'support', 
    'confidence', 'lift', 'leverage', 'conviction', 'zhangs_metric'
]
rules[columns_to_round] = rules[columns_to_round].round(4)

# %% [markdown]
# ### **欄位解釋**
#
# | **欄位名稱**            | **解釋**                                                                                                    |
# |-------------------------|-----------------------------------------------------------------------------------------------------------|
# | **`antecedents`**       | 前件項目（規則的 "如果" 部分）。                                                                          |
# | **`consequents`**       | 後件項目（規則的 "那麼" 部分）。                                                                          |
# | **`antecedent support`**| 前件項目出現的支持度，表示前件項目在所有交易中的比例。                                                       |
# | **`consequent support`**| 後件項目出現的支持度，表示後件項目在所有交易中的比例。                                                       |
# | **`support`**           | 前件和後件項目同時出現的支持度，表示兩者同時出現在交易中的比例。                                            |
# | **`confidence`**        | 置信度，表示在包含前件項目的交易中，後件項目出現的比例。計算公式：`support / antecedent support`           |
# | **`lift`**              | 提升度，表示前件和後件項目之間的相關性強度。計算公式：`confidence / consequent support`                   |
# | **`leverage`**          | 杠杆值，表示前後項目同時出現的實際頻率與預期頻率的差異。計算公式：`support - (antecedent support × consequent support)` |
# | **`conviction`**        | 信念度，衡量規則的可靠性。計算公式：`(1 - consequent support) / (1 - confidence)`                          |
# | **`zhangs_metric`**     | 張氏指標，衡量規則的重要性，介於 -1 和 1，值越接近 1 表示關聯越強。                                        |

# %%
print("\n關聯規則 (Association Rules):")
rules = rules[['antecedents', 'consequents', 'antecedent support',
       'consequent support', 'support', 'confidence', 'lift', 'zhangs_metric']]#.head(30)
# Out:
# 關聯規則 (Association Rules):

# %%
rules.head(80)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (偏位)    (0201電容)              0.1028              0.0055   0.0022
# 1     (0201電容)        (偏位)              0.0055              0.1028   0.0022
# 2     (0201電容)        (吸嘴)              0.0055              0.0232   0.0012
# 3         (吸嘴)    (0201電容)              0.0232              0.0055   0.0012
# 4         (撞件)    (0201電容)              0.0536              0.0055   0.0010
# ..         ...         ...                 ...                 ...      ...
# 75        (a1)      (name)              0.0037              0.0023   0.0011
# 76       (std)        (a1)              0.0022              0.0037   0.0011
# 77        (a1)       (std)              0.0037              0.0022   0.0011
# 78      (step)        (a1)              0.0026              0.0037   0.0014
# 79        (a1)      (step)              0.0037              0.0026   0.0014
#
#     confidence      lift  leverage  conviction  zhangs_metric
# 0       0.0213    3.8912    0.0016      1.0162         0.8281
# 1       0.4000    3.8912    0.0016      1.4953         0.7471
# 2       0.2250    9.7136    0.0011      1.2604         0.9020
# 3       0.0533    9.7136    0.0011      1.0505         0.9183
# 4       0.0179    3.2655    0.0007      1.0126         0.7331
# ..         ...       ...       ...         ...            ...
# 75      0.2963  127.1634    0.0011      1.4177         0.9958
# 76      0.5000  135.1111    0.0011      1.9926         0.9948
# 77      0.2963  135.1111    0.0011      1.4179         0.9963
# 78      0.5263  142.2222    0.0014      2.1033         0.9956
# 79      0.3704  142.2222    0.0014      1.5841         0.9967
#
# [80 rows x 10 columns]

# %%
rules[(rules['antecedents'] == {'吸嘴'})&(rules['consequents'] == {'殘錫'})].reset_index(drop=True)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0        (吸嘴)        (殘錫)              0.0232              0.0203   0.0029
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0      0.1243  6.1257    0.0024      1.1187         0.8566

# %%
rules[(rules['antecedents'] == {'吸嘴'})].reset_index(drop=True)
# Out:
#    antecedents consequents  antecedent support  consequent support  support  \
# 0         (吸嘴)    (0201電容)              0.0232              0.0055   0.0012
# 1         (吸嘴)    (0402電容)              0.0232              0.0159   0.0012
# 2         (吸嘴)      (high)              0.0232              0.0108   0.0010
# 3         (吸嘴)     (kyoto)              0.0232              0.0111   0.0011
# 4         (吸嘴)      (p29b)              0.0232              0.0055   0.0011
# 5         (吸嘴)       (ven)              0.0232              0.0104   0.0011
# 6         (吸嘴)        (保養)              0.0232              0.0070   0.0030
# 7         (吸嘴)        (偏位)              0.0232              0.1028   0.0079
# 8         (吸嘴)      (吸料位置)              0.0232              0.0145   0.0011
# 9         (吸嘴)        (殘錫)              0.0232              0.0203   0.0029
# 10        (吸嘴)        (泛一)              0.0232              0.0112   0.0021
# 11        (吸嘴)        (泛二)              0.0232              0.0077   0.0010
# 12        (吸嘴)        (空焊)              0.0232              0.0583   0.0012
# 13        (吸嘴)        (缺件)              0.0232              0.0387   0.0082
# 14        (吸嘴)        (螺柱)              0.0232              0.0074   0.0015
# 15        (吸嘴)        (貼裝)              0.0232              0.0396   0.0041
# 16        (吸嘴)        (電容)              0.0232              0.0643   0.0019
# 17        (吸嘴)        (電感)              0.0232              0.0182   0.0011
# 18        (吸嘴)        (電阻)              0.0232              0.0166   0.0015
# 19        (吸嘴)        (高一)              0.0232              0.0145   0.0037
# 20        (吸嘴)        (高三)              0.0232              0.0095   0.0015
# 21        (吸嘴)        (高二)              0.0232              0.0081   0.0012
# 22        (吸嘴)    (保養, 缺件)              0.0232              0.0025   0.0014
# 23        (吸嘴)    (偏位, 貼裝)              0.0232              0.0175   0.0025
# 24        (吸嘴)    (偏位, 高一)              0.0232              0.0067   0.0016
# 25        (吸嘴)    (缺件, 殘錫)              0.0232              0.0018   0.0015
# 26        (吸嘴)    (泛一, 缺件)              0.0232              0.0021   0.0010
# 27        (吸嘴)    (缺件, 貼裝)              0.0232              0.0032   0.0011
# 28        (吸嘴)    (高一, 缺件)              0.0232              0.0047   0.0018
#
#     confidence     lift  leverage  conviction  zhangs_metric
# 0       0.0533   9.7136    0.0011      1.0505         0.9183
# 1       0.0533   3.3495    0.0009      1.0395         0.7181
# 2       0.0414   3.8253    0.0007      1.0319         0.7561
# 3       0.0473   4.2639    0.0008      1.0380         0.7836
# 4       0.0473   8.6343    0.0010      1.0439         0.9051
# 5       0.0473   4.5444    0.0009      1.0388         0.7984
# 6       0.1302  18.6230    0.0029      1.1416         0.9687
# 7       0.3432   3.3386    0.0056      1.3660         0.7171
# 8       0.0473   3.2582    0.0008      1.0344         0.7095
# 9       0.1243   6.1257    0.0024      1.1187         0.8566
# 10      0.0888   7.8972    0.0018      1.0851         0.8941
# 11      0.0414   5.3964    0.0008      1.0352         0.8340
# 12      0.0533   0.9142   -0.0001      0.9947        -0.0876
# 13      0.3550   9.1854    0.0073      1.4905         0.9123
# 14      0.0651   8.7942    0.0013      1.0617         0.9073
# 15      0.1775   4.4815    0.0032      1.1677         0.7953
# 16      0.0828   1.2887    0.0004      1.0202         0.2293
# 17      0.0473   2.5968    0.0007      1.0306         0.6295
# 18      0.0651   3.9247    0.0011      1.0519         0.7629
# 19      0.1598  10.9965    0.0034      1.1728         0.9306
# 20      0.0651   6.8824    0.0013      1.0595         0.8750
# 21      0.0533   6.5855    0.0010      1.0477         0.8683
# 22      0.0592  23.9842    0.0013      1.0603         0.9810
# 23      0.1065   6.0710    0.0021      1.0996         0.8551
# 24      0.0710  10.5726    0.0015      1.0692         0.9269
# 25      0.0651  36.5298    0.0015      1.0677         0.9957
# 26      0.0414  20.1467    0.0009      1.0411         0.9729
# 27      0.0473  15.0162    0.0010      1.0464         0.9555
# 28      0.0769  16.5068    0.0017      1.0783         0.9617

# %%
rules[(rules['antecedents'] == {'反白'})].reset_index(drop=True)
# Out:
#    antecedents     consequents  antecedent support  consequent support  \
# 0         (反白)           (aoi)              0.0129              0.0270
# 1         (反白)        (feeder)              0.0129              0.0210
# 2         (反白)            (ic)              0.0129              0.0199
# 3         (反白)            (y5)              0.0129              0.0012
# 4         (反白)          (供料不穩)              0.0129              0.0099
# 5         (反白)            (偏位)              0.0129              0.1028
# 6         (反白)            (備料)              0.0129              0.0022
# 7         (反白)            (晶振)              0.0129              0.0025
# 8         (反白)            (缺件)              0.0129              0.0387
# 9         (反白)            (高四)              0.0129              0.0112
# 10        (反白)  (feeder, 供料不穩)              0.0129              0.0086
#
#     support  confidence     lift  leverage  conviction  zhangs_metric
# 0    0.0010      0.0745   2.7580    0.0006      1.0513         0.6457
# 1    0.0070      0.5426  25.8723    0.0067      2.1402         0.9739
# 2    0.0010      0.0745   3.7470    0.0007      1.0590         0.7427
# 3    0.0011      0.0851  68.9929    0.0011      1.0917         0.9984
# 4    0.0032      0.2447  24.7943    0.0030      1.3109         0.9722
# 5    0.0014      0.1064   1.0349    0.0000      1.0040         0.0342
# 6    0.0012      0.0957  43.6596    0.0012      1.1035         0.9898
# 7    0.0014      0.1064  43.1206    0.0013      1.1163         0.9896
# 8    0.0010      0.0745   1.9267    0.0005      1.0387         0.4872
# 9    0.0018      0.1383  12.3051    0.0016      1.1475         0.9307
# 10   0.0030      0.2340  27.1044    0.0029      1.2943         0.9757

# %%
rules[(rules['antecedents'] == {'反白'})&(rules['consequents'] == {'缺件'})].reset_index(drop=True)
# Out:
#   antecedents consequents  antecedent support  consequent support  support  \
# 0        (反白)        (缺件)              0.0129              0.0387    0.001
#
#    confidence    lift  leverage  conviction  zhangs_metric
# 0      0.0745  1.9267    0.0005      1.0387         0.4872

# %%
rules[rules['antecedents'] == {'feeder'}].reset_index(drop=True)
# Out:
#    antecedents  consequents  antecedent support  consequent support  support  \
# 0     (feeder)        (aoi)               0.021              0.0270   0.0011
# 1     (feeder)        (p25)               0.021              0.0136   0.0010
# 2     (feeder)     (repair)               0.021              0.0108   0.0012
# 3     (feeder)        (s31)               0.021              0.0048   0.0011
# 4     (feeder)       (供料不穩)               0.021              0.0099   0.0086
# 5     (feeder)         (偏位)               0.021              0.1028   0.0064
# 6     (feeder)         (反白)               0.021              0.0129   0.0070
# 7     (feeder)       (吸料位置)               0.021              0.0145   0.0011
# 8     (feeder)         (墊片)               0.021              0.0025   0.0011
# 9     (feeder)         (缺件)               0.021              0.0387   0.0027
# 10    (feeder)         (貼裝)               0.021              0.0396   0.0011
# 11    (feeder)         (進料)               0.021              0.0037   0.0011
# 12    (feeder)         (電容)               0.021              0.0643   0.0014
# 13    (feeder)         (電感)               0.021              0.0182   0.0014
# 14    (feeder)         (電阻)               0.021              0.0166   0.0011
# 15    (feeder)         (高一)               0.021              0.0145   0.0011
# 16    (feeder)         (高三)               0.021              0.0095   0.0018
# 17    (feeder)         (高二)               0.021              0.0081   0.0011
# 18    (feeder)         (高五)               0.021              0.0096   0.0015
# 19    (feeder)         (高四)               0.021              0.0112   0.0022
# 20    (feeder)  (s31, 供料不穩)               0.021              0.0010   0.0010
# 21    (feeder)   (偏位, 供料不穩)               0.021              0.0026   0.0025
# 22    (feeder)   (反白, 供料不穩)               0.021              0.0032   0.0030
# 23    (feeder)   (缺件, 供料不穩)               0.021              0.0011   0.0010
# 24    (feeder)   (高四, 供料不穩)               0.021              0.0011   0.0011
# 25    (feeder)     (偏位, 高五)               0.021              0.0051   0.0010
#
#     confidence     lift  leverage  conviction  zhangs_metric
# 0       0.0523   1.9365    0.0005      1.0267         0.4940
# 1       0.0458   3.3718    0.0007      1.0337         0.7185
# 2       0.0588   5.4326    0.0010      1.0510         0.8334
# 3       0.0523  10.8997    0.0010      1.0501         0.9277
# 4       0.4118  41.7255    0.0084      1.6832         0.9969
# 5       0.3072   2.9883    0.0043      1.2950         0.6796
# 6       0.3333  25.8723    0.0067      1.4807         0.9819
# 7       0.0523   3.5990    0.0008      1.0398         0.7376
# 8       0.0523  21.1939    0.0010      1.0526         0.9732
# 9       0.1307   3.3820    0.0019      1.1059         0.7194
# 10      0.0523   1.3200    0.0003      1.0134         0.2476
# 11      0.0523  14.1293    0.0010      1.0513         0.9491
# 12      0.0654   1.0168    0.0000      1.0012         0.0168
# 13      0.0654   3.5854    0.0010      1.0504         0.7365
# 14      0.0523   3.1528    0.0007      1.0377         0.6974
# 15      0.0523   3.5990    0.0008      1.0398         0.7376
# 16      0.0850   8.9844    0.0016      1.0825         0.9077
# 17      0.0523   6.4659    0.0009      1.0466         0.8635
# 18      0.0719   7.4936    0.0013      1.0671         0.8851
# 19      0.1046   9.3046    0.0020      1.1042         0.9116
# 20      0.0458  47.6863    0.0009      1.0469         1.0000
# 21      0.1176  45.1765    0.0024      1.1304         0.9988
# 22      0.1438  45.6130    0.0029      1.1643         0.9990
# 23      0.0458  41.7255    0.0009      1.0468         0.9969
# 24      0.0523  47.6863    0.0011      1.0540         1.0000
# 25      0.0458   9.0217    0.0009      1.0426         0.9082

# %%
rules
# Out:
#        antecedents                                        consequents  \
# 0             (偏位)                                           (0201電容)
# 1         (0201電容)                                               (偏位)
# 2         (0201電容)                                               (吸嘴)
# 3             (吸嘴)                                           (0201電容)
# 4             (撞件)                                           (0201電容)
# ...            ...                                                ...
# 185485        (lm)  (act, loc, dev, msr, hi, a1, std, lo, name, step)
# 185486       (std)   (act, loc, dev, msr, hi, a1, lm, lo, name, step)
# 185487        (lo)  (act, loc, dev, msr, hi, a1, lm, std, name, step)
# 185488      (name)    (act, loc, dev, msr, hi, a1, lm, std, lo, step)
# 185489      (step)    (act, loc, dev, msr, hi, a1, lm, std, lo, name)
#
#         antecedent support  consequent support  support  confidence      lift  \
# 0                   0.1028              0.0055   0.0022      0.0213    3.8912
# 1                   0.0055              0.1028   0.0022      0.4000    3.8912
# 2                   0.0055              0.0232   0.0012      0.2250    9.7136
# 3                   0.0232              0.0055   0.0012      0.0533    9.7136
# 4                   0.0536              0.0055   0.0010      0.0179    3.2655
# ...                    ...                 ...      ...         ...       ...
# 185485              0.0217              0.0010   0.0010      0.0443   46.1772
# 185486              0.0022              0.0010   0.0010      0.4375  456.0000
# 185487              0.0019              0.0010   0.0010      0.5000  521.1429
# 185488              0.0023              0.0010   0.0010      0.4118  429.1765
# 185489              0.0026              0.0010   0.0010      0.3684  384.0000
#
#         leverage  conviction  zhangs_metric
# 0         0.0016      1.0162         0.8281
# 1         0.0016      1.4953         0.7471
# 2         0.0011      1.2604         0.9020
# 3         0.0011      1.0505         0.9183
# 4         0.0007      1.0126         0.7331
# ...          ...         ...            ...
# 185485    0.0009      1.0454         1.0000
# 185486    0.0010      1.7761         1.0000
# 185487    0.0010      1.9981         1.0000
# 185488    0.0010      1.6984         1.0000
# 185489    0.0010      1.5818         1.0000
#
# [185490 rows x 10 columns]

# %%
def format_frozenset_columns(df, columns):
    """
    Format frozenset columns in a DataFrame to remove the frozenset wrapper.

    Args:
        df (pd.DataFrame): The DataFrame containing frozenset columns.
        columns (list): List of column names to format.

    Returns:
        pd.DataFrame: The formatted DataFrame.
    """
    df = df.copy()
    for column in columns:
        df[column] = df[column].apply(lambda x: ', '.join(x) if isinstance(x, frozenset) else x)
    return df



formatted_rules = format_frozenset_columns(rules, ["antecedents", "consequents"])

# %%
rules.to_excel('PDCS_Rules.xlsx', index=False)
